# %%
from Phenomena.phenomena_determination import Phenomena
from pymeeus.Epoch import Epoch
from pymeeus.Earth import Earth
from pymeeus.Jupiter import Jupiter
from pymeeus.JupiterMoons import JupiterMoons
from pymeeus.Sun import Sun

import pymeeus

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# Out:
# Occultation event detected on satellite : 2 @ (2020, 1, 2, 12, 25, 0.9999856352806091)
# Occultation event detected on satellite : 2 @ (2020, 1, 2, 12, 25, 1.9999802112579346)
# Penumbral event detected on satellite : 0 @ (2020, 1, 2, 12, 30, 50.99808722734451)
# Penumbral event detected on satellite : 0 @ (2020, 1, 2, 12, 30, 51.99808180332184)
# Umbral event detected on satellite : 0 @ (2020, 1, 2, 12, 31, 35.99784314632416)
# Umbral event detected on satellite : 0 @ (2020, 1, 2, 12, 31, 36.99783772230148)
# t_corretto: 	(2020, 1, 2, 12, 39, 44.82222855091095)
# t_corretto: 	(2020, 1, 2, 12, 38, 59.82279449701309)

# %% [markdown]
# # Test computaion for Io on January first

# %%
epoch = Epoch()
epoch.set(2020, 1, 2, 12, 0, 0)
time_step = 1.157401129603386e-05

# %%
#radii of the galileian satellites in jupiter-radii
moons_radii = np.array([[3643.2/(2*69911) , 3121.6/(2*69911) , 5262.4/(2*69911), 4820.6/(2*69911)], [0,0,0,0], [0,0,0,0]])
moons_radii_vec = np.array([3643.2/(2*69911) , 3121.6/(2*69911) , 5262.4/(2*69911), 4820.6/(2*69911)])

# %%
print(moons_radii)
# Out:
# [[0.02605599 0.02232553 0.03763642 0.03447669]
#  [0.         0.         0.         0.        ]
#  [0.         0.         0.         0.        ]]

# %%
position_matrix = (np.array(JupiterMoons.rectangular_positions(epoch))).reshape(4, 3)

alpha_rad, vertex_jr,beta_rad, beta_vertex = Phenomena.round_base_cone_param(epoch, True) # True

print("Alpha : " + str(alpha_rad * 180/np.pi))
print("Vertex : " + str(vertex_jr))
print("Beta : " + str(beta_rad * 180/np.pi))
print("Penumbral Vertex : " + str(beta_vertex))

alpha_comp = np.pi/2 - alpha_rad

print("Alpha_comp : " + str(alpha_comp * 180/np.pi))

r = np.sqrt(position_matrix[:, 0]**2 + position_matrix[:, 1]**2 + position_matrix[:, 2]**2)

intersection_point = vertex_jr - r
print("Cone intersection depth : " + str(intersection_point[0]))

r_width = intersection_point * np.tan(alpha_comp)
print("Width of shadow (radius) : " + str(r_width))

#r_width = r_width **2

r_penumbra = 1 + (1/np.tan(beta_rad)) * r

print("Width of penumbra :" + str(r_penumbra))
# Out:
# Alpha : 89.95451017234058
# Vertex : 1259.5292271319984
# Beta : 89.94353819216131
# Penumbral Vertex : -1087.198425969685
# Alpha_comp : 0.045489827659419085
# Cone intersection depth : 1253.6041626623378
# Width of shadow (radius) : [0.99529581 0.99252102 0.98810992 0.97922513]
# Width of penumbra :[1.00583882 1.00928289 1.01475793 1.02578569]

# %%
for i in range(1, 3600):

    epoch += time_step
    phenomena_matrix = JupiterMoons.check_phenomena(epoch)


    for i in range(0, 3):

            if ((phenomena_matrix[i][0] <= r_width[i]) and (phenomena_matrix[i][0] > 0)):
                print(epoch.get_full_date())
                print ("Phenomena of satellite " +str(i))
                print(phenomena_matrix[i])

            if ((phenomena_matrix[i][1] <=  r_width[i]) and (phenomena_matrix[i][1] > 0)):
                print(epoch.get_full_date())
                print("Phenomena of satellite " + str(i))
                print(phenomena_matrix[i])

            if ((phenomena_matrix[i][0] >= - r_width[i]) and (phenomena_matrix[i][0] < 0)):
                print(epoch.get_full_date())
                print("Phenomena of satellite " + str(i))
                print(phenomena_matrix[i])

            if ((phenomena_matrix[i][1] >= - r_width[i]) and (phenomena_matrix[i][1] < 0)):
                print(epoch.get_full_date())
                print("Phenomena of satellite " + str(i))
                print(phenomena_matrix[i])
# Out:
# (2020, 1, 2, 12, 0, 0.9999945759773254)
# Phenomena of satellite 2
# [0.7512755847430287, 0.9630942162139595, 0.0]
# (2020, 1, 2, 12, 0, 0.9999945759773254)
# Phenomena of satellite 2
# [0.7512755847430287, 0.9630942162139595, 0.0]
# (2020, 1, 2, 12, 0, 1.9999891519546509)
# Phenomena of satellite 2
# [0.7513660345593101, 0.9632114704803654, 0.0]
# (2020, 1, 2, 12, 0, 1.9999891519546509)
# Phenomena of satellite 2
# [0.7513660345593101, 0.9632114704803654, 0.0]
# (2020, 1, 2, 12, 0, 2.9999837279319763)
# Phenomena of satellite 2
# [0.7514565039594641, 0.9633287343109468, 0.0]
# (2020, 1, 2, 12, 0, 2.9999837279319763)
# Phenomena of satellite 2
# [0.7514565039594641, 0.9633287343109468, 0.0]
# (2020, 1, 2, 12, 0, 3.9999783039093018)
# Phenomena of satellite 2
# [0.7515469929639059, 0.963446007736384, 0.0]
# (2020, 1, 2, 12, 0, 3.9999783039093018)
# Phenomena of satellite 2
# [0.7515469929639059, 0.963446007736384, 0.0]
# (2020, 1, 2, 12, 0, 4.999972879886627)
# Phenomena of satellite 2
# [0.7516375015650936, 0.9635632906898891, 0.0]
# (2020, 1, 2, 12, 0, 4.999972879886627)
# Phenomena of satellite 2
# [0.7516375015650936, 0.9635632906898891, 0.0]
# (2020, 1, 2, 12, 0, 5.999967455863953)
# Phenomena of satellite 2
# [0.7517280297671787, 0.9636805832311384, 0.0]
# (2020, 1, 2, 12, 0, 5.999967455863953)
# Phenomena of satellite 2
# [0.7517280297671787, 0.9636805832311384, 0.0]
# (2020, 1, 2, 12, 0, 6.999962031841278)
# Phenomena of satellite 2
# [0.7518185775086685, 0.9637978852515678, 0.0]
# (2020, 1, 2, 12, 0, 6.999962031841278)
# Phenomena of satellite 2
# [0.7518185775086685, 0.9637978852515678, 0.0]
# (2020, 1, 2, 12, 0, 7.9999566078186035)
# Phenomena of satellite 2
# [0.7519091447768304, 0.9639151968735088, 0.0]
# (2020, 1, 2, 12, 0, 7.9999566078186035)
# Phenomena of satellite 2
# [0.7519091447768304, 0.9639151968735088, 0.0]
# (2020, 1, 2, 12, 0, 8.999951183795929)
# Phenomena of satellite 2
# [0.7519997316461902, 0.9640325180095254, 0.0]
# (2020, 1, 2, 12, 0, 8.999951183795929)
# Phenomena of satellite 2
# [0.7519997316461902, 0.9640325180095254, 0.0]
# (2020, 1, 2, 12, 0, 9.999945759773254)
# Phenomena of satellite 2
# [0.7520903380715801, 0.9641498486769884, 0.0]
# (2020, 1, 2, 12, 0, 9.999945759773254)
# Phenomena of satellite 2
# [0.7520903380715801, 0.9641498486769884, 0.0]
# (2020, 1, 2, 12, 0, 10.99994033575058)
# Phenomena of satellite 2
# [0.7521809640404558, 0.9642671889146566, 0.0]
# (2020, 1, 2, 12, 0, 10.99994033575058)
# Phenomena of satellite 2
# [0.7521809640404558, 0.9642671889146566, 0.0]
# (2020, 1, 2, 12, 0, 11.999934911727905)
# Phenomena of satellite 2
# [0.752271609523965, 0.9643845386556954, 0.0]
# (2020, 1, 2, 12, 0, 11.999934911727905)
# Phenomena of satellite 2
# [0.752271609523965, 0.9643845386556954, 0.0]
# (2020, 1, 2, 12, 0, 12.99992948770523)
# Phenomena of satellite 2
# [0.7523622744989801, 0.9645018978967594, 0.0]
# (2020, 1, 2, 12, 0, 12.99992948770523)
# Phenomena of satellite 2
# [0.7523622744989801, 0.9645018978967594, 0.0]
# (2020, 1, 2, 12, 0, 13.999924063682556)
# Phenomena of satellite 2
# [0.7524529590720197, 0.9646192666972856, 0.0]
# (2020, 1, 2, 12, 0, 13.999924063682556)
# Phenomena of satellite 2
# [0.7524529590720197, 0.9646192666972856, 0.0]
# (2020, 1, 2, 12, 0, 14.999918639659882)
# Phenomena of satellite 2
# [0.7525436631006605, 0.9647366449696558, 0.0]
# (2020, 1, 2, 12, 0, 14.999918639659882)
# Phenomena of satellite 2
# [0.7525436631006605, 0.9647366449696558, 0.0]
# (2020, 1, 2, 12, 0, 15.999913215637207)
# Phenomena of satellite 2
# [0.7526343866860967, 0.9648540328365062, 0.0]
# (2020, 1, 2, 12, 0, 15.999913215637207)
# Phenomena of satellite 2
# [0.7526343866860967, 0.9648540328365062, 0.0]
# (2020, 1, 2, 12, 0, 16.999907791614532)
# Phenomena of satellite 2
# [0.7527251297344499, 0.9649714301681204, 0.0]
# (2020, 1, 2, 12, 0, 16.999907791614532)
# Phenomena of satellite 2
# [0.7527251297344499, 0.9649714301681204, 0.0]
# (2020, 1, 2, 12, 0, 17.999902367591858)
# Phenomena of satellite 2
# [0.7528158922549614, 0.9650888369821639, 0.0]
# (2020, 1, 2, 12, 0, 17.999902367591858)
# Phenomena of satellite 2
# [0.7528158922549614, 0.9650888369821639, 0.0]
# (2020, 1, 2, 12, 0, 18.999896943569183)
# Phenomena of satellite 2
# [0.7529066743164244, 0.965206253317045, 0.0]
# (2020, 1, 2, 12, 0, 18.999896943569183)
# Phenomena of satellite 2
# [0.7529066743164244, 0.965206253317045, 0.0]
# (2020, 1, 2, 12, 0, 19.99989151954651)
# Phenomena of satellite 2
# [0.7529974758087657, 0.9653236791691361, 0.0]
# (2020, 1, 2, 12, 0, 19.99989151954651)
# Phenomena of satellite 2
# [0.7529974758087657, 0.9653236791691361, 0.0]
# (2020, 1, 2, 12, 0, 20.999886095523834)
# Phenomena of satellite 2
# [0.7530882968007614, 0.9654411145350148, 0.0]
# (2020, 1, 2, 12, 0, 20.999886095523834)
# Phenomena of satellite 2
# [0.7530882968007614, 0.9654411145350148, 0.0]
# (2020, 1, 2, 12, 0, 21.99988067150116)
# Phenomena of satellite 2
# [0.7531791372366878, 0.9655585593613236, 0.0]
# (2020, 1, 2, 12, 0, 21.99988067150116)
# Phenomena of satellite 2
# [0.7531791372366878, 0.9655585593613236, 0.0]
# (2020, 1, 2, 12, 0, 22.999875247478485)
# Phenomena of satellite 2
# [0.753269997120146, 0.9656760136602903, 0.0]
# (2020, 1, 2, 12, 0, 22.999875247478485)
# Phenomena of satellite 2
# [0.753269997120146, 0.9656760136602903, 0.0]
# (2020, 1, 2, 12, 0, 23.99986982345581)
# Phenomena of satellite 2
# [0.7533608764874933, 0.9657934774835385, 0.0]
# (2020, 1, 2, 12, 0, 23.99986982345581)
# Phenomena of satellite 2
# [0.7533608764874933, 0.9657934774835385, 0.0]
# (2020, 1, 2, 12, 0, 24.999864399433136)
# Phenomena of satellite 2
# [0.7534517752611084, 0.965910950785563, 0.0]
# (2020, 1, 2, 12, 0, 24.999864399433136)
# Phenomena of satellite 2
# [0.7534517752611084, 0.965910950785563, 0.0]
# (2020, 1, 2, 12, 0, 25.99985897541046)
# Phenomena of satellite 2
# [0.7535426934991521, 0.9660284335838728, 0.0]
# (2020, 1, 2, 12, 0, 25.99985897541046)
# Phenomena of satellite 2
# [0.7535426934991521, 0.9660284335838728, 0.0]
# (2020, 1, 2, 12, 0, 26.999853551387787)
# Phenomena of satellite 2
# [0.7536336311729677, 0.9661459258118367, 0.0]
# (2020, 1, 2, 12, 0, 26.999853551387787)
# Phenomena of satellite 2
# [0.7536336311729677, 0.9661459258118367, 0.0]
# (2020, 1, 2, 12, 0, 27.999848127365112)
# Phenomena of satellite 2
# [0.7537245882369896, 0.9662634275290184, 0.0]
# (2020, 1, 2, 12, 0, 27.999848127365112)
# Phenomena of satellite 2
# [0.7537245882369896, 0.9662634275290184, 0.0]
# (2020, 1, 2, 12, 0, 28.999842703342438)
# Phenomena of satellite 2
# [0.7538155647443103, 0.9663809387529634, 0.0]
# (2020, 1, 2, 12, 0, 28.999842703342438)
# Phenomena of satellite 2
# [0.7538155647443103, 0.9663809387529634, 0.0]
# (2020, 1, 2, 12, 0, 29.999837279319763)
# Phenomena of satellite 2
# [0.7539065606060429, 0.9664984593961303, 0.0]
# (2020, 1, 2, 12, 0, 29.999837279319763)
# Phenomena of satellite 2
# [0.7539065606060429, 0.9664984593961303, 0.0]
# (2020, 1, 2, 12, 0, 30.99983185529709)
# Phenomena of satellite 2
# [0.7539975759459365, 0.9666159895390869, 0.0]
# (2020, 1, 2, 12, 0, 30.99983185529709)
# Phenomena of satellite 2
# [0.7539975759459365, 0.9666159895390869, 0.0]
# (2020, 1, 2, 12, 0, 31.999826431274414)
# Phenomena of satellite 2
# [0.7540886106371913, 0.9667335291151202, 0.0]
# (2020, 1, 2, 12, 0, 31.999826431274414)
# Phenomena of satellite 2
# [0.7540886106371913, 0.9667335291151202, 0.0]
# (2020, 1, 2, 12, 0, 32.99982100725174)
# Phenomena of satellite 2
# [0.7541796647160975, 0.9668510781419195, 0.0]
# (2020, 1, 2, 12, 0, 32.99982100725174)
# Phenomena of satellite 2
# [0.7541796647160975, 0.9668510781419195, 0.0]
# (2020, 1, 2, 12, 0, 33.999815583229065)
# Phenomena of satellite 2
# [0.7542707381703181, 0.9669686366580751, 0.0]
# (2020, 1, 2, 12, 0, 33.999815583229065)
# Phenomena of satellite 2
# [0.7542707381703181, 0.9669686366580751, 0.0]
# (2020, 1, 2, 12, 0, 34.99981015920639)
# Phenomena of satellite 2
# [0.754361830992601, 0.9670862045758567, 0.0]
# (2020, 1, 2, 12, 0, 34.99981015920639)
# Phenomena of satellite 2
# [0.754361830992601, 0.9670862045758567, 0.0]
# (2020, 1, 2, 12, 0, 35.999804735183716)
# Phenomena of satellite 2
# [0.7544529431871355, 0.9672037819548354, 0.0]
# (2020, 1, 2, 12, 0, 35.999804735183716)
# Phenomena of satellite 2
# [0.7544529431871355, 0.9672037819548354, 0.0]
# (2020, 1, 2, 12, 0, 36.99979931116104)
# Phenomena of satellite 2
# [0.7545440747411263, 0.9673213688127811, 0.0]
# (2020, 1, 2, 12, 0, 36.99979931116104)
# Phenomena of satellite 2
# [0.7545440747411263, 0.9673213688127811, 0.0]
# (2020, 1, 2, 12, 0, 37.99979388713837)
# Phenomena of satellite 2
# [0.7546352256420782, 0.9674389650828779, 0.0]
# (2020, 1, 2, 12, 0, 37.99979388713837)
# Phenomena of satellite 2
# [0.7546352256420782, 0.9674389650828779, 0.0]
# (2020, 1, 2, 12, 0, 38.99978846311569)
# Phenomena of satellite 2
# [0.7547263958829812, 0.9675565707616908, 0.0]
# (2020, 1, 2, 12, 0, 38.99978846311569)
# Phenomena of satellite 2
# [0.7547263958829812, 0.9675565707616908, 0.0]
# (2020, 1, 2, 12, 0, 39.99978303909302)
# Phenomena of satellite 2
# [0.7548175854678738, 0.9676741858878082, 0.0]
# (2020, 1, 2, 12, 0, 39.99978303909302)
# Phenomena of satellite 2
# [0.7548175854678738, 0.9676741858878082, 0.0]
# (2020, 1, 2, 12, 0, 40.99977761507034)
# Phenomena of satellite 2
# [0.7549087943840878, 0.9677918104287304, 0.0]
# (2020, 1, 2, 12, 0, 40.99977761507034)
# Phenomena of satellite 2
# [0.7549087943840878, 0.9677918104287304, 0.0]
# (2020, 1, 2, 12, 0, 41.99977219104767)
# Phenomena of satellite 2
# [0.7550000226190788, 0.9679094444390165, 0.0]
# (2020, 1, 2, 12, 0, 41.99977219104767)
# Phenomena of satellite 2
# [0.7550000226190788, 0.9679094444390165, 0.0]
# (2020, 1, 2, 12, 0, 42.999766767024994)
# Phenomena of satellite 2
# [0.7550912701659018, 0.9680270878019763, 0.0]
# (2020, 1, 2, 12, 0, 42.999766767024994)
# Phenomena of satellite 2
# [0.7550912701659018, 0.9680270878019763, 0.0]
# (2020, 1, 2, 12, 0, 43.99976134300232)
# Phenomena of satellite 2
# [0.7551825370120913, 0.9681447406193783, 0.0]
# (2020, 1, 2, 12, 0, 43.99976134300232)
# Phenomena of satellite 2
# [0.7551825370120913, 0.9681447406193783, 0.0]
# (2020, 1, 2, 12, 0, 44.999755918979645)
# Phenomena of satellite 2
# [0.7552738231778414, 0.9682624028457151, 0.0]
# (2020, 1, 2, 12, 0, 44.999755918979645)
# Phenomena of satellite 2
# [0.7552738231778414, 0.9682624028457151, 0.0]
# (2020, 1, 2, 12, 0, 45.99975049495697)
# Phenomena of satellite 2
# [0.755365128666983, 0.9683800744983299, 0.0]
# (2020, 1, 2, 12, 0, 45.99975049495697)
# Phenomena of satellite 2
# [0.755365128666983, 0.9683800744983299, 0.0]
# (2020, 1, 2, 12, 0, 46.999745070934296)
# Phenomena of satellite 2
# [0.7554564533906755, 0.9684977555528677, 0.0]
# (2020, 1, 2, 12, 0, 46.999745070934296)
# Phenomena of satellite 2
# [0.7554564533906755, 0.9684977555528677, 0.0]
# (2020, 1, 2, 12, 0, 47.99973964691162)
# Phenomena of satellite 2
# [0.7555477974019817, 0.9686154460058563, 0.0]
# (2020, 1, 2, 12, 0, 47.99973964691162)
# Phenomena of satellite 2
# [0.7555477974019817, 0.9686154460058563, 0.0]
# (2020, 1, 2, 12, 0, 48.99973422288895)
# Phenomena of satellite 2
# [0.7556391607047739, 0.9687331458538162, 0.0]
# (2020, 1, 2, 12, 0, 48.99973422288895)
# Phenomena of satellite 2
# [0.7556391607047739, 0.9687331458538162, 0.0]
# (2020, 1, 2, 12, 0, 49.99972879886627)
# Phenomena of satellite 2
# [0.7557305432535805, 0.9688508550932114, 0.0]
# (2020, 1, 2, 12, 0, 49.99972879886627)
# Phenomena of satellite 2
# [0.7557305432535805, 0.9688508550932114, 0.0]
# (2020, 1, 2, 12, 0, 50.9997233748436)
# Phenomena of satellite 2
# [0.7558219450908221, 0.9689685737416777, 0.0]
# (2020, 1, 2, 12, 0, 50.9997233748436)
# Phenomena of satellite 2
# [0.7558219450908221, 0.9689685737416777, 0.0]
# (2020, 1, 2, 12, 0, 51.99971795082092)
# Phenomena of satellite 2
# [0.7559133661602004, 0.9690863017744892, 0.0]
# (2020, 1, 2, 12, 0, 51.99971795082092)
# Phenomena of satellite 2
# [0.7559133661602004, 0.9690863017744892, 0.0]
# (2020, 1, 2, 12, 0, 52.99971252679825)
# Phenomena of satellite 2
# [0.7560048064820967, 0.9692040391887278, 0.0]
# (2020, 1, 2, 12, 0, 52.99971252679825)
# Phenomena of satellite 2
# [0.7560048064820967, 0.9692040391887278, 0.0]
# (2020, 1, 2, 12, 0, 53.999707102775574)
# Phenomena of satellite 2
# [0.7560962660110891, 0.9693217859802359, 0.0]
# (2020, 1, 2, 12, 0, 53.999707102775574)
# Phenomena of satellite 2
# [0.7560962660110891, 0.9693217859802359, 0.0]
# (2020, 1, 2, 12, 0, 54.9997016787529)
# Phenomena of satellite 2
# [0.7561877448002806, 0.9694395421880301, 0.0]
# (2020, 1, 2, 12, 0, 54.9997016787529)
# Phenomena of satellite 2
# [0.7561877448002806, 0.9694395421880301, 0.0]
# (2020, 1, 2, 12, 0, 55.999696254730225)
# Phenomena of satellite 2
# [0.7562792428263345, 0.9695573077244388, 0.0]
# (2020, 1, 2, 12, 0, 55.999696254730225)
# Phenomena of satellite 2
# [0.7562792428263345, 0.9695573077244388, 0.0]
# (2020, 1, 2, 12, 0, 56.99969083070755)
# Phenomena of satellite 2
# [0.7563707600604784, 0.9696750826490659, 0.0]
# (2020, 1, 2, 12, 0, 56.99969083070755)
# Phenomena of satellite 2
# [0.7563707600604784, 0.9696750826490659, 0.0]
# (2020, 1, 2, 12, 0, 57.999685406684875)
# Phenomena of satellite 2
# [0.7564622964899989, 0.969792866916306, 0.0]
# (2020, 1, 2, 12, 0, 57.999685406684875)
# Phenomena of satellite 2
# [0.7564622964899989, 0.969792866916306, 0.0]
# (2020, 1, 2, 12, 0, 58.9996799826622)
# Phenomena of satellite 2
# [0.756553852135388, 0.9699106605648474, 0.0]
# (2020, 1, 2, 12, 0, 58.9996799826622)
# Phenomena of satellite 2
# [0.756553852135388, 0.9699106605648474, 0.0]
# (2020, 1, 2, 12, 0, 59.999674558639526)
# Phenomena of satellite 2
# [0.7566454269731363, 0.9700284636044431, 0.0]
# (2020, 1, 2, 12, 0, 59.999674558639526)
# Phenomena of satellite 2
# [0.7566454269731363, 0.9700284636044431, 0.0]
# (2020, 1, 2, 12, 1, 0.9996691346168518)
# Phenomena of satellite 2
# [0.7567370210073696, 0.9701462759842492, 0.0]
# (2020, 1, 2, 12, 1, 0.9996691346168518)
# Phenomena of satellite 2
# [0.7567370210073696, 0.9701462759842492, 0.0]
# (2020, 1, 2, 12, 1, 1.9996637105941772)
# Phenomena of satellite 2
# [0.756828634225319, 0.9702640977139113, 0.0]
# (2020, 1, 2, 12, 1, 1.9996637105941772)
# Phenomena of satellite 2
# [0.756828634225319, 0.9702640977139113, 0.0]
# (2020, 1, 2, 12, 1, 2.9996582865715027)
# Phenomena of satellite 2
# [0.7569202665982977, 0.9703819287900228, 0.0]
# (2020, 1, 2, 12, 1, 2.9996582865715027)
# Phenomena of satellite 2
# [0.7569202665982977, 0.9703819287900228, 0.0]
# (2020, 1, 2, 12, 1, 3.999652862548828)
# Phenomena of satellite 2
# [0.7570119181356454, 0.9704997692090782, 0.0]
# (2020, 1, 2, 12, 1, 3.999652862548828)
# Phenomena of satellite 2
# [0.7570119181356454, 0.9704997692090782, 0.0]
# (2020, 1, 2, 12, 1, 4.999647438526154)
# Phenomena of satellite 2
# [0.7571035888413832, 0.9706176189888323, 0.0]
# (2020, 1, 2, 12, 1, 4.999647438526154)
# Phenomena of satellite 2
# [0.7571035888413832, 0.9706176189888323, 0.0]
# (2020, 1, 2, 12, 1, 5.999642014503479)
# Phenomena of satellite 2
# [0.7571952787357058, 0.9707354780834911, 0.0]
# (2020, 1, 2, 12, 1, 5.999642014503479)
# Phenomena of satellite 2
# [0.7571952787357058, 0.9707354780834911, 0.0]
# (2020, 1, 2, 12, 1, 6.999636590480804)
# Phenomena of satellite 2
# [0.7572869877405546, 0.9708533465529573, 0.0]
# (2020, 1, 2, 12, 1, 6.999636590480804)
# Phenomena of satellite 2
# [0.7572869877405546, 0.9708533465529573, 0.0]
# (2020, 1, 2, 12, 1, 7.99963116645813)
# Phenomena of satellite 2
# [0.7573787158983019, 0.970971224372538, 0.0]
# (2020, 1, 2, 12, 1, 7.99963116645813)
# Phenomena of satellite 2
# [0.7573787158983019, 0.970971224372538, 0.0]
# (2020, 1, 2, 12, 1, 8.999625742435455)
# Phenomena of satellite 2
# [0.7574704631525706, 0.9710891114546103, 0.0]
# (2020, 1, 2, 12, 1, 8.999625742435455)
# Phenomena of satellite 2
# [0.7574704631525706, 0.9710891114546103, 0.0]
# (2020, 1, 2, 12, 1, 9.99962031841278)
# Phenomena of satellite 2
# [0.757562229589703, 0.9712070079012388, 0.0]
# (2020, 1, 2, 12, 1, 9.99962031841278)
# Phenomena of satellite 2
# [0.757562229589703, 0.9712070079012388, 0.0]
# (2020, 1, 2, 12, 1, 10.999614894390106)
# Phenomena of satellite 2
# [0.7576540151311056, 0.971324913666711, 0.0]
# (2020, 1, 2, 12, 1, 10.999614894390106)
# Phenomena of satellite 2
# [0.7576540151311056, 0.971324913666711, 0.0]
# (2020, 1, 2, 12, 1, 11.999609470367432)
# Phenomena of satellite 2
# [0.7577458197646306, 0.9714428287474702, 0.0]
# (2020, 1, 2, 12, 1, 11.999609470367432)
# Phenomena of satellite 2
# [0.7577458197646306, 0.9714428287474702, 0.0]
# (2020, 1, 2, 12, 1, 12.999604046344757)
# Phenomena of satellite 2
# [0.7578376435489124, 0.9715607531613317, 0.0]
# (2020, 1, 2, 12, 1, 12.999604046344757)
# Phenomena of satellite 2
# [0.7578376435489124, 0.9715607531613317, 0.0]
# (2020, 1, 2, 12, 1, 13.999598622322083)
# Phenomena of satellite 2
# [0.757929486372772, 0.9716786868626347, 0.0]
# (2020, 1, 2, 12, 1, 13.999598622322083)
# Phenomena of satellite 2
# [0.757929486372772, 0.9716786868626347, 0.0]
# (2020, 1, 2, 12, 1, 14.999593198299408)
# Phenomena of satellite 2
# [0.758021348306092, 0.9717966299110159, 0.0]
# (2020, 1, 2, 12, 1, 14.999593198299408)
# Phenomena of satellite 2
# [0.758021348306092, 0.9717966299110159, 0.0]
# (2020, 1, 2, 12, 1, 15.999587774276733)
# Phenomena of satellite 2
# [0.7581132293363688, 0.9719145822400231, 0.0]
# (2020, 1, 2, 12, 1, 15.999587774276733)
# Phenomena of satellite 2
# [0.7581132293363688, 0.9719145822400231, 0.0]
# (2020, 1, 2, 12, 1, 16.99958235025406)
# Phenomena of satellite 2
# [0.7582051294402958, 0.9720325438462681, 0.0]
# (2020, 1, 2, 12, 1, 16.99958235025406)
# Phenomena of satellite 2
# [0.7582051294402958, 0.9720325438462681, 0.0]
# (2020, 1, 2, 12, 1, 17.999576926231384)
# Phenomena of satellite 2
# [0.7582970486053552, 0.9721505148103902, 0.0]
# (2020, 1, 2, 12, 1, 17.999576926231384)
# Phenomena of satellite 2
# [0.7582970486053552, 0.9721505148103902, 0.0]
# (2020, 1, 2, 12, 1, 18.99957150220871)
# Phenomena of satellite 2
# [0.7583889868519117, 0.972268495015754, 0.0]
# (2020, 1, 2, 12, 1, 18.99957150220871)
# Phenomena of satellite 2
# [0.7583889868519117, 0.972268495015754, 0.0]
# (2020, 1, 2, 12, 1, 19.999566078186035)
# Phenomena of satellite 2
# [0.7584809441345242, 0.9723864845590426, 0.0]
# (2020, 1, 2, 12, 1, 19.999566078186035)
# Phenomena of satellite 2
# [0.7584809441345242, 0.9723864845590426, 0.0]
# (2020, 1, 2, 12, 1, 20.99956065416336)
# Phenomena of satellite 2
# [0.7585729204628818, 0.9725044833657753, 0.0]
# (2020, 1, 2, 12, 1, 20.99956065416336)
# Phenomena of satellite 2
# [0.7585729204628818, 0.9725044833657753, 0.0]
# (2020, 1, 2, 12, 1, 21.999555230140686)
# Phenomena of satellite 2
# [0.7586649158409743, 0.9726224914534876, 0.0]
# (2020, 1, 2, 12, 1, 21.999555230140686)
# Phenomena of satellite 2
# [0.7586649158409743, 0.9726224914534876, 0.0]
# (2020, 1, 2, 12, 1, 22.99954980611801)
# Phenomena of satellite 2
# [0.758756930272593, 0.9727405088609781, 0.0]
# (2020, 1, 2, 12, 1, 22.99954980611801)
# Phenomena of satellite 2
# [0.758756930272593, 0.9727405088609781, 0.0]
# (2020, 1, 2, 12, 1, 23.999544382095337)
# Phenomena of satellite 2
# [0.7588489637126976, 0.9728585354582254, 0.0]
# (2020, 1, 2, 12, 1, 23.999544382095337)
# Phenomena of satellite 2
# [0.7588489637126976, 0.9728585354582254, 0.0]
# (2020, 1, 2, 12, 1, 24.999538958072662)
# Phenomena of satellite 2
# [0.7589410161704376, 0.9729765714318254, 0.0]
# (2020, 1, 2, 12, 1, 24.999538958072662)
# Phenomena of satellite 2
# [0.7589410161704376, 0.9729765714318254, 0.0]
# (2020, 1, 2, 12, 1, 25.999533534049988)
# Phenomena of satellite 2
# [0.7590330876721431, 0.973094616651724, 0.0]
# (2020, 1, 2, 12, 1, 25.999533534049988)
# Phenomena of satellite 2
# [0.7590330876721431, 0.973094616651724, 0.0]
# (2020, 1, 2, 12, 1, 26.999528110027313)
# Phenomena of satellite 2
# [0.7591251781392201, 0.973212671093051, 0.0]
# (2020, 1, 2, 12, 1, 26.999528110027313)
# Phenomena of satellite 2
# [0.7591251781392201, 0.973212671093051, 0.0]
# (2020, 1, 2, 12, 1, 27.99952268600464)
# Phenomena of satellite 2
# [0.7592172876582834, 0.9733307348794489, 0.0]
# (2020, 1, 2, 12, 1, 27.99952268600464)
# Phenomena of satellite 2
# [0.7592172876582834, 0.9733307348794489, 0.0]
# (2020, 1, 2, 12, 1, 28.999517261981964)
# Phenomena of satellite 2
# [0.7593094161341927, 0.9734488078595739, 0.0]
# (2020, 1, 2, 12, 1, 28.999517261981964)
# Phenomena of satellite 2
# [0.7593094161341927, 0.9734488078595739, 0.0]
# (2020, 1, 2, 12, 1, 29.99951183795929)
# Phenomena of satellite 2
# [0.7594015635931702, 0.9735668900931563, 0.0]
# (2020, 1, 2, 12, 1, 29.99951183795929)
# Phenomena of satellite 2
# [0.7594015635931702, 0.9735668900931563, 0.0]
# (2020, 1, 2, 12, 1, 30.999506413936615)
# Phenomena of satellite 2
# [0.7594937300392892, 0.9736849816193992, 0.0]
# (2020, 1, 2, 12, 1, 30.999506413936615)
# Phenomena of satellite 2
# [0.7594937300392892, 0.9736849816193992, 0.0]
# (2020, 1, 2, 12, 1, 31.99950098991394)
# Phenomena of satellite 2
# [0.7595859154764962, 0.973803082392432, 0.0]
# (2020, 1, 2, 12, 1, 31.99950098991394)
# Phenomena of satellite 2
# [0.7595859154764962, 0.973803082392432, 0.0]
# (2020, 1, 2, 12, 1, 32.999495565891266)
# Phenomena of satellite 2
# [0.7596781198759324, 0.9739211924510187, 0.0]
# (2020, 1, 2, 12, 1, 32.999495565891266)
# Phenomena of satellite 2
# [0.7596781198759324, 0.9739211924510187, 0.0]
# (2020, 1, 2, 12, 1, 33.99949014186859)
# Phenomena of satellite 2
# [0.7597703431975728, 0.9740393116861441, 0.0]
# (2020, 1, 2, 12, 1, 33.99949014186859)
# Phenomena of satellite 2
# [0.7597703431975728, 0.9740393116861441, 0.0]
# (2020, 1, 2, 12, 1, 34.99948471784592)
# Phenomena of satellite 2
# [0.7598625854951226, 0.9741574402002483, 0.0]
# (2020, 1, 2, 12, 1, 34.99948471784592)
# Phenomena of satellite 2
# [0.7598625854951226, 0.9741574402002483, 0.0]
# (2020, 1, 2, 12, 1, 35.99947929382324)
# Phenomena of satellite 2
# [0.7599548467559724, 0.9742755779050584, 0.0]
# (2020, 1, 2, 12, 1, 35.99947929382324)
# Phenomena of satellite 2
# [0.7599548467559724, 0.9742755779050584, 0.0]
# (2020, 1, 2, 12, 1, 36.99947386980057)
# Phenomena of satellite 2
# [0.7600471269347411, 0.9743937248821655, 0.0]
# (2020, 1, 2, 12, 1, 36.99947386980057)
# Phenomena of satellite 2
# [0.7600471269347411, 0.9743937248821655, 0.0]
# (2020, 1, 2, 12, 1, 37.99946844577789)
# Phenomena of satellite 2
# [0.7601394260575843, 0.974511881098396, 0.0]
# (2020, 1, 2, 12, 1, 37.99946844577789)
# Phenomena of satellite 2
# [0.7601394260575843, 0.974511881098396, 0.0]
# (2020, 1, 2, 12, 1, 38.99946302175522)
# Phenomena of satellite 2
# [0.7602317440789633, 0.9746300465035811, 0.0]
# (2020, 1, 2, 12, 1, 38.99946302175522)
# Phenomena of satellite 2
# [0.7602317440789633, 0.9746300465035811, 0.0]
# (2020, 1, 2, 12, 1, 39.999457597732544)
# Phenomena of satellite 2
# [0.7603240810358501, 0.9747482211704627, 0.0]
# (2020, 1, 2, 12, 1, 39.999457597732544)
# Phenomena of satellite 2
# [0.7603240810358501, 0.9747482211704627, 0.0]
# (2020, 1, 2, 12, 1, 40.99945217370987)
# Phenomena of satellite 2
# [0.7604164369161232, 0.974866405074513, 0.0]
# (2020, 1, 2, 12, 1, 40.99945217370987)
# Phenomena of satellite 2
# [0.7604164369161232, 0.974866405074513, 0.0]
# (2020, 1, 2, 12, 1, 41.999446749687195)
# Phenomena of satellite 2
# [0.7605088116630105, 0.9749845981491185, 0.0]
# (2020, 1, 2, 12, 1, 41.999446749687195)
# Phenomena of satellite 2
# [0.7605088116630105, 0.9749845981491185, 0.0]
# (2020, 1, 2, 12, 1, 42.99944132566452)
# Phenomena of satellite 2
# [0.7606012053468818, 0.9751028004541338, 0.0]
# (2020, 1, 2, 12, 1, 42.99944132566452)
# Phenomena of satellite 2
# [0.7606012053468818, 0.9751028004541338, 0.0]
# (2020, 1, 2, 12, 1, 43.999435901641846)
# Phenomena of satellite 2
# [0.7606936178892516, 0.9752210119650302, 0.0]
# (2020, 1, 2, 12, 1, 43.999435901641846)
# Phenomena of satellite 2
# [0.7606936178892516, 0.9752210119650302, 0.0]
# (2020, 1, 2, 12, 1, 44.99943047761917)
# Phenomena of satellite 2
# [0.7607860493434635, 0.9753392326997687, 0.0]
# (2020, 1, 2, 12, 1, 44.99943047761917)
# Phenomena of satellite 2
# [0.7607860493434635, 0.9753392326997687, 0.0]
# (2020, 1, 2, 12, 1, 45.9994250535965)
# Phenomena of satellite 2
# [0.7608784996532963, 0.9754574626333709, 0.0]
# (2020, 1, 2, 12, 1, 45.9994250535965)
# Phenomena of satellite 2
# [0.7608784996532963, 0.9754574626333709, 0.0]
# (2020, 1, 2, 12, 1, 46.99941962957382)
# Phenomena of satellite 2
# [0.7609709688282127, 0.9755757018052001, 0.0]
# (2020, 1, 2, 12, 1, 46.99941962957382)
# Phenomena of satellite 2
# [0.7609709688282127, 0.9755757018052001, 0.0]
# (2020, 1, 2, 12, 1, 47.99941420555115)
# Phenomena of satellite 2
# [0.7610634568725327, 0.9756939501058606, 0.0]
# (2020, 1, 2, 12, 1, 47.99941420555115)
# Phenomena of satellite 2
# [0.7610634568725327, 0.9756939501058606, 0.0]
# (2020, 1, 2, 12, 1, 48.99940878152847)
# Phenomena of satellite 2
# [0.7611559637737972, 0.9758122075954644, 0.0]
# (2020, 1, 2, 12, 1, 48.99940878152847)
# Phenomena of satellite 2
# [0.7611559637737972, 0.9758122075954644, 0.0]
# (2020, 1, 2, 12, 1, 49.9994033575058)
# Phenomena of satellite 2
# [0.7612484895525747, 0.9759304743129374, 0.0]
# (2020, 1, 2, 12, 1, 49.9994033575058)
# Phenomena of satellite 2
# [0.7612484895525747, 0.9759304743129374, 0.0]
# (2020, 1, 2, 12, 1, 50.999397933483124)
# Phenomena of satellite 2
# [0.7613410341189945, 0.9760487502336751, 0.0]
# (2020, 1, 2, 12, 1, 50.999397933483124)
# Phenomena of satellite 2
# [0.7613410341189945, 0.9760487502336751, 0.0]
# (2020, 1, 2, 12, 1, 51.99939250946045)
# Phenomena of satellite 2
# [0.7614335975436723, 0.9761670353120162, 0.0]
# (2020, 1, 2, 12, 1, 51.99939250946045)
# Phenomena of satellite 2
# [0.7614335975436723, 0.9761670353120162, 0.0]
# (2020, 1, 2, 12, 1, 52.999387085437775)
# Phenomena of satellite 2
# [0.7615261798141743, 0.9762853295870257, 0.0]
# (2020, 1, 2, 12, 1, 52.999387085437775)
# Phenomena of satellite 2
# [0.7615261798141743, 0.9762853295870257, 0.0]
# (2020, 1, 2, 12, 1, 53.9993816614151)
# Phenomena of satellite 2
# [0.7616187808683301, 0.9764036330127887, 0.0]
# (2020, 1, 2, 12, 1, 53.9993816614151)
# Phenomena of satellite 2
# [0.7616187808683301, 0.9764036330127887, 0.0]
# (2020, 1, 2, 12, 1, 54.999376237392426)
# Phenomena of satellite 2
# [0.7617114007489045, 0.9765219456282963, 0.0]
# (2020, 1, 2, 12, 1, 54.999376237392426)
# Phenomena of satellite 2
# [0.7617114007489045, 0.9765219456282963, 0.0]
# (2020, 1, 2, 12, 1, 55.99937081336975)
# Phenomena of satellite 2
# [0.7618040394436609, 0.9766402674090943, 0.0]
# (2020, 1, 2, 12, 1, 55.99937081336975)
# Phenomena of satellite 2
# [0.7618040394436609, 0.9766402674090943, 0.0]
# (2020, 1, 2, 12, 1, 56.999365389347076)
# Phenomena of satellite 2
# [0.761896696923221, 0.9767585983648429, 0.0]
# (2020, 1, 2, 12, 1, 56.999365389347076)
# Phenomena of satellite 2
# [0.761896696923221, 0.9767585983648429, 0.0]
# (2020, 1, 2, 12, 1, 57.9993599653244)
# Phenomena of satellite 2
# [0.7619893732587073, 0.9768769384447382, 0.0]
# (2020, 1, 2, 12, 1, 57.9993599653244)
# Phenomena of satellite 2
# [0.7619893732587073, 0.9768769384447382, 0.0]
# (2020, 1, 2, 12, 1, 58.99935454130173)
# Phenomena of satellite 2
# [0.7620820682931119, 0.9769952877222001, 0.0]
# (2020, 1, 2, 12, 1, 58.99935454130173)
# Phenomena of satellite 2
# [0.7620820682931119, 0.9769952877222001, 0.0]
# (2020, 1, 2, 12, 1, 59.99934911727905)
# Phenomena of satellite 2
# [0.762174782147396, 0.9771136461511953, 0.0]
# (2020, 1, 2, 12, 1, 59.99934911727905)
# Phenomena of satellite 2
# [0.762174782147396, 0.9771136461511953, 0.0]
# (2020, 1, 2, 12, 2, 0.9993436932563782)
# Phenomena of satellite 2
# [0.7622675147423792, 0.9772320137497686, 0.0]
# (2020, 1, 2, 12, 2, 0.9993436932563782)
# Phenomena of satellite 2
# [0.7622675147423792, 0.9772320137497686, 0.0]
# (2020, 1, 2, 12, 2, 1.9993382692337036)
# Phenomena of satellite 2
# [0.762360266149054, 0.9773503904721068, 0.0]
# (2020, 1, 2, 12, 2, 1.9993382692337036)
# Phenomena of satellite 2
# [0.762360266149054, 0.9773503904721068, 0.0]
# (2020, 1, 2, 12, 2, 2.999332845211029)
# Phenomena of satellite 2
# [0.7624530363102654, 0.9774687763573624, 0.0]
# (2020, 1, 2, 12, 2, 2.999332845211029)
# Phenomena of satellite 2
# [0.7624530363102654, 0.9774687763573624, 0.0]
# (2020, 1, 2, 12, 2, 3.9993274211883545)
# Phenomena of satellite 2
# [0.7625458251859314, 0.9775871713596163, 0.0]
# (2020, 1, 2, 12, 2, 3.9993274211883545)
# Phenomena of satellite 2
# [0.7625458251859314, 0.9775871713596163, 0.0]
# (2020, 1, 2, 12, 2, 4.99932199716568)
# Phenomena of satellite 2
# [0.7626386328472352, 0.9777055755390437, 0.0]
# (2020, 1, 2, 12, 2, 4.99932199716568)
# Phenomena of satellite 2
# [0.7626386328472352, 0.9777055755390437, 0.0]
# (2020, 1, 2, 12, 2, 5.999316573143005)
# Phenomena of satellite 2
# [0.7627314592147049, 0.9778239888076099, 0.0]
# (2020, 1, 2, 12, 2, 5.999316573143005)
# Phenomena of satellite 2
# [0.7627314592147049, 0.9778239888076099, 0.0]
# (2020, 1, 2, 12, 2, 6.999311149120331)
# Phenomena of satellite 2
# [0.7628243043093128, 0.9779424112677791, 0.0]
# (2020, 1, 2, 12, 2, 6.999311149120331)
# Phenomena of satellite 2
# [0.7628243043093128, 0.9779424112677791, 0.0]
# (2020, 1, 2, 12, 2, 7.999305725097656)
# Phenomena of satellite 2
# [0.7629171681743373, 0.9780608428315946, 0.0]
# (2020, 1, 2, 12, 2, 7.999305725097656)
# Phenomena of satellite 2
# [0.7629171681743373, 0.9780608428315946, 0.0]
# (2020, 1, 2, 12, 2, 8.999300301074982)
# Phenomena of satellite 2
# [0.7630100506973082, 0.9781792834743852, 0.0]
# (2020, 1, 2, 12, 2, 8.999300301074982)
# Phenomena of satellite 2
# [0.7630100506973082, 0.9781792834743852, 0.0]
# (2020, 1, 2, 12, 2, 9.999294877052307)
# Phenomena of satellite 2
# [0.763102951982397, 0.9782977332987257, 0.0]
# (2020, 1, 2, 12, 2, 9.999294877052307)
# Phenomena of satellite 2
# [0.763102951982397, 0.9782977332987257, 0.0]
# (2020, 1, 2, 12, 2, 10.999289453029633)
# Phenomena of satellite 2
# [0.7631958719504627, 0.9784161921953325, 0.0]
# (2020, 1, 2, 12, 2, 10.999289453029633)
# Phenomena of satellite 2
# [0.7631958719504627, 0.9784161921953325, 0.0]
# (2020, 1, 2, 12, 2, 11.999284029006958)
# Phenomena of satellite 2
# [0.7632888105945267, 0.9785346602880032, 0.0]
# (2020, 1, 2, 12, 2, 11.999284029006958)
# Phenomena of satellite 2
# [0.7632888105945267, 0.9785346602880032, 0.0]
# (2020, 1, 2, 12, 2, 12.999278604984283)
# Phenomena of satellite 2
# [0.7633817679692763, 0.978653137446328, 0.0]
# (2020, 1, 2, 12, 2, 12.999278604984283)
# Phenomena of satellite 2
# [0.7633817679692763, 0.978653137446328, 0.0]
# (2020, 1, 2, 12, 2, 13.999273180961609)
# Phenomena of satellite 2
# [0.7634747439619242, 0.9787716236456121, 0.0]
# (2020, 1, 2, 12, 2, 13.999273180961609)
# Phenomena of satellite 2
# [0.7634747439619242, 0.9787716236456121, 0.0]
# (2020, 1, 2, 12, 2, 14.999267756938934)
# Phenomena of satellite 2
# [0.7635677387101908, 0.9788901190520144, 0.0]
# (2020, 1, 2, 12, 2, 14.999267756938934)
# Phenomena of satellite 2
# [0.7635677387101908, 0.9788901190520144, 0.0]
# (2020, 1, 2, 12, 2, 15.99926233291626)
# Phenomena of satellite 2
# [0.7636607520736869, 0.9790086235058942, 0.0]
# (2020, 1, 2, 12, 2, 15.99926233291626)
# Phenomena of satellite 2
# [0.7636607520736869, 0.9790086235058942, 0.0]
# (2020, 1, 2, 12, 2, 16.999256908893585)
# Phenomena of satellite 2
# [0.7637537841237098, 0.9791271371048063, 0.0]
# (2020, 1, 2, 12, 2, 16.999256908893585)
# Phenomena of satellite 2
# [0.7637537841237098, 0.9791271371048063, 0.0]
# (2020, 1, 2, 12, 2, 17.99925148487091)
# Phenomena of satellite 2
# [0.7638468348475383, 0.9792456597735724, 0.0]
# (2020, 1, 2, 12, 2, 17.99925148487091)
# Phenomena of satellite 2
# [0.7638468348475383, 0.9792456597735724, 0.0]
# (2020, 1, 2, 12, 2, 18.999246060848236)
# Phenomena of satellite 2
# [0.7639399041659705, 0.9793641915301261, 0.0]
# (2020, 1, 2, 12, 2, 18.999246060848236)
# Phenomena of satellite 2
# [0.7639399041659705, 0.9793641915301261, 0.0]
# (2020, 1, 2, 12, 2, 19.99924063682556)
# Phenomena of satellite 2
# [0.7640329921559252, 0.9794827323924112, 0.0]
# (2020, 1, 2, 12, 2, 19.99924063682556)
# Phenomena of satellite 2
# [0.7640329921559252, 0.9794827323924112, 0.0]
# (2020, 1, 2, 12, 2, 20.999235212802887)
# Phenomena of satellite 2
# [0.7641260987714794, 0.9796012823146374, 0.0]
# (2020, 1, 2, 12, 2, 20.999235212802887)
# Phenomena of satellite 2
# [0.7641260987714794, 0.9796012823146374, 0.0]
# (2020, 1, 2, 12, 2, 21.999229788780212)
# Phenomena of satellite 2
# [0.7642192240501323, 0.9797198413568589, 0.0]
# (2020, 1, 2, 12, 2, 21.999229788780212)
# Phenomena of satellite 2
# [0.7642192240501323, 0.9797198413568589, 0.0]
# (2020, 1, 2, 12, 2, 22.999224364757538)
# Phenomena of satellite 2
# [0.764312367912747, 0.9798384094101137, 0.0]
# (2020, 1, 2, 12, 2, 22.999224364757538)
# Phenomena of satellite 2
# [0.764312367912747, 0.9798384094101137, 0.0]
# (2020, 1, 2, 12, 2, 23.999218940734863)
# Phenomena of satellite 2
# [0.7644055304025763, 0.9799569865767035, 0.0]
# (2020, 1, 2, 12, 2, 23.999218940734863)
# Phenomena of satellite 2
# [0.7644055304025763, 0.9799569865767035, 0.0]
# (2020, 1, 2, 12, 2, 24.99921351671219)
# Phenomena of satellite 2
# [0.7644987114794902, 0.9800755728323336, 0.0]
# (2020, 1, 2, 12, 2, 24.99921351671219)
# Phenomena of satellite 2
# [0.7644987114794902, 0.9800755728323336, 0.0]
# (2020, 1, 2, 12, 2, 25.999208092689514)
# Phenomena of satellite 2
# [0.7645919111812416, 0.9801941681734733, 0.0]
# (2020, 1, 2, 12, 2, 25.999208092689514)
# Phenomena of satellite 2
# [0.7645919111812416, 0.9801941681734733, 0.0]
# (2020, 1, 2, 12, 2, 26.99920266866684)
# Phenomena of satellite 2
# [0.7646851294952021, 0.980312772554471, 0.0]
# (2020, 1, 2, 12, 2, 26.99920266866684)
# Phenomena of satellite 2
# [0.7646851294952021, 0.980312772554471, 0.0]
# (2020, 1, 2, 12, 2, 27.999197244644165)
# Phenomena of satellite 2
# [0.7647783663588333, 0.9804313859930721, 0.0]
# (2020, 1, 2, 12, 2, 27.999197244644165)
# Phenomena of satellite 2
# [0.7647783663588333, 0.9804313859930721, 0.0]
# (2020, 1, 2, 12, 2, 28.99919182062149)
# Phenomena of satellite 2
# [0.7648716217988484, 0.9805500084862466, 0.0]
# (2020, 1, 2, 12, 2, 28.99919182062149)
# Phenomena of satellite 2
# [0.7648716217988484, 0.9805500084862466, 0.0]
# (2020, 1, 2, 12, 2, 29.999186396598816)
# Phenomena of satellite 2
# [0.7649648958196524, 0.9806686400514774, 0.0]
# (2020, 1, 2, 12, 2, 29.999186396598816)
# Phenomena of satellite 2
# [0.7649648958196524, 0.9806686400514774, 0.0]
# (2020, 1, 2, 12, 2, 30.99918097257614)
# Phenomena of satellite 2
# [0.7650581884253509, 0.9807872806432794, 0.0]
# (2020, 1, 2, 12, 2, 30.99918097257614)
# Phenomena of satellite 2
# [0.7650581884253509, 0.9807872806432794, 0.0]
# (2020, 1, 2, 12, 2, 31.999175548553467)
# Phenomena of satellite 2
# [0.7651514995869638, 0.9809059303217821, 0.0]
# (2020, 1, 2, 12, 2, 31.999175548553467)
# Phenomena of satellite 2
# [0.7651514995869638, 0.9809059303217821, 0.0]
# (2020, 1, 2, 12, 2, 32.99917012453079)
# Phenomena of satellite 2
# [0.7652448292808699, 0.9810245890202187, 0.0]
# (2020, 1, 2, 12, 2, 32.99917012453079)
# Phenomena of satellite 2
# [0.7652448292808699, 0.9810245890202187, 0.0]
# (2020, 1, 2, 12, 2, 33.99916470050812)
# Phenomena of satellite 2
# [0.7653381775113973, 0.9811432567775564, 0.0]
# (2020, 1, 2, 12, 2, 33.99916470050812)
# Phenomena of satellite 2
# [0.7653381775113973, 0.9811432567775564, 0.0]
# (2020, 1, 2, 12, 2, 34.99915927648544)
# Phenomena of satellite 2
# [0.7654315443162747, 0.9812619335398872, 0.0]
# (2020, 1, 2, 12, 2, 34.99915927648544)
# Phenomena of satellite 2
# [0.7654315443162747, 0.9812619335398872, 0.0]
# (2020, 1, 2, 12, 2, 35.99915385246277)
# Phenomena of satellite 2
# [0.7655249296497847, 0.9813806193413892, 0.0]
# (2020, 1, 2, 12, 2, 35.99915385246277)
# Phenomena of satellite 2
# [0.7655249296497847, 0.9813806193413892, 0.0]
# (2020, 1, 2, 12, 2, 36.999148428440094)
# Phenomena of satellite 2
# [0.7656183335050045, 0.9814993142131059, 0.0]
# (2020, 1, 2, 12, 2, 36.999148428440094)
# Phenomena of satellite 2
# [0.7656183335050045, 0.9814993142131059, 0.0]
# (2020, 1, 2, 12, 2, 37.99914300441742)
# Phenomena of satellite 2
# [0.7657117558697977, 0.981618018109201, 0.0]
# (2020, 1, 2, 12, 2, 37.99914300441742)
# Phenomena of satellite 2
# [0.7657117558697977, 0.981618018109201, 0.0]
# (2020, 1, 2, 12, 2, 38.999137580394745)
# Phenomena of satellite 2
# [0.7658051967314198, 0.9817367310263907, 0.0]
# (2020, 1, 2, 12, 2, 38.999137580394745)
# Phenomena of satellite 2
# [0.7658051967314198, 0.9817367310263907, 0.0]
# (2020, 1, 2, 12, 2, 39.99913215637207)
# Phenomena of satellite 2
# [0.765898656144447, 0.9818554529187945, 0.0]
# (2020, 1, 2, 12, 2, 39.99913215637207)
# Phenomena of satellite 2
# [0.765898656144447, 0.9818554529187945, 0.0]
# (2020, 1, 2, 12, 2, 40.999126732349396)
# Phenomena of satellite 2
# [0.7659921340184858, 0.9819741838892192, 0.0]
# (2020, 1, 2, 12, 2, 40.999126732349396)
# Phenomena of satellite 2
# [0.7659921340184858, 0.9819741838892192, 0.0]
# (2020, 1, 2, 12, 2, 41.99912130832672)
# Phenomena of satellite 2
# [0.7660856303970626, 0.9820929238497932, 0.0]
# (2020, 1, 2, 12, 2, 41.99912130832672)
# Phenomena of satellite 2
# [0.7660856303970626, 0.9820929238497932, 0.0]
# (2020, 1, 2, 12, 2, 42.99911588430405)
# Phenomena of satellite 2
# [0.7661791452508614, 0.9822116728604132, 0.0]
# (2020, 1, 2, 12, 2, 42.99911588430405)
# Phenomena of satellite 2
# [0.7661791452508614, 0.9822116728604132, 0.0]
# (2020, 1, 2, 12, 2, 43.99911046028137)
# Phenomena of satellite 2
# [0.7662726785841549, 0.9823304308543925, 0.0]
# (2020, 1, 2, 12, 2, 43.99911046028137)
# Phenomena of satellite 2
# [0.7662726785841549, 0.9823304308543925, 0.0]
# (2020, 1, 2, 12, 2, 44.9991050362587)
# Phenomena of satellite 2
# [0.766366230384779, 0.982449197849378, 0.0]
# (2020, 1, 2, 12, 2, 44.9991050362587)
# Phenomena of satellite 2
# [0.766366230384779, 0.982449197849378, 0.0]
# (2020, 1, 2, 12, 2, 45.99909961223602)
# Phenomena of satellite 2
# [0.7664598006627368, 0.9825679738210481, 0.0]
# (2020, 1, 2, 12, 2, 45.99909961223602)
# Phenomena of satellite 2
# [0.7664598006627368, 0.9825679738210481, 0.0]
# (2020, 1, 2, 12, 2, 46.99909418821335)
# Phenomena of satellite 2
# [0.7665533893886421, 0.9826867588297421, 0.0]
# (2020, 1, 2, 12, 2, 46.99909418821335)
# Phenomena of satellite 2
# [0.7665533893886421, 0.9826867588297421, 0.0]
# (2020, 1, 2, 12, 2, 47.999088764190674)
# Phenomena of satellite 2
# [0.766646996583819, 0.9828055528083113, 0.0]
# (2020, 1, 2, 12, 2, 47.999088764190674)
# Phenomena of satellite 2
# [0.766646996583819, 0.9828055528083113, 0.0]
# (2020, 1, 2, 12, 2, 48.999083340168)
# Phenomena of satellite 2
# [0.7667406222022374, 0.9829243558171912, 0.0]
# (2020, 1, 2, 12, 2, 48.999083340168)
# Phenomena of satellite 2
# [0.7667406222022374, 0.9829243558171912, 0.0]
# (2020, 1, 2, 12, 2, 49.999077916145325)
# Phenomena of satellite 2
# [0.7668342662538427, 0.9830431677470549, 0.0]
# (2020, 1, 2, 12, 2, 49.999077916145325)
# Phenomena of satellite 2
# [0.7668342662538427, 0.9830431677470549, 0.0]
# (2020, 1, 2, 12, 2, 50.99907249212265)
# Phenomena of satellite 2
# [0.766927928743182, 0.9831619887218613, 0.0]
# (2020, 1, 2, 12, 2, 50.99907249212265)
# Phenomena of satellite 2
# [0.766927928743182, 0.9831619887218613, 0.0]
# (2020, 1, 2, 12, 2, 51.999067068099976)
# Phenomena of satellite 2
# [0.767021609674657, 0.9832808186960669, 0.0]
# (2020, 1, 2, 12, 2, 51.999067068099976)
# Phenomena of satellite 2
# [0.767021609674657, 0.9832808186960669, 0.0]
# (2020, 1, 2, 12, 2, 52.9990616440773)
# Phenomena of satellite 2
# [0.7671153090189354, 0.9833996575810197, 0.0]
# (2020, 1, 2, 12, 2, 52.9990616440773)
# Phenomena of satellite 2
# [0.7671153090189354, 0.9833996575810197, 0.0]
# (2020, 1, 2, 12, 2, 53.99905622005463)
# Phenomena of satellite 2
# [0.7672090267357162, 0.9835185055009468, 0.0]
# (2020, 1, 2, 12, 2, 53.99905622005463)
# Phenomena of satellite 2
# [0.7672090267357162, 0.9835185055009468, 0.0]
# (2020, 1, 2, 12, 2, 54.99905079603195)
# Phenomena of satellite 2
# [0.7673027628798916, 0.9836373623385589, 0.0]
# (2020, 1, 2, 12, 2, 54.99905079603195)
# Phenomena of satellite 2
# [0.7673027628798916, 0.9836373623385589, 0.0]
# (2020, 1, 2, 12, 2, 55.99904537200928)
# Phenomena of satellite 2
# [0.7673965174053463, 0.9837562281702541, 0.0]
# (2020, 1, 2, 12, 2, 55.99904537200928)
# Phenomena of satellite 2
# [0.7673965174053463, 0.9837562281702541, 0.0]
# (2020, 1, 2, 12, 2, 56.9990399479866)
# Phenomena of satellite 2
# [0.7674902903669167, 0.9838751030059907, 0.0]
# (2020, 1, 2, 12, 2, 56.9990399479866)
# Phenomena of satellite 2
# [0.7674902903669167, 0.9838751030059907, 0.0]
# (2020, 1, 2, 12, 2, 57.99903452396393)
# Phenomena of satellite 2
# [0.7675840816738154, 0.9839939867997153, 0.0]
# (2020, 1, 2, 12, 2, 57.99903452396393)
# Phenomena of satellite 2
# [0.7675840816738154, 0.9839939867997153, 0.0]
# (2020, 1, 2, 12, 2, 58.999029099941254)
# Phenomena of satellite 2
# [0.7676778913698039, 0.9841128795270948, 0.0]
# (2020, 1, 2, 12, 2, 58.999029099941254)
# Phenomena of satellite 2
# [0.7676778913698039, 0.9841128795270948, 0.0]
# (2020, 1, 2, 12, 2, 59.99902367591858)
# Phenomena of satellite 2
# [0.7677717194088971, 0.9842317811635461, 0.0]
# (2020, 1, 2, 12, 2, 59.99902367591858)
# Phenomena of satellite 2
# [0.7677717194088971, 0.9842317811635461, 0.0]
# (2020, 1, 2, 12, 3, 0.9990182518959045)
# Phenomena of satellite 2
# [0.7678655658289162, 0.9843506918121518, 0.0]
# (2020, 1, 2, 12, 3, 0.9990182518959045)
# Phenomena of satellite 2
# [0.7678655658289162, 0.9843506918121518, 0.0]
# (2020, 1, 2, 12, 3, 1.99901282787323)
# Phenomena of satellite 2
# [0.7679594306177021, 0.9844696114056466, 0.0]
# (2020, 1, 2, 12, 3, 1.99901282787323)
# Phenomena of satellite 2
# [0.7679594306177021, 0.9844696114056466, 0.0]
# (2020, 1, 2, 12, 3, 2.9990074038505554)
# Phenomena of satellite 2
# [0.7680533137346858, 0.9845885399621649, 0.0]
# (2020, 1, 2, 12, 3, 2.9990074038505554)
# Phenomena of satellite 2
# [0.7680533137346858, 0.9845885399621649, 0.0]
# (2020, 1, 2, 12, 3, 3.999001979827881)
# Phenomena of satellite 2
# [0.7681472152182295, 0.9847074774569721, 0.0]
# (2020, 1, 2, 12, 3, 3.999001979827881)
# Phenomena of satellite 2
# [0.7681472152182295, 0.9847074774569721, 0.0]
# (2020, 1, 2, 12, 3, 4.998996555805206)
# Phenomena of satellite 2
# [0.7682411350052256, 0.9848264238443803, 0.0]
# (2020, 1, 2, 12, 3, 4.998996555805206)
# Phenomena of satellite 2
# [0.7682411350052256, 0.9848264238443803, 0.0]
# (2020, 1, 2, 12, 3, 5.998991131782532)
# Phenomena of satellite 2
# [0.7683350731169616, 0.9849453791848254, 0.0]
# (2020, 1, 2, 12, 3, 5.998991131782532)
# Phenomena of satellite 2
# [0.7683350731169616, 0.9849453791848254, 0.0]
# (2020, 1, 2, 12, 3, 6.998985707759857)
# Phenomena of satellite 2
# [0.7684290295634663, 0.9850643434752343, 0.0]
# (2020, 1, 2, 12, 3, 6.998985707759857)
# Phenomena of satellite 2
# [0.7684290295634663, 0.9850643434752343, 0.0]
# (2020, 1, 2, 12, 3, 7.998980283737183)
# Phenomena of satellite 2
# [0.7685230043496006, 0.9851833166907009, 0.0]
# (2020, 1, 2, 12, 3, 7.998980283737183)
# Phenomena of satellite 2
# [0.7685230043496006, 0.9851833166907009, 0.0]
# (2020, 1, 2, 12, 3, 8.998974859714508)
# Phenomena of satellite 2
# [0.7686169974625869, 0.9853022988707729, 0.0]
# (2020, 1, 2, 12, 3, 8.998974859714508)
# Phenomena of satellite 2
# [0.7686169974625869, 0.9853022988707729, 0.0]
# (2020, 1, 2, 12, 3, 9.998969435691833)
# Phenomena of satellite 2
# [0.7687110088060755, 0.9854212899056639, 0.0]
# (2020, 1, 2, 12, 3, 9.998969435691833)
# Phenomena of satellite 2
# [0.7687110088060755, 0.9854212899056639, 0.0]
# (2020, 1, 2, 12, 3, 10.998964011669159)
# Phenomena of satellite 2
# [0.7688050384573718, 0.9855402898985395, 0.0]
# (2020, 1, 2, 12, 3, 10.998964011669159)
# Phenomena of satellite 2
# [0.7688050384573718, 0.9855402898985395, 0.0]
# (2020, 1, 2, 12, 3, 11.998958587646484)
# Phenomena of satellite 2
# [0.7688990864210185, 0.985659298803506, 0.0]
# (2020, 1, 2, 12, 3, 11.998958587646484)
# Phenomena of satellite 2
# [0.7688990864210185, 0.985659298803506, 0.0]
# (2020, 1, 2, 12, 3, 12.99895316362381)
# Phenomena of satellite 2
# [0.7689931527016561, 0.985778316617291, 0.0]
# (2020, 1, 2, 12, 3, 12.99895316362381)
# Phenomena of satellite 2
# [0.7689931527016561, 0.985778316617291, 0.0]
# (2020, 1, 2, 12, 3, 13.998947739601135)
# Phenomena of satellite 2
# [0.7690872372191623, 0.9858973433712099, 0.0]
# (2020, 1, 2, 12, 3, 13.998947739601135)
# Phenomena of satellite 2
# [0.7690872372191623, 0.9858973433712099, 0.0]
# (2020, 1, 2, 12, 3, 14.99894231557846)
# Phenomena of satellite 2
# [0.7691813399838343, 0.986016378971617, 0.0]
# (2020, 1, 2, 12, 3, 14.99894231557846)
# Phenomena of satellite 2
# [0.7691813399838343, 0.986016378971617, 0.0]
# (2020, 1, 2, 12, 3, 15.998936891555786)
# Phenomena of satellite 2
# [0.7692754610003708, 0.9861354235135843, 0.0]
# (2020, 1, 2, 12, 3, 15.998936891555786)
# Phenomena of satellite 2
# [0.7692754610003708, 0.9861354235135843, 0.0]
# (2020, 1, 2, 12, 3, 16.99893146753311)
# Phenomena of satellite 2
# [0.7693696003235786, 0.9862544769725602, 0.0]
# (2020, 1, 2, 12, 3, 16.99893146753311)
# Phenomena of satellite 2
# [0.7693696003235786, 0.9862544769725602, 0.0]
# (2020, 1, 2, 12, 3, 17.998926043510437)
# Phenomena of satellite 2
# [0.7694637578737883, 0.9863735392814112, 0.0]
# (2020, 1, 2, 12, 3, 17.998926043510437)
# Phenomena of satellite 2
# [0.7694637578737883, 0.9863735392814112, 0.0]
# (2020, 1, 2, 12, 3, 18.998920619487762)
# Phenomena of satellite 2
# [0.769557933694821, 0.9864926105433588, 0.0]
# (2020, 1, 2, 12, 3, 18.998920619487762)
# Phenomena of satellite 2
# [0.769557933694821, 0.9864926105433588, 0.0]
# (2020, 1, 2, 12, 3, 19.998915195465088)
# Phenomena of satellite 2
# [0.7696521276955014, 0.9866116906273215, 0.0]
# (2020, 1, 2, 12, 3, 19.998915195465088)
# Phenomena of satellite 2
# [0.7696521276955014, 0.9866116906273215, 0.0]
# (2020, 1, 2, 12, 3, 20.998909771442413)
# Phenomena of satellite 2
# [0.7697463399141754, 0.9867307796364879, 0.0]
# (2020, 1, 2, 12, 3, 20.998909771442413)
# Phenomena of satellite 2
# [0.7697463399141754, 0.9867307796364879, 0.0]
# (2020, 1, 2, 12, 3, 21.99890434741974)
# Phenomena of satellite 2
# [0.7698405704061452, 0.9868498775677643, 0.0]
# (2020, 1, 2, 12, 3, 21.99890434741974)
# Phenomena of satellite 2
# [0.7698405704061452, 0.9868498775677643, 0.0]
# (2020, 1, 2, 12, 3, 22.998898923397064)
# Phenomena of satellite 2
# [0.7699348191080834, 0.9869689843112263, 0.0]
# (2020, 1, 2, 12, 3, 22.998898923397064)
# Phenomena of satellite 2
# [0.7699348191080834, 0.9869689843112263, 0.0]
# (2020, 1, 2, 12, 3, 23.99889349937439)
# Phenomena of satellite 2
# [0.7700290859966609, 0.9870881000126621, 0.0]
# (2020, 1, 2, 12, 3, 23.99889349937439)
# Phenomena of satellite 2
# [0.7700290859966609, 0.9870881000126621, 0.0]
# (2020, 1, 2, 12, 3, 24.998888075351715)
# Phenomena of satellite 2
# [0.7701233710763447, 0.9872072245199882, 0.0]
# (2020, 1, 2, 12, 3, 24.998888075351715)
# Phenomena of satellite 2
# [0.7701233710763447, 0.9872072245199882, 0.0]
# (2020, 1, 2, 12, 3, 25.99888265132904)
# Phenomena of satellite 2
# [0.7702176743345691, 0.9873263578934323, 0.0]
# (2020, 1, 2, 12, 3, 25.99888265132904)
# Phenomena of satellite 2
# [0.7702176743345691, 0.9873263578934323, 0.0]
# (2020, 1, 2, 12, 3, 26.998877227306366)
# Phenomena of satellite 2
# [0.7703119958268074, 0.987445500172725, 0.0]
# (2020, 1, 2, 12, 3, 26.998877227306366)
# Phenomena of satellite 2
# [0.7703119958268074, 0.987445500172725, 0.0]
# (2020, 1, 2, 12, 3, 27.99887180328369)
# Phenomena of satellite 2
# [0.7704063354787145, 0.9875646512904155, 0.0]
# (2020, 1, 2, 12, 3, 27.99887180328369)
# Phenomena of satellite 2
# [0.7704063354787145, 0.9875646512904155, 0.0]
# (2020, 1, 2, 12, 3, 28.998866379261017)
# Phenomena of satellite 2
# [0.7705006933286306, 0.9876838113072275, 0.0]
# (2020, 1, 2, 12, 3, 28.998866379261017)
# Phenomena of satellite 2
# [0.7705006933286306, 0.9876838113072275, 0.0]
# (2020, 1, 2, 12, 3, 29.998860955238342)
# Phenomena of satellite 2
# [0.770595069296665, 0.9878029801348915, 0.0]
# (2020, 1, 2, 12, 3, 29.998860955238342)
# Phenomena of satellite 2
# [0.770595069296665, 0.9878029801348915, 0.0]
# (2020, 1, 2, 12, 3, 30.998855531215668)
# Phenomena of satellite 2
# [0.7706894634548052, 0.9879221578552186, 0.0]
# (2020, 1, 2, 12, 3, 30.998855531215668)
# Phenomena of satellite 2
# [0.7706894634548052, 0.9879221578552186, 0.0]
# (2020, 1, 2, 12, 3, 31.998850107192993)
# Phenomena of satellite 2
# [0.7707838757456033, 0.9880413443795596, 0.0]
# (2020, 1, 2, 12, 3, 31.998850107192993)
# Phenomena of satellite 2
# [0.7707838757456033, 0.9880413443795596, 0.0]
# (2020, 1, 2, 12, 3, 32.99884468317032)
# Phenomena of satellite 2
# [0.7708783062077774, 0.9881605397821238, 0.0]
# (2020, 1, 2, 12, 3, 33.998839259147644)
# Phenomena of satellite 2
# [0.7709727548117428, 0.988279744054269, 0.0]
# (2020, 1, 2, 12, 3, 34.99883383512497)
# Phenomena of satellite 2
# [0.7710672215452484, 0.9883989571209185, 0.0]
# (2020, 1, 2, 12, 3, 35.998828411102295)
# Phenomena of satellite 2
# [0.7711617063676701, 0.9885181790640105, 0.0]
# (2020, 1, 2, 12, 3, 36.99882298707962)
# Phenomena of satellite 2
# [0.7712562093571533, 0.9886374098376298, 0.0]
# (2020, 1, 2, 12, 3, 37.998817563056946)
# Phenomena of satellite 2
# [0.7713507304335266, 0.9887566494171796, 0.0]
# (2020, 1, 2, 12, 3, 38.99881213903427)
# Phenomena of satellite 2
# [0.7714452696690351, 0.9888758978634808, 0.0]
# (2020, 1, 2, 12, 3, 39.9988067150116)
# Phenomena of satellite 2
# [0.7715398269328122, 0.9889951551093038, 0.0]
# (2020, 1, 2, 12, 3, 40.99880129098892)
# Phenomena of satellite 2
# [0.7716344023030357, 0.9891144211726842, 0.0]
# (2020, 1, 2, 12, 3, 41.99879586696625)
# Phenomena of satellite 2
# [0.7717289958011708, 0.9892336960503175, 0.0]
# (2020, 1, 2, 12, 3, 42.99879044294357)
# Phenomena of satellite 2
# [0.7718236073298508, 0.989352979760457, 0.0]
# (2020, 1, 2, 12, 3, 43.9987850189209)
# Phenomena of satellite 2
# ...
# (2020, 1, 2, 12, 58, 47.98086404800415)
# Phenomena of satellite 0
# [0.8147579631018065, 0.6217935803328248, 0.0]
# (2020, 1, 2, 12, 58, 47.98086404800415)
# Phenomena of satellite 0
# [0.8147579631018065, 0.6217935803328248, 0.0]
# (2020, 1, 2, 12, 58, 48.980858623981476)
# Phenomena of satellite 0
# [0.8145281466948927, 0.621570457501004, 0.0]
# (2020, 1, 2, 12, 58, 48.980858623981476)
# Phenomena of satellite 0
# [0.8145281466948927, 0.621570457501004, 0.0]
# (2020, 1, 2, 12, 58, 49.9808531999588)
# Phenomena of satellite 0
# [0.814298334566293, 0.6213473468872843, 0.0]
# (2020, 1, 2, 12, 58, 49.9808531999588)
# Phenomena of satellite 0
# [0.814298334566293, 0.6213473468872843, 0.0]
# (2020, 1, 2, 12, 58, 50.98084777593613)
# Phenomena of satellite 0
# [0.8140685267209498, 0.6211242483472824, 0.0]
# (2020, 1, 2, 12, 58, 50.98084777593613)
# Phenomena of satellite 0
# [0.8140685267209498, 0.6211242483472824, 0.0]
# (2020, 1, 2, 12, 58, 51.98084235191345)
# Phenomena of satellite 0
# [0.8138387232902722, 0.6209011620147659, 0.0]
# (2020, 1, 2, 12, 58, 51.98084235191345)
# Phenomena of satellite 0
# [0.8138387232902722, 0.6209011620147659, 0.0]
# (2020, 1, 2, 12, 58, 52.98083692789078)
# Phenomena of satellite 0
# [0.8136089241093188, 0.620678087864557, 0.0]
# (2020, 1, 2, 12, 58, 52.98083692789078)
# Phenomena of satellite 0
# [0.8136089241093188, 0.620678087864557, 0.0]
# (2020, 1, 2, 12, 58, 53.9808315038681)
# Phenomena of satellite 0
# [0.8133791292682386, 0.6204550258318586, 0.0]
# (2020, 1, 2, 12, 58, 53.9808315038681)
# Phenomena of satellite 0
# [0.8133791292682386, 0.6204550258318586, 0.0]
# (2020, 1, 2, 12, 58, 54.98082607984543)
# Phenomena of satellite 0
# [0.8131493388132668, 0.6202319760902064, 0.0]
# (2020, 1, 2, 12, 58, 54.98082607984543)
# Phenomena of satellite 0
# [0.8131493388132668, 0.6202319760902064, 0.0]
# (2020, 1, 2, 12, 58, 55.980820655822754)
# Phenomena of satellite 0
# [0.8129195526267224, 0.6200089384953565, 0.0]
# (2020, 1, 2, 12, 58, 55.980820655822754)
# Phenomena of satellite 0
# [0.8129195526267224, 0.6200089384953565, 0.0]
# (2020, 1, 2, 12, 58, 56.98081523180008)
# Phenomena of satellite 0
# [0.8126897707989685, 0.6197859131414478, 0.0]
# (2020, 1, 2, 12, 58, 56.98081523180008)
# Phenomena of satellite 0
# [0.8126897707989685, 0.6197859131414478, 0.0]
# (2020, 1, 2, 12, 58, 57.980809807777405)
# Phenomena of satellite 0
# [0.8124599932879072, 0.6195628999636754, 0.0]
# (2020, 1, 2, 12, 58, 57.980809807777405)
# Phenomena of satellite 0
# [0.8124599932879072, 0.6195628999636754, 0.0]
# (2020, 1, 2, 12, 58, 58.98080438375473)
# Phenomena of satellite 0
# [0.8122302201837185, 0.6193398990959971, 0.0]
# (2020, 1, 2, 12, 58, 58.98080438375473)
# Phenomena of satellite 0
# [0.8122302201837185, 0.6193398990959971, 0.0]
# (2020, 1, 2, 12, 58, 59.980798959732056)
# Phenomena of satellite 0
# [0.8120004514098871, 0.6191169105169927, 0.0]
# (2020, 1, 2, 12, 58, 59.980798959732056)
# Phenomena of satellite 0
# [0.8120004514098871, 0.6191169105169927, 0.0]
# (2020, 1, 2, 12, 59, 0.9807935357093811)
# Phenomena of satellite 0
# [0.8117706869747332, 0.6188939342342383, 0.0]
# (2020, 1, 2, 12, 59, 0.9807935357093811)
# Phenomena of satellite 0
# [0.8117706869747332, 0.6188939342342383, 0.0]
# (2020, 1, 2, 12, 59, 1.9807881116867065)
# Phenomena of satellite 0
# [0.8115409269181385, 0.618670970186622, 0.0]
# (2020, 1, 2, 12, 59, 1.9807881116867065)
# Phenomena of satellite 0
# [0.8115409269181385, 0.618670970186622, 0.0]
# (2020, 1, 2, 12, 59, 2.980782687664032)
# Phenomena of satellite 0
# [0.8113111712894967, 0.6184480184685013, 0.0]
# (2020, 1, 2, 12, 59, 2.980782687664032)
# Phenomena of satellite 0
# [0.8113111712894967, 0.6184480184685013, 0.0]
# (2020, 1, 2, 12, 59, 3.9807772636413574)
# Phenomena of satellite 0
# [0.8110814199711202, 0.6182250791342015, 0.0]
# (2020, 1, 2, 12, 59, 3.9807772636413574)
# Phenomena of satellite 0
# [0.8110814199711202, 0.6182250791342015, 0.0]
# (2020, 1, 2, 12, 59, 4.980771839618683)
# Phenomena of satellite 0
# [0.8108516730942744, 0.618002152119342, 0.0]
# (2020, 1, 2, 12, 59, 4.980771839618683)
# Phenomena of satellite 0
# [0.8108516730942744, 0.618002152119342, 0.0]
# (2020, 1, 2, 12, 59, 5.980766415596008)
# Phenomena of satellite 0
# [0.8106219304943373, 0.6177792373989528, 0.0]
# (2020, 1, 2, 12, 59, 5.980766415596008)
# Phenomena of satellite 0
# [0.8106219304943373, 0.6177792373989528, 0.0]
# (2020, 1, 2, 12, 59, 6.980760991573334)
# Phenomena of satellite 0
# [0.8103921924251146, 0.6175563350674091, 0.0]
# (2020, 1, 2, 12, 59, 6.980760991573334)
# Phenomena of satellite 0
# [0.8103921924251146, 0.6175563350674091, 0.0]
# (2020, 1, 2, 12, 59, 7.980755567550659)
# Phenomena of satellite 0
# [0.8101624586873223, 0.6173334451791577, 0.0]
# (2020, 1, 2, 12, 59, 7.980755567550659)
# Phenomena of satellite 0
# [0.8101624586873223, 0.6173334451791577, 0.0]
# (2020, 1, 2, 12, 59, 8.980750143527985)
# Phenomena of satellite 0
# [0.8099327293712761, 0.6171105677095085, 0.0]
# (2020, 1, 2, 12, 59, 8.980750143527985)
# Phenomena of satellite 0
# [0.8099327293712761, 0.6171105677095085, 0.0]
# (2020, 1, 2, 12, 59, 9.98074471950531)
# Phenomena of satellite 0
# [0.8097030043940605, 0.6168877025543589, 0.0]
# (2020, 1, 2, 12, 59, 9.98074471950531)
# Phenomena of satellite 0
# [0.8097030043940605, 0.6168877025543589, 0.0]
# (2020, 1, 2, 12, 59, 10.980739295482635)
# Phenomena of satellite 0
# [0.8094732839278137, 0.6166648499270965, 0.0]
# (2020, 1, 2, 12, 59, 10.980739295482635)
# Phenomena of satellite 0
# [0.8094732839278137, 0.6166648499270965, 0.0]
# (2020, 1, 2, 12, 59, 11.980733871459961)
# Phenomena of satellite 0
# [0.8092435678141172, 0.6164420097235842, 0.0]
# (2020, 1, 2, 12, 59, 11.980733871459961)
# Phenomena of satellite 0
# [0.8092435678141172, 0.6164420097235842, 0.0]
# (2020, 1, 2, 12, 59, 12.980728447437286)
# Phenomena of satellite 0
# [0.8090138561842756, 0.6162191820382245, 0.0]
# (2020, 1, 2, 12, 59, 12.980728447437286)
# Phenomena of satellite 0
# [0.8090138561842756, 0.6162191820382245, 0.0]
# (2020, 1, 2, 12, 59, 13.980723023414612)
# Phenomena of satellite 0
# [0.8087841489554451, 0.6159963667669502, 0.0]
# (2020, 1, 2, 12, 59, 13.980723023414612)
# Phenomena of satellite 0
# [0.8087841489554451, 0.6159963667669502, 0.0]
# (2020, 1, 2, 12, 59, 14.980717599391937)
# Phenomena of satellite 0
# [0.8085544461769166, 0.6157735639646142, 0.0]
# (2020, 1, 2, 12, 59, 14.980717599391937)
# Phenomena of satellite 0
# [0.8085544461769166, 0.6157735639646142, 0.0]
# (2020, 1, 2, 12, 59, 15.980712175369263)
# Phenomena of satellite 0
# [0.8083247478540028, 0.6155507737651446, 0.0]
# (2020, 1, 2, 12, 59, 15.980712175369263)
# Phenomena of satellite 0
# [0.8083247478540028, 0.6155507737651446, 0.0]
# (2020, 1, 2, 12, 59, 16.980706751346588)
# Phenomena of satellite 0
# [0.8080950539512776, 0.6153279959853583, 0.0]
# (2020, 1, 2, 12, 59, 16.980706751346588)
# Phenomena of satellite 0
# [0.8080950539512776, 0.6153279959853583, 0.0]
# (2020, 1, 2, 12, 59, 17.980701327323914)
# Phenomena of satellite 0
# [0.8078653644769853, 0.6151052307592647, 0.0]
# (2020, 1, 2, 12, 59, 17.980701327323914)
# Phenomena of satellite 0
# [0.8078653644769853, 0.6151052307592647, 0.0]
# (2020, 1, 2, 12, 59, 18.98069590330124)
# Phenomena of satellite 0
# [0.8076356794712388, 0.6148824781849739, 0.0]
# (2020, 1, 2, 12, 59, 18.98069590330124)
# Phenomena of satellite 0
# [0.8076356794712388, 0.6148824781849739, 0.0]
# (2020, 1, 2, 12, 59, 19.980690479278564)
# Phenomena of satellite 0
# [0.80740599890154, 0.6146597380721315, 0.0]
# (2020, 1, 2, 12, 59, 19.980690479278564)
# Phenomena of satellite 0
# [0.80740599890154, 0.6146597380721315, 0.0]
# (2020, 1, 2, 12, 59, 20.98068505525589)
# Phenomena of satellite 0
# [0.8071763228552128, 0.6144370105981308, 0.0]
# (2020, 1, 2, 12, 59, 20.98068505525589)
# Phenomena of satellite 0
# [0.8071763228552128, 0.6144370105981308, 0.0]
# (2020, 1, 2, 12, 59, 21.980679631233215)
# Phenomena of satellite 0
# [0.8069466512586178, 0.6142142956195176, 0.0]
# (2020, 1, 2, 12, 59, 21.980679631233215)
# Phenomena of satellite 0
# [0.8069466512586178, 0.6142142956195176, 0.0]
# (2020, 1, 2, 12, 59, 22.98067420721054)
# Phenomena of satellite 0
# [0.8067169841520679, 0.6139915933894644, 0.0]
# (2020, 1, 2, 12, 59, 22.98067420721054)
# Phenomena of satellite 0
# [0.8067169841520679, 0.6139915933894644, 0.0]
# (2020, 1, 2, 12, 59, 23.980668783187866)
# Phenomena of satellite 0
# [0.8064873215438585, 0.6137689038041645, 0.0]
# (2020, 1, 2, 12, 59, 23.980668783187866)
# Phenomena of satellite 0
# [0.8064873215438585, 0.6137689038041645, 0.0]
# (2020, 1, 2, 12, 59, 24.98066335916519)
# Phenomena of satellite 0
# [0.8062576633985558, 0.6135462267599067, 0.0]
# (2020, 1, 2, 12, 59, 24.98066335916519)
# Phenomena of satellite 0
# [0.8062576633985558, 0.6135462267599067, 0.0]
# (2020, 1, 2, 12, 59, 25.980657935142517)
# Phenomena of satellite 0
# [0.8060280097655215, 0.6133235623909694, 0.0]
# (2020, 1, 2, 12, 59, 25.980657935142517)
# Phenomena of satellite 0
# [0.8060280097655215, 0.6133235623909694, 0.0]
# (2020, 1, 2, 12, 59, 26.980652511119843)
# Phenomena of satellite 0
# [0.805798360602946, 0.6131009106729565, 0.0]
# (2020, 1, 2, 12, 59, 26.980652511119843)
# Phenomena of satellite 0
# [0.805798360602946, 0.6131009106729565, 0.0]
# (2020, 1, 2, 12, 59, 27.980647087097168)
# Phenomena of satellite 0
# [0.805568716001253, 0.6128782717400327, 0.0]
# (2020, 1, 2, 12, 59, 27.980647087097168)
# Phenomena of satellite 0
# [0.805568716001253, 0.6128782717400327, 0.0]
# (2020, 1, 2, 12, 59, 28.980641663074493)
# Phenomena of satellite 0
# [0.8053390758020512, 0.6126556454888229, 0.0]
# (2020, 1, 2, 12, 59, 28.980641663074493)
# Phenomena of satellite 0
# [0.8053390758020512, 0.6126556454888229, 0.0]
# (2020, 1, 2, 12, 59, 29.98063623905182)
# Phenomena of satellite 0
# [0.8051094402186372, 0.6124330318551058, 0.0]
# (2020, 1, 2, 12, 59, 29.98063623905182)
# Phenomena of satellite 0
# [0.8051094402186372, 0.6124330318551058, 0.0]
# (2020, 1, 2, 12, 59, 30.980630815029144)
# Phenomena of satellite 0
# [0.8048798090862169, 0.6122104310923016, 0.0]
# (2020, 1, 2, 12, 59, 30.980630815029144)
# Phenomena of satellite 0
# [0.8048798090862169, 0.6122104310923016, 0.0]
# (2020, 1, 2, 12, 59, 31.98062539100647)
# Phenomena of satellite 0
# [0.8046501825363238, 0.6119878430571716, 0.0]
# (2020, 1, 2, 12, 59, 31.98062539100647)
# Phenomena of satellite 0
# [0.8046501825363238, 0.6119878430571716, 0.0]
# (2020, 1, 2, 12, 59, 32.980619966983795)
# Phenomena of satellite 0
# [0.8044205604924236, 0.6117652677650592, 0.0]
# (2020, 1, 2, 12, 59, 32.980619966983795)
# Phenomena of satellite 0
# [0.8044205604924236, 0.6117652677650592, 0.0]
# (2020, 1, 2, 12, 59, 33.98061454296112)
# Phenomena of satellite 0
# [0.8041909430039753, 0.6115427052314939, 0.0]
# (2020, 1, 2, 12, 59, 33.98061454296112)
# Phenomena of satellite 0
# [0.8041909430039753, 0.6115427052314939, 0.0]
# (2020, 1, 2, 12, 59, 34.980609118938446)
# Phenomena of satellite 0
# [0.8039613300293157, 0.6113201554719285, 0.0]
# (2020, 1, 2, 12, 59, 34.980609118938446)
# Phenomena of satellite 0
# [0.8039613300293157, 0.6113201554719285, 0.0]
# (2020, 1, 2, 12, 59, 35.98060369491577)
# Phenomena of satellite 0
# [0.8037317217404837, 0.6110976186602848, 0.0]
# (2020, 1, 2, 12, 59, 35.98060369491577)
# Phenomena of satellite 0
# [0.8037317217404837, 0.6110976186602848, 0.0]
# (2020, 1, 2, 12, 59, 36.9805982708931)
# Phenomena of satellite 0
# [0.8035021178157686, 0.6108750945743578, 0.0]
# (2020, 1, 2, 12, 59, 36.9805982708931)
# Phenomena of satellite 0
# [0.8035021178157686, 0.6108750945743578, 0.0]
# (2020, 1, 2, 12, 59, 37.98059284687042)
# Phenomena of satellite 0
# [0.803272518587839, 0.6106525833124564, 0.0]
# (2020, 1, 2, 12, 59, 37.98059284687042)
# Phenomena of satellite 0
# [0.803272518587839, 0.6106525833124564, 0.0]
# (2020, 1, 2, 12, 59, 38.98058742284775)
# Phenomena of satellite 0
# [0.8030429238607777, 0.610430085001857, 0.0]
# (2020, 1, 2, 12, 59, 38.98058742284775)
# Phenomena of satellite 0
# [0.8030429238607777, 0.610430085001857, 0.0]
# (2020, 1, 2, 12, 59, 39.98058199882507)
# Phenomena of satellite 0
# [0.80281333367462, 0.6102075994635464, 0.0]
# (2020, 1, 2, 12, 59, 39.98058199882507)
# Phenomena of satellite 0
# [0.80281333367462, 0.6102075994635464, 0.0]
# (2020, 1, 2, 12, 59, 40.9805765748024)
# Phenomena of satellite 0
# [0.8025837480379776, 0.6099851269112465, 0.0]
# (2020, 1, 2, 12, 59, 40.9805765748024)
# Phenomena of satellite 0
# [0.8025837480379776, 0.6099851269112465, 0.0]
# (2020, 1, 2, 12, 59, 41.980571150779724)
# Phenomena of satellite 0
# [0.8023541671200612, 0.6097626672020954, 0.0]
# (2020, 1, 2, 12, 59, 41.980571150779724)
# Phenomena of satellite 0
# [0.8023541671200612, 0.6097626672020954, 0.0]
# (2020, 1, 2, 12, 59, 42.98056572675705)
# Phenomena of satellite 0
# [0.802124590642873, 0.6095402204308777, 0.0]
# (2020, 1, 2, 12, 59, 42.98056572675705)
# Phenomena of satellite 0
# [0.802124590642873, 0.6095402204308777, 0.0]
# (2020, 1, 2, 12, 59, 43.980560302734375)
# Phenomena of satellite 0
# [0.8018950188920956, 0.6093177866133486, 0.0]
# (2020, 1, 2, 12, 59, 43.980560302734375)
# Phenomena of satellite 0
# [0.8018950188920956, 0.6093177866133486, 0.0]
# (2020, 1, 2, 12, 59, 44.9805548787117)
# Phenomena of satellite 0
# [0.8016654516309435, 0.6090953657650751, 0.0]
# (2020, 1, 2, 12, 59, 44.9805548787117)
# Phenomena of satellite 0
# [0.8016654516309435, 0.6090953657650751, 0.0]
# (2020, 1, 2, 12, 59, 45.980549454689026)
# Phenomena of satellite 0
# [0.8014358890285135, 0.6088729578224973, 0.0]
# (2020, 1, 2, 12, 59, 45.980549454689026)
# Phenomena of satellite 0
# [0.8014358890285135, 0.6088729578224973, 0.0]
# (2020, 1, 2, 12, 59, 46.98054403066635)
# Phenomena of satellite 0
# [0.8012063310115789, 0.6086505628807252, 0.0]
# (2020, 1, 2, 12, 59, 46.98054403066635)
# Phenomena of satellite 0
# [0.8012063310115789, 0.6086505628807252, 0.0]
# (2020, 1, 2, 12, 59, 47.98053860664368)
# Phenomena of satellite 0
# [0.8009767776202765, 0.6084281809552685, 0.0]
# (2020, 1, 2, 12, 59, 47.98053860664368)
# Phenomena of satellite 0
# [0.8009767776202765, 0.6084281809552685, 0.0]
# (2020, 1, 2, 12, 59, 48.980533182621)
# Phenomena of satellite 0
# [0.8007472289042731, 0.6082058121016267, 0.0]
# (2020, 1, 2, 12, 59, 48.980533182621)
# Phenomena of satellite 0
# [0.8007472289042731, 0.6082058121016267, 0.0]
# (2020, 1, 2, 12, 59, 49.98052775859833)
# Phenomena of satellite 0
# [0.8005176847053194, 0.6079834562167123, 0.0]
# (2020, 1, 2, 12, 59, 49.98052775859833)
# Phenomena of satellite 0
# [0.8005176847053194, 0.6079834562167123, 0.0]
# (2020, 1, 2, 12, 59, 50.98052233457565)
# Phenomena of satellite 0
# [0.8002881451548192, 0.607761113395514, 0.0]
# (2020, 1, 2, 12, 59, 50.98052233457565)
# Phenomena of satellite 0
# [0.8002881451548192, 0.607761113395514, 0.0]
# (2020, 1, 2, 12, 59, 51.98051691055298)
# Phenomena of satellite 0
# [0.8000586102928637, 0.6075387836538721, 0.0]
# (2020, 1, 2, 12, 59, 51.98051691055298)
# Phenomena of satellite 0
# [0.8000586102928637, 0.6075387836538721, 0.0]
# (2020, 1, 2, 12, 59, 52.980511486530304)
# Phenomena of satellite 0
# [0.7998290800464669, 0.6073164669679425, 0.0]
# (2020, 1, 2, 12, 59, 52.980511486530304)
# Phenomena of satellite 0
# [0.7998290800464669, 0.6073164669679425, 0.0]
# (2020, 1, 2, 12, 59, 53.98050606250763)
# Phenomena of satellite 0
# [0.7995995544618919, 0.6070941633537036, 0.0]
# (2020, 1, 2, 12, 59, 53.98050606250763)
# Phenomena of satellite 0
# [0.7995995544618919, 0.6070941633537036, 0.0]
# (2020, 1, 2, 12, 59, 54.980500638484955)
# Phenomena of satellite 0
# [0.799370033466078, 0.6068718729458064, 0.0]
# (2020, 1, 2, 12, 59, 54.980500638484955)
# Phenomena of satellite 0
# [0.799370033466078, 0.6068718729458064, 0.0]
# (2020, 1, 2, 12, 59, 55.98049521446228)
# Phenomena of satellite 0
# [0.7991405172628419, 0.6066495956413133, 0.0]
# (2020, 1, 2, 12, 59, 55.98049521446228)
# Phenomena of satellite 0
# [0.7991405172628419, 0.6066495956413133, 0.0]
# (2020, 1, 2, 12, 59, 56.980489790439606)
# Phenomena of satellite 0
# [0.7989110056972977, 0.6064273314201277, 0.0]
# (2020, 1, 2, 12, 59, 56.980489790439606)
# Phenomena of satellite 0
# [0.7989110056972977, 0.6064273314201277, 0.0]
# (2020, 1, 2, 12, 59, 57.98048436641693)
# Phenomena of satellite 0
# [0.7986814987339955, 0.6062050803307062, 0.0]
# (2020, 1, 2, 12, 59, 57.98048436641693)
# Phenomena of satellite 0
# [0.7986814987339955, 0.6062050803307062, 0.0]
# (2020, 1, 2, 12, 59, 58.98047894239426)
# Phenomena of satellite 0
# [0.7984519964194781, 0.6059828425112707, 0.0]
# (2020, 1, 2, 12, 59, 58.98047894239426)
# Phenomena of satellite 0
# [0.7984519964194781, 0.6059828425112707, 0.0]

# %%
#check the central point for the entrance time in the umbra

epoch.set(2020, 1, 2, 12, 0, 0)
time_step = 1.157401129603386e-05 

t_centro = epoch

status_old = 0;
status_new = 0;


for i in range(1, 3600):

    epoch += time_step
    position_matrix = (np.array(JupiterMoons.rectangular_positions(epoch, solar = True))).reshape(4, 3)

    position_matrix[:, 1] *= 1.071374
    
    r_std =  np.sqrt(position_matrix[:, 0]**2 + position_matrix[:, 1]**2)
    
    r_moon = np.sqrt(position_matrix[:, 0]**2 + position_matrix[:, 1]**2 +  (position_matrix[:, 2]**2))
                                                             
    for i_sat in range(0,1):
                     
        if (r_std[i_sat] <= r_width[i_sat]) : 
            status_new = 1
            #print("event detcted")
        else:
            status_new = 0
            
            
            
        if (status_old != status_new):
            print(epoch.get_full_date())
            print("CENTRO : ")
            print(r_std[i_sat])
            print("----------------------------")
            t_centro = epoch
            
        status_old = status_new
# Out:
# (2020, 1, 2, 12, 31, 35.98971605300903)
# CENTRO :
# 0.9952698111035089
# ----------------------------

# %%
#check the furthermost point for the entrance time in the shadow

epoch.set(2020, 1, 2, 12, 0, 0)
time_step = 1.157401129603386e-05 

t_avanzo = epoch

status_old = 0;
status_new = 0;


for i in range(1, 3600):

    epoch += time_step
    
    position_matrix = (np.array(JupiterMoons.rectangular_positions(epoch, solar = True))).reshape(4, 3)
    
    position_matrix_avanzo = position_matrix + np.transpose(moons_radii)
    
    position_matrix_avanzo[:, 1] *= 1.071374

    r_avanzo = np.sqrt(position_matrix_avanzo[:, 0]**2 + (position_matrix_avanzo[:, 1])**2)
       
                                          
    for i_sat in range(0,1):
                     
        if (r_avanzo[i_sat] <= r_width[i_sat]) : 
            status_new = 1
            #print("event detcted")
        else:
            status_new = 0
            
            
            
        if (status_old != status_new):
            print(epoch.get_full_date())
            print("AVANZO : ")
            print(r_avanzo[i_sat])
            print("----------------------------")
            t_avanzo = epoch
            
        status_old = status_new
# Out:
# (2020, 1, 2, 12, 33, 25.98911941051483)
# AVANZO :
# 0.9951081468851727
# ----------------------------

# %%
#check entrance in umbra for the furthermost time

epoch.set(2020, 1, 2, 12, 0, 0)
time_step = 1.157401129603386e-05 


t_regresso = epoch;


status_old = 0;
status_new = 0;

for i in range(1, 3600):

    epoch += time_step
    position_matrix = (np.array(JupiterMoons.rectangular_positions(epoch, solar = True))).reshape(4, 3)
    
    position_matrix_avanzo = position_matrix + np.transpose(moons_radii)

    #print(position_matrix_avanzo)
    
    position_matrix_regresso = position_matrix - np.transpose(moons_radii)
    
    position_matrix_regresso[:, 1] *= 1.071374
    
    r_regresso = np.sqrt(position_matrix_regresso[:, 0]**2 + (position_matrix_regresso[:, 1])**2)
       
    r_std =  np.sqrt(position_matrix[:, 0]**2 + position_matrix[:, 1]**2)
        
    for i_sat in range(0,1):
            
        if (r_regresso[i_sat] <= r_width[i_sat]) : 
            status_new = 1
        else:
            status_new = 0
            
            
            
        if (status_old != status_new):
            print("event detcted")
            print(epoch.get_full_date())
            print("REGRESSO : ")
            print(r_regresso[i_sat])
            print("----------------------------")
            t_regresso = epoch;
            
        status_old = status_new
# Out:
# event detcted
# (2020, 1, 2, 12, 29, 46.99030727148056)
# REGRESSO :
# 0.9951797022112245
# ----------------------------

# %%
#correct for light delay

epoch.set(2020, 1, 2, 12, 0, 0)
time_step = 1.157401129603386e-05 

l_earth, b_earth, r_earth = Earth.geometric_heliocentric_position(epoch, tofk5=True)
l_jupiter, b_jupiter, r_jupiter = Jupiter.geometric_heliocentric_position(epoch, tofk5=True)

print("Earth radius in AU " + str(r_earth))
print("Jupiter radius in AU " + str(r_jupiter))

l_earth = float(l_earth)* np.pi/180
b_earth = float(b_earth)* np.pi/180

l_jupiter = float(l_jupiter)* np.pi/180
b_jupiter = float(b_jupiter)* np.pi/180

x_e = r_earth * np.cos(b_earth) * np.cos(l_earth) 
y_e = r_earth * np.cos(b_earth) * np.sin(l_earth) 
z_e = r_earth * np.sin(b_earth) 


x_j = r_jupiter * np.cos(b_jupiter) * np.cos(l_jupiter) 
y_j = r_jupiter * np.cos(b_jupiter) * np.sin(l_jupiter) 
z_j = r_jupiter * np.sin(b_jupiter) 

Delta = np.sqrt((x_j-x_e)**2+(y_j-y_e)**2+(z_j-z_e)**2)

print("Delta : "+ str(Delta))

correction_term_au = Delta - r_jupiter

time_correction = correction_term_au * (149597870700)/(299792458)#(150*(10**9))/(3*(10**8))

print("Correction in seconds : " + str(time_correction))

time_correction_jd = time_step * time_correction

t_centro_corrected = t_centro + time_correction_jd
t_regresso_corrected = t_regresso + time_correction_jd
t_avanzo_corrected = t_avanzo + time_correction_jd


print("t_centro : \t" + str(t_centro_corrected.get_full_date()))
print("t_regresso: \t" + str(t_regresso_corrected.get_full_date()))
print("t_avanzo : \t" + str(t_avanzo_corrected.get_full_date()))
# Out:
# Earth radius in AU 0.98326516298437
# Jupiter radius in AU 5.227032007938788
# Delta : 6.206664082962258
# Correction in seconds : 488.8410918360523
# t_centro : 	(2020, 1, 2, 12, 39, 44.82814282178879)
# t_regresso: 	(2020, 1, 2, 12, 37, 55.828734040260315)
# t_avanzo : 	(2020, 1, 2, 12, 41, 34.827546179294586)

# %% [markdown]
# # Calculate entrance point for europa in the shadow of Jupiter

# %% [markdown]
# Entrance in umbra : 21:00:15
#
# Complete entrance in umbra : 21:04:27

# %%
#calculate the parameters describing the umbra of jupiter

epoch.set(2020, 1, 1, 20, 30, 0)
time_step = 1.157401129603386e-05 

position_matrix = (np.array(JupiterMoons.rectangular_positions(epoch))).reshape(4, 3)

alpha_rad, vertex_jr,beta_rad, beta_vertex = JupiterMoons.round_base_cone_param(epoch, True) # True

print("Alpha : " + str(alpha_rad * 180/np.pi))
print("Vertex : " + str(vertex_jr))
print("Beta : " + str(beta_rad * 180/np.pi))
print("Penumbral Vertex : " + str(beta_vertex))

alpha_comp = np.pi/2 - alpha_rad

print("Alpha_comp : " + str(alpha_comp * 180/np.pi))

r = np.sqrt(position_matrix[:, 0]**2 + position_matrix[:, 1]**2 + position_matrix[:, 2]**2)

intersection_point = vertex_jr - r
print("Cone intersection depth : " + str(intersection_point[0]))

r_width = intersection_point * np.tan(alpha_comp)
print("Width of shadow (radius) : " + str(r_width))

r_penumbra = 1 + (1/np.tan(beta_rad)) * r

print("Width of penumbra :" + str(r_penumbra))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-9aa173d4fcaa> in <module>
#       6 position_matrix = (np.array(JupiterMoons.rectangular_positions(epoch))).reshape(4, 3)
#       7
# ----> 8 alpha_rad, vertex_jr,beta_rad, beta_vertex = JupiterMoons.round_base_cone_param(epoch, True) # True
#       9
#      10 print("Alpha : " + str(alpha_rad * 180/np.pi))
#
# AttributeError: type object 'JupiterMoons' has no attribute 'round_base_cone_param'

# %%
epoch.set(2020, 1, 1, 20, 30, 0)
time_step = 1.157401129603386e-05 

t_avanzo = epoch

status_old = [0, 0, 0, 0];
status_new = [0, 0, 0, 0];


for i in range(1, 3600):

    epoch += time_step
    
    position_matrix = (np.array(JupiterMoons.rectangular_positions(epoch, solar = True))).reshape(4, 3)
    
    position_matrix_avanzo = position_matrix + np.transpose(moons_radii)
    
    position_matrix_avanzo[:, 1] *= 1.071347

    r_avanzo = np.sqrt(position_matrix_avanzo[:, 0]**2 + position_matrix_avanzo[:, 1]**2)   
                                          
    for i_sat in range(0,3):
                     
        if (r_avanzo[i_sat] <= r_width[i_sat]) : 
            status_new[i_sat] = 1
        else:
            status_new[i_sat] = 0
            
        if (status_old[i_sat] != status_new[i_sat]):
            print("Event detected on satellite : " + str(i_sat))
            print(epoch.get_full_date())
            print("AVANZO : ")
            print(r_avanzo[i_sat])
            print("----------------------------")
            t_avanzo = epoch
            
        status_old[i_sat] = status_new[i_sat]

# %%
epoch.set(2020, 1, 1, 20, 30, 0)
time_step = 1.157401129603386e-05 


t_regresso = epoch;


status_old = [0, 0, 0, 0];
status_new = [0, 0, 0, 0];


for i in range(1, 3600):

    epoch += time_step
    position_matrix = (np.array(JupiterMoons.rectangular_positions(epoch, solar = True))).reshape(4, 3)
    
    position_matrix_regresso = position_matrix - np.transpose(moons_radii)
    
    position_matrix_regresso[:, 1] *= 1.071374
                             
    r_regresso = np.sqrt(position_matrix_regresso[:, 0]**2 + position_matrix_regresso[:, 1]**2)
    
    for i_sat in range(0,2):
                     
        if (r_regresso[i_sat] <= r_width[i_sat]) : 
            status_new[i_sat] = 1
        else:
            status_new[i_sat] = 0
            
        if (status_old[i_sat] != status_new[i_sat]):
            print("Event detected on satellite : " + str(i_sat))
            print(epoch.get_full_date())
            print("REGRESSO : ")
            print(r_regresso[i_sat])
            print("----------------------------")
            t_regresso = epoch
            
        status_old[i_sat] = status_new[i_sat]

# %%
epoch.set(2020, 1, 1, 20, 30, 0)
time_step = 1.157401129603386e-05 

t_centro = epoch

status_old = [0, 0, 0, 0];
status_new = [0, 0, 0, 0];


for i in range(1, 3600):

    epoch += time_step
    position_matrix = (np.array(JupiterMoons.rectangular_positions(epoch, solar = True))).reshape(4, 3)
    
    position_matrix[:, 1] = position_matrix[:, 1]*1.071347

    r_std =  np.sqrt(position_matrix[:, 0]**2 + (position_matrix[:, 1])**2)
                                                                 
    for i_sat in range(0,2):

        if(r_std[i_sat] <= r_width[i_sat]) : 
            status_new[i_sat] = 1
        else:
            status_new[i_sat] = 0

        if (status_old[i_sat] != status_new[i_sat]):
            print("Event detected on satellite : " + str(i_sat))
            print(epoch.get_full_date())
            print("CENTRO : ")
            print(r_std[i_sat])
            print("Coordinates :")
            print(position_matrix)
            print("----------------------------")
            t_centro = epoch

        status_old[i_sat] = status_new[i_sat]

# %%
epoch.set(2020, 1, 1, 20, 30, 0)
time_step = 1.157401129603386e-05 

l_earth, b_earth, r_earth = Earth.geometric_heliocentric_position(epoch, tofk5=True)
l_jupiter, b_jupiter, r_jupiter = Jupiter.geometric_heliocentric_position(epoch, tofk5=True)

print("Earth radius in AU " + str(r_earth))
print("Jupiter radius in AU " + str(r_jupiter))

l_earth = float(l_earth)* np.pi/180
b_earth = float(b_earth)* np.pi/180

l_jupiter = float(l_jupiter)* np.pi/180
b_jupiter = float(b_jupiter)* np.pi/180

x_e = r_earth * np.cos(b_earth) * np.cos(l_earth) 
y_e = r_earth * np.cos(b_earth) * np.sin(l_earth) 
z_e = r_earth * np.sin(b_earth) 


x_j = r_jupiter * np.cos(b_jupiter) * np.cos(l_jupiter) 
y_j = r_jupiter * np.cos(b_jupiter) * np.sin(l_jupiter) 
z_j = r_jupiter * np.sin(b_jupiter) 

Delta = np.sqrt((x_j-x_e)**2+(y_j-y_e)**2+(z_j-z_e)**2)

print("Delta : "+ str(Delta))

correction_term_au = Delta - r_jupiter

time_correction = correction_term_au * (149597870700)/(299792458)#(150*(10**9))/(3*(10**8))

print("Correction in seconds : " + str(time_correction))

time_correction_jd = time_step * time_correction

t_centro_corrected = t_centro + time_correction_jd
t_regresso_corrected = t_regresso + time_correction_jd
t_avanzo_corrected = t_avanzo + time_correction_jd


print("t_centro : \t" + str(t_centro_corrected.get_full_date()))
print("t_regresso: \t" + str(t_regresso_corrected.get_full_date()))
print("t_avanzo : \t" + str(t_avanzo_corrected.get_full_date()))

# %%
#try correcting for spherical differences
epoch.set(2020, 1, 1, 20, 30, 0)
time_step = 1.157401129603386e-05 


t_regresso = epoch;


status_old = [0, 0, 0, 0];
status_new = [0, 0, 0, 0];


for i in range(1, 3600):

    epoch += time_step
    position_matrix = (np.array(JupiterMoons.rectangular_positions(epoch, solar = True))).reshape(4, 3)
    
    position_matrix_regresso = position_matrix #- np.transpose(moons_radii)
    #print(position_matrix)
    
    gamma = np.arctan2(position_matrix[:, 1]*1.071374,position_matrix[:, 0])
    cos_alpha = np.cos(gamma)
    sin_alpha = np.sin(gamma)
    
    position_matrix_regresso[:, 0] -= (cos_alpha * moons_radii_vec).T
    position_matrix_regresso[:, 1] -= (sin_alpha * moons_radii_vec).T
    
    #print(gamma*180/np.pi)
    
    #print(moons_radii_vec)
    
    #print(cos_alpha)
    #print(sin_alpha)
    
    position_matrix_regresso[:, 1] *= 1.071374
                             
    #print(position_matrix_regresso)
    
    #break
        
    r_regresso = np.sqrt(position_matrix_regresso[:, 0]**2 + position_matrix_regresso[:, 1]**2)
    
    
    
    
    for i_sat in range(0,2):
                     
        if (r_regresso[i_sat] <= r_width[i_sat]) : 
            status_new[i_sat] = 1
        else:
            status_new[i_sat] = 0
            
        if (status_old[i_sat] != status_new[i_sat]):
            print("Event detected on satellite : " + str(i_sat))
            print(epoch.get_full_date())
            print("REGRESSO : ")
            print(r_regresso[i_sat])
            print("----------------------------")
            t_regresso = epoch
            
        status_old[i_sat] = status_new[i_sat]

# %%
epoch.set(2020, 1, 1, 21, 00, 0)
time_step = 1.157401129603386e-05 

l_earth, b_earth, r_earth = Earth.geometric_heliocentric_position(epoch, tofk5=True)
l_jupiter, b_jupiter, r_jupiter = Jupiter.geometric_heliocentric_position(epoch, tofk5=True)

print("Earth radius in AU " + str(r_earth))
print("Jupiter radius in AU " + str(r_jupiter))

l_earth = float(l_earth)* np.pi/180
b_earth = float(b_earth)* np.pi/180

l_jupiter = float(l_jupiter)* np.pi/180
b_jupiter = float(b_jupiter)* np.pi/180

x_e = r_earth * np.cos(b_earth) * np.cos(l_earth) 
y_e = r_earth * np.cos(b_earth) * np.sin(l_earth) 
z_e = r_earth * np.sin(b_earth) 


x_j = r_jupiter * np.cos(b_jupiter) * np.cos(l_jupiter) 
y_j = r_jupiter * np.cos(b_jupiter) * np.sin(l_jupiter) 
z_j = r_jupiter * np.sin(b_jupiter) 

Delta = np.sqrt((x_j-x_e)**2+(y_j-y_e)**2+(z_j-z_e)**2)

print("Delta : "+ str(Delta))

correction_term_au = Delta - r_jupiter

time_correction = correction_term_au * (149597870700)/(299792458)#(150*(10**9))/(3*(10**8))

print("Correction in seconds : " + str(time_correction))

time_correction_jd = time_step * time_correction

#t_centro_corrected = t_centro + time_correction_jd
t_regresso_corrected = t_regresso + time_correction_jd
#t_avanzo_corrected = t_avanzo + time_correction_jd


#print("t_centro : \t" + str(t_centro_corrected.get_full_date()))
print("t_regresso: \t" + str(t_regresso_corrected.get_full_date()))
#print("t_avanzo : \t" + str(t_avanzo_corrected.get_full_date()))

# %%
def crossing_point(epoch_start, time_span, time_step = 1.157401129603386e-05 ): 
    
    epoch = epoch_start
    
    #phenomena matrix : 
    
    penumbra_matrix = [0,0,0,0]
    umbra_matrix = [0,0,0,0]
    occultation_matrix = [0,0,0,0]
    overlap_matrix = [0,0,0,0]
    shadow_matrix = [0,0,0,0]
    
    penumbra_matrix_new = [0,0,0,0]
    umbra_matrix_new = [0,0,0,0]
    occultation_matrix_new = [0,0,0,0]
    overlap_matrix_new = [0,0,0,0]
    shadow_matrix_new = [0,0,0,0]
    
    for i in range (time_span):
        
        epoch += time_step
    
        position_matrix = (np.array(JupiterMoons.rectangular_positions(epoch, solar = True))).reshape(4, 3)

        position_matrix[:, 1] = position_matrix[:, 1]*1.071347

        #calculate the form of the shadow
        alpha_rad, vertex_jr,beta_rad, beta_vertex = JupiterMoons.round_base_cone_param(epoch, True) # True

        alpha_comp = np.pi/2 - alpha_rad

        r = np.sqrt(position_matrix[:, 0]**2 + position_matrix[:, 1]**2 + position_matrix[:, 2]**2)

        intersection_point = vertex_jr - r

        r_width = intersection_point * np.tan(alpha_comp)

        r_penumbra = 1 + (1/np.tan(beta_rad)) * r

        for i_sat in range(0,3):

            satellite_position = position_matrix[i_sat, :]

            if(satellite_position[2] > 0):
                #check for umbra and penumbra

                r_std =  np.sqrt(position_matrix[:, 0]**2 + (position_matrix[:, 1])**2)

                if(r_std[i_sat] <= r_width[i_sat]) : 

                    if(umbra_matrix[i_sat] != umbra_matrix_new[i_sat]):

                        if(umbra_matrix[i_sat]==0):
                            umbra_matrix_new[i_sat] = 1
                        else:
                            umbra_matrix_new[i_sat] = -1
                    else:
                        umbra_matrix[i_sat] = 0

                    if (umbra_matrix[i_sat] != umbra_matrix_new[i_sat]):
                        print("Umbral event detected on satellite : " + str(i_sat))
                        t_centro = epoch

                umbra_matrix[i_sat] = umbra_matrix_new[i_sat]     

                if(r_std[i_sat] <= r_penumbra[i_sat]) : 

                    if(penumbra_matrix[i_sat] != penumbra_matrix_new[i_sat]):

                        if(penumbra_matrix[i_sat]==0):
                            penumbra_matrix_new[i_sat] = 1
                        else:
                            penumbra_matrix_new[i_sat] = -1
                    else:
                        penumbra_matrix[i_sat] = 0

                    if (penumbra_matrix[i_sat] != penumbra_matrix_new[i_sat]):
                        print("Penumbral event detected on satellite : " + str(i_sat))
                        t_centro = epoch

                umbra_matrix[i_sat] = umbra_matrix_new[i_sat]     

            else :
                #check for shadow
                r_std =  np.sqrt(position_matrix[:, 0]**2 + (position_matrix[:, 1])**2)

                if(r_std[i_sat] <= 1) : 

                    if(shadow_matrix[i_sat] != shadow_matrix_new[i_sat]):

                        if(shadow_matrix[i_sat]==0):
                            shadow_matrix_new[i_sat] = 1
                        else:
                            shadow_matrix_new[i_sat] = -1
                    else:
                        shadow_matrix[i_sat] = 0

                    if (shadow_matrix[i_sat] != shadow_matrix_new[i_sat]):
                        print("Shadow event detected on satellite : " + str(i_sat))
                        t_centro = epoch

                shadow_matrix[i_sat] = shadow_matrix_new[i_sat]

            #now consider earth based phenomena


            position_matrix_eb = (np.array(JupiterMoons.rectangular_positions(epoch, solar = False))).reshape(4, 3)

            position_matrix_eb[:, 1] = position_matrix_eb[:, 1]*1.071347

            if(satellite_position[2] > 0):
                #check for occultation

                r_std =  np.sqrt(position_matrix[:, 0]**2 + (position_matrix[:, 1])**2)

                if(r_std[i_sat] <= 1) : 

                    if(occultation_matrix[i_sat] != occultation_matrix_new[i_sat]):

                        if(occultation_matrix[i_sat]==0):
                            occultation_matrix_new[i_sat] = 1
                        else:
                            occultation_matrix_new[i_sat] = -1
                    else:
                        occultation_matrix[i_sat] = 0

                    if (occultation_matrix[i_sat] != occultation_matrix_new[i_sat]):
                        print("Occultation event detected on satellite : " + str(i_sat))
                        t_centro = epoch

                occultation_matrix[i_sat] = occultation_matrix_new[i_sat]     

            else :
                #check for overlay
                r_std =  np.sqrt(position_matrix[:, 0]**2 + (position_matrix[:, 1])**2)

                if(r_std[i_sat] <= 1) : 

                    if(overlap_matrix[i_sat] != overlap_matrix_new[i_sat]):

                        if(overlap_matrix[i_sat]==0):
                            overlap_matrix_new[i_sat] = 1
                        else:
                            overlap_matrix_new[i_sat] = -1
                    else:
                        overlap_matrix[i_sat] = 0

                    if (overlap_matrix[i_sat] != overlap_matrix_new[i_sat]):
                        print("Overlap event detected on satellite : " + str(i_sat))
                        t_centro = epoch

                overlap_matrix[i_sat] = overlap_matrix_new[i_sat]
                
                
    return [[penumbra_matrix],[umbra_matrix],[occultation_matrix],[overlap_matrix],[shadow_matrix]]

# %%
epoch.set(2020, 1, 2, 12, 30, 0)

JupiterMoons.crossing_point(epoch, 3600)
