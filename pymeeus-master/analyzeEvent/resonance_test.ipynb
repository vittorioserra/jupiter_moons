# %% [markdown]
# This notebook is here to verify weather the frequency components we gout out of the fft roughly are the resonance factors for the Earth-Sun-Jupiter system

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
#these can be whatever we want
r_1 = 1
r_2 = 2

f_1 = 1 #(years)
f_2 = 1/11.82#(years)

a_1 = 1
a_2 = 3

t = np.linspace(0,15,10000)

x_1 = a_1*np.cos(2*np.pi*f_1*t)
y_1 = a_1*np.sin(2*np.pi*f_1*t)

x_2 = a_2*np.cos(2*np.pi*f_2*t)
y_2 = a_2*np.sin(2*np.pi*f_2*t)

# %%
plt.plot(x_1, y_1)
plt.plot(x_2, y_2)

# %%
dist = np.sqrt((x_1-x_2)**2 +(y_1-y_2)**2) 
plt.plot(t, dist)

# %%
plt.plot(t[int(1*10000/15):int(1.25*10000/15)], dist[int(1*10000/15):int(1.25*10000/15)])
