# %%
from Calendar.Calculation import Calculation
from pymeeus.Epoch import Epoch

import matplotlib.pyplot as plt

# %%
epoch_start = Epoch()
epoch_start.set(2020, 1, 1, 0)
epoch_end = Epoch()
epoch_end.set(2020, 3, 1, 0)
# 1 s in jd = 1.157401129603386e-05
time_step = 60 * 120 * 1.157401129603386e-05

calc = Calculation(epoch_start, epoch_end, time_step)
# Out:
# Got rough timings
# Got exact timings
# Found  250  timings

# %%
plt.plot(calc.distances[0][0])
plt.grid(True)
plt.ylim([0, 1])

print(len(calc.timing_lists[0][1]))
print(calc.timing_lists[0][1])
# Out:
# 67
# [(19, 'start', Epoch(2458851.0217100894), 0, 1), (20, 'end', Epoch(2458851.115276477), 0, 1), (40, 'start', Epoch(2458852.7916182955), 0, 1), (41, 'end', Epoch(2458852.885194855), 0, 1), (61, 'start', Epoch(2458854.5614756388), 0, 1), (62, 'end', Epoch(2458854.6550521986), 0, 1), (83, 'start', Epoch(2458856.3313960438), 0, 1), (85, 'end', Epoch(2458856.4249827755), 0, 1), (105, 'start', Epoch(2458858.101233043), 0, 1), (106, 'end', Epoch(2458858.194829947), 0, 1), (126, 'start', Epoch(2458859.871131076), 0, 1), (127, 'end', Epoch(2458859.964738153), 0, 1), (148, 'start', Epoch(2458861.6409904463), 0, 1), (149, 'end', Epoch(2458861.734597523), 0, 1), (169, 'start', Epoch(2458863.4108986524), 0, 1), (171, 'end', Epoch(2458863.5045159017), 0, 1), (191, 'start', Epoch(2458865.180735651), 0, 1), (192, 'end', Epoch(2458865.2743630726), 0, 1), (212, 'start', Epoch(2458866.950633684), 0, 1), (213, 'end', Epoch(2458867.044261106), 0, 1), (234, 'start', Epoch(2458868.720482882), 0, 1), (235, 'end', Epoch(2458868.814120476), 0, 1), (255, 'start', Epoch(2458870.490391088), 0, 1), (257, 'end', Epoch(2458870.5840286827), 0, 1), (277, 'start', Epoch(2458872.2602179144), 0, 1), (278, 'end', Epoch(2458872.3538758536), 0, 1), (299, 'start', Epoch(2458874.030107802), 0, 1), (300, 'end', Epoch(2458874.123765741), 0, 1), (320, 'start', Epoch(2458875.7999549727), 0, 1), (321, 'end', Epoch(2458875.893612912), 0, 1), (341, 'start', Epoch(2458877.569863179), 0, 1), (342, 'end', Epoch(2458877.6635211185), 0, 1), (363, 'start', Epoch(2458879.339690005), 0, 1), (364, 'end', Epoch(2458879.43336829), 0, 1), (385, 'start', Epoch(2458881.10956972), 0, 1), (386, 'end', Epoch(2458881.203248005), 0, 1), (406, 'start', Epoch(2458882.879416891), 0, 1), (407, 'end', Epoch(2458882.973095176), 0, 1), (427, 'start', Epoch(2458884.6493149246), 0, 1), (428, 'end', Epoch(2458884.743003381), 0, 1), (450, 'start', Epoch(2458886.4191437773), 0, 1), (451, 'end', Epoch(2458886.5128322346), 0, 1), (471, 'start', Epoch(2458888.189021466), 0, 1), (472, 'end', Epoch(2458888.282720095), 0, 1), (492, 'start', Epoch(2458889.9588482925), 0, 1), (493, 'end', Epoch(2458890.052557094), 0, 1), (514, 'start', Epoch(2458891.7287483523), 0, 1), (515, 'end', Epoch(2458891.822457154), 0, 1), (535, 'start', Epoch(2458893.4985650056), 0, 1), (537, 'end', Epoch(2458893.59228398), 0, 1), (557, 'start', Epoch(2458895.268442694), 0, 1), (558, 'end', Epoch(2458895.362161668), 0, 1), (578, 'start', Epoch(2458897.0382695207), 0, 1), (579, 'end', Epoch(2458897.131998667), 0, 1), (600, 'start', Epoch(2458898.8081594086), 0, 1), (601, 'end', Epoch(2458898.901888555), 0, 1), (621, 'start', Epoch(2458900.577976062), 0, 1), (623, 'end', Epoch(2458900.671715381), 0, 1), (643, 'start', Epoch(2458902.347843578), 0, 1), (644, 'end', Epoch(2458902.4415828967), 0, 1), (665, 'start', Epoch(2458904.117672431), 0, 1), (666, 'end', Epoch(2458904.21141175), 0, 1), (686, 'start', Epoch(2458905.8875501193), 0, 1), (687, 'end', Epoch(2458905.981299611), 0, 1), (707, 'start', Epoch(2458907.6573667736), 0, 1), (709, 'end', Epoch(2458907.7511264374), 0, 1), (729, 'start', Epoch(2458909.427224117), 0, 1)]

# %%
for row in range(len(calc.timing_lists)):
    for col in range(len(calc.timing_lists[row]) - 1):
        for timing in calc.timing_lists[row][col]:
            print("Sat: ", row + 1, ", ", col, ", ", timing[1])
            print(timing[2].get_full_date())
            print()
# Out:
# Sat:  1 ,  0 ,  start
# (2020, 1, 2, 12, 45, 26.528361439704895)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 2, 15, 0, 22.96881526708603)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 4, 7, 15, 56.46005719900131)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 4, 9, 30, 53.77940386533737)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 6, 1, 46, 21.997208297252655)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 6, 4, 1, 20.195488035678864)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 7, 20, 16, 51.225105822086334)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 7, 22, 31, 51.181171238422394)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 9, 14, 47, 14.125538170337677)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 9, 17, 2, 14.960496425628662)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 11, 9, 17, 40.54162234067917)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 11, 11, 32, 43.134366273880005)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 13, 3, 48, 2.738296687602997)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 13, 6, 3, 7.0888665318489075)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 14, 22, 18, 29.15438085794449)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 15, 0, 33, 34.383843541145325)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 16, 16, 48, 47.66030877828598)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 16, 19, 3, 54.64759737253189)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 18, 11, 19, 10.560741126537323)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 18, 13, 34, 18.426962792873383)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 20, 5, 49, 28.3629110455513)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 20, 8, 4, 37.98691838979721)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 22, 0, 19, 50.38449078798294)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 22, 2, 35, 0.8873507380485535)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 23, 18, 50, 4.495954513549805)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 23, 21, 5, 16.756640374660492)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 25, 13, 20, 23.177017271518707)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 25, 15, 35, 36.31659597158432)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 27, 7, 50, 35.5306550860405)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 27, 10, 5, 50.428059697151184)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 29, 2, 20, 52.27879732847214)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 29, 4, 36, 8.055135011672974)
#
# Sat:  1 ,  0 ,  start
# (2020, 1, 30, 20, 51, 1.9957566261291504)
#
# Sat:  1 ,  0 ,  end
# (2020, 1, 30, 23, 6, 18.65094691514969)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 1, 15, 21, 13.645636439323425)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 1, 17, 36, 32.058612406253815)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 3, 9, 51, 20.725836753845215)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 3, 12, 6, 40.8966788649559)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 5, 4, 21, 31.321688890457153)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 5, 6, 36, 52.37138360738754)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 6, 22, 51, 34.182559847831726)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 7, 1, 6, 56.99004024267197)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 8, 17, 21, 40.38390755653381)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 8, 19, 37, 3.191387951374054)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 10, 11, 51, 40.432924926280975)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 10, 14, 7, 4.99823123216629)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 12, 6, 21, 44.17264848947525)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 12, 8, 37, 9.616887867450714)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 14, 0, 51, 40.70609450340271)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 14, 3, 7, 7.029186487197876)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 15, 19, 21, 38.11839312314987)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 15, 21, 37, 6.199311017990112)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 17, 13, 51, 32.01512038707733)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 17, 16, 7, 0.09603828191757202)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 19, 8, 21, 27.84472793340683)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 19, 10, 36, 56.804538667201996)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 21, 2, 51, 16.468057930469513)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 21, 5, 6, 47.18565434217453)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 22, 21, 21, 5.970240533351898)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 22, 23, 36, 37.566770017147064)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 24, 15, 50, 50.37416070699692)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 24, 18, 6, 23.728475868701935)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 26, 10, 20, 38.11855763196945)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 26, 12, 36, 11.472872793674469)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 28, 4, 50, 17.95283854007721)
#
# Sat:  1 ,  0 ,  end
# (2020, 2, 28, 7, 5, 53.06493937969208)
#
# Sat:  1 ,  0 ,  start
# (2020, 2, 29, 23, 19, 58.66601228713989)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 2, 12, 31, 15.75172483921051)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 2, 14, 45, 59.88759845495224)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 4, 6, 59, 55.820729434490204)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 4, 9, 14, 40.835455656051636)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 6, 1, 28, 31.495189368724823)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 6, 3, 43, 16.50995582342148)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 7, 19, 57, 12.61818140745163)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 7, 22, 11, 58.51180046796799)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 9, 14, 25, 46.53489589691162)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 9, 16, 40, 33.307407796382904)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 11, 8, 54, 25.724967420101166)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 11, 11, 9, 13.376412391662598)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 13, 3, 23, 1.5745621919631958)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 13, 5, 37, 49.22600716352463)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 14, 21, 51, 41.64356678724289)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 15, 0, 6, 30.173904597759247)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 16, 16, 20, 15.560241043567657)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 16, 18, 35, 4.96947169303894)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 18, 10, 48, 54.7503125667572)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 18, 13, 3, 44.159543216228485)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 20, 5, 17, 29.721014499664307)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 20, 7, 32, 20.009137988090515)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 21, 23, 46, 9.790019094944)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 22, 2, 1, 0.07818281650543213)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 23, 18, 14, 42.82780051231384)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 23, 20, 29, 34.873749911785126)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 25, 12, 43, 21.31407380104065)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 25, 14, 58, 13.360023200511932)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 27, 7, 11, 56.10964089632034)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 27, 9, 26, 48.155590295791626)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 29, 1, 40, 36.17864549160004)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 29, 3, 55, 28.224635124206543)
#
# Sat:  1 ,  1 ,  start
# (2020, 1, 30, 20, 9, 9.21642690896988)
#
# Sat:  1 ,  1 ,  end
# (2020, 1, 30, 22, 24, 3.02024245262146)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 1, 14, 37, 46.82380735874176)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 1, 16, 52, 40.62762290239334)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 3, 9, 6, 21.619374454021454)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 3, 11, 21, 15.423189997673035)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 5, 3, 35, 0.8094862103462219)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 5, 5, 49, 55.49211412668228)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 6, 22, 3, 34.02236223220825)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 7, 0, 18, 28.70507061481476)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 8, 16, 32, 11.454648077487946)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 8, 18, 47, 7.016209065914154)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 10, 11, 0, 44.49246972799301)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 10, 13, 15, 40.932923555374146)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 12, 5, 29, 23.857635855674744)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 12, 7, 44, 20.298089683055878)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 13, 23, 57, 56.01648420095444)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 14, 2, 12, 53.33587110042572)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 15, 18, 26, 33.44877004623413)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 15, 20, 41, 30.76811671257019)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 17, 12, 55, 6.486591696739197)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 17, 15, 10, 4.684831202030182)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 19, 7, 23, 44.97290521860123)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 19, 9, 38, 43.17114472389221)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 21, 1, 52, 17.13175356388092)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 21, 4, 7, 16.208926141262054)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 22, 20, 20, 53.68514657020569)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 22, 22, 35, 52.7622789144516)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 24, 14, 49, 26.89802259206772)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 24, 17, 4, 25.975195169448853)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 26, 9, 18, 4.330308437347412)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 26, 11, 33, 4.286373853683472)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 28, 3, 46, 36.48923724889755)
#
# Sat:  1 ,  1 ,  end
# (2020, 2, 28, 6, 1, 37.32419550418854)
#
# Sat:  1 ,  1 ,  start
# (2020, 2, 29, 22, 15, 12.163697183132172)
#
# Sat:  2 ,  0 ,  start
# (2020, 1, 1, 21, 11, 41.832202076911926)
#
# Sat:  2 ,  0 ,  end
# (2020, 1, 1, 23, 50, 49.33905601501465)
#
# Sat:  2 ,  0 ,  start
# (2020, 1, 5, 10, 36, 12.332480549812317)
#
# Sat:  2 ,  0 ,  end
# (2020, 1, 5, 13, 15, 43.56960207223892)
#
# Sat:  2 ,  0 ,  start
# (2020, 1, 9, 0, 0, 44.76559907197952)
#
# Sat:  2 ,  0 ,  end
# (2020, 1, 9, 2, 40, 41.49089455604553)
#
# Sat:  2 ,  0 ,  start
# (2020, 1, 12, 13, 25, 10.871332883834839)
#
# Sat:  2 ,  0 ,  end
# (2020, 1, 12, 16, 5, 32.205869257450104)
#
# Sat:  2 ,  0 ,  start
# (2020, 1, 16, 2, 49, 38.909946978092194)
#
# Sat:  2 ,  0 ,  end
# (2020, 1, 16, 5, 30, 25.732657313346863)
#
# Sat:  2 ,  0 ,  start
# (2020, 1, 19, 16, 13, 59.91737812757492)
#
# Sat:  2 ,  0 ,  end
# (2020, 1, 19, 18, 55, 10.470396280288696)
#
# Sat:  2 ,  0 ,  start
# (2020, 1, 23, 5, 38, 23.38643342256546)
#
# Sat:  2 ,  0 ,  end
# (2020, 1, 23, 8, 20, 0.3064379096031189)
#
# Sat:  2 ,  0 ,  start
# (2020, 1, 26, 19, 2, 35.60481548309326)
#
# Sat:  2 ,  0 ,  end
# (2020, 1, 26, 21, 44, 37.13414132595062)
#
# Sat:  2 ,  0 ,  start
# (2020, 1, 30, 8, 26, 49.40592885017395)
#
# Sat:  2 ,  0 ,  end
# (2020, 1, 30, 11, 9, 16.423388421535492)
#
# Sat:  2 ,  0 ,  start
# (2020, 2, 2, 21, 50, 47.561945021152496)
#
# Sat:  2 ,  0 ,  end
# (2020, 2, 3, 0, 33, 38.309712409973145)
#
# Sat:  2 ,  0 ,  start
# (2020, 2, 6, 11, 14, 49.23349231481552)
#
# Sat:  2 ,  0 ,  end
# (2020, 2, 6, 13, 58, 6.348326504230499)
#
# Sat:  2 ,  0 ,  start
# (2020, 2, 10, 0, 38, 32.273114919662476)
#
# Sat:  2 ,  0 ,  end
# (2020, 2, 10, 3, 22, 11.360471248626709)
#
# Sat:  2 ,  0 ,  start
# (2020, 2, 13, 14, 2, 20.761148929595947)
#
# Sat:  2 ,  0 ,  end
# (2020, 2, 13, 16, 46, 25.336679220199585)
#
# Sat:  2 ,  0 ,  start
# (2020, 2, 17, 3, 25, 40.94923585653305)
#
# Sat:  2 ,  0 ,  end
# (2020, 2, 17, 6, 10, 7.497288286685944)
#
# Sat:  2 ,  0 ,  start
# (2020, 2, 20, 16, 49, 10.980359315872192)
#
# Sat:  2 ,  0 ,  end
# (2020, 2, 20, 19, 34, 2.137652635574341)
#
# Sat:  2 ,  0 ,  start
# (2020, 2, 24, 6, 12, 6.734340190887451)
#
# Sat:  2 ,  0 ,  end
# (2020, 2, 24, 8, 57, 18.985303044319153)
#
# Sat:  2 ,  0 ,  start
# (2020, 2, 27, 19, 35, 15.496779978275299)
#
# Sat:  2 ,  0 ,  end
# (2020, 2, 27, 22, 20, 51.478010416030884)
#
# Sat:  2 ,  1 ,  start
# (2020, 1, 1, 20, 53, 7.385179102420807)
#
# Sat:  2 ,  1 ,  end
# (2020, 1, 1, 23, 31, 33.58362704515457)
#
# Sat:  2 ,  1 ,  start
# (2020, 1, 5, 10, 10, 21.07137143611908)
#
# Sat:  2 ,  1 ,  end
# (2020, 1, 5, 12, 49, 1.3321852684020996)
#
# Sat:  2 ,  1 ,  start
# (2020, 1, 8, 23, 27, 39.32716280221939)
#
# Sat:  2 ,  1 ,  end
# (2020, 1, 9, 2, 6, 34.52935606241226)
#
# Sat:  2 ,  1 ,  start
# (2020, 1, 12, 12, 44, 55.650073885917664)
#
# Sat:  2 ,  1 ,  end
# (2020, 1, 12, 15, 24, 4.914713501930237)
#
# Sat:  2 ,  1 ,  start
# (2020, 1, 16, 2, 2, 16.542584002017975)
#
# Sat:  2 ,  1 ,  end
# (2020, 1, 16, 4, 41, 41.627375185489655)
#
# Sat:  2 ,  1 ,  start
# (2020, 1, 19, 15, 19, 35.67726820707321)
#
# Sat:  2 ,  1 ,  end
# (2020, 1, 19, 17, 59, 14.82458621263504)
#
# Sat:  2 ,  1 ,  start
# (2020, 1, 23, 4, 37, 2.547014057636261)
#
# Sat:  2 ,  1 ,  end
# (2020, 1, 23, 7, 16, 57.514483630657196)
#
# Sat:  2 ,  1 ,  start
# (2020, 1, 26, 17, 54, 26.955135762691498)
#
# Sat:  2 ,  1 ,  end
# (2020, 1, 26, 20, 34, 35.98501145839691)
#
# Sat:  2 ,  1 ,  start
# (2020, 1, 30, 7, 11, 57.340412735939026)
#
# Sat:  2 ,  1 ,  end
# (2020, 1, 30, 9, 52, 23.069493770599365)
#
# Sat:  2 ,  1 ,  start
# (2020, 2, 2, 20, 29, 24.385293424129486)
#
# Sat:  2 ,  1 ,  end
# (2020, 2, 2, 23, 10, 4.176740348339081)
#
# Sat:  2 ,  1 ,  start
# (2020, 2, 6, 9, 47, 0.21914273500442505)
#
# Sat:  2 ,  1 ,  end
# (2020, 2, 6, 12, 27, 56.709674298763275)
#
# Sat:  2 ,  1 ,  start
# (2020, 2, 9, 23, 4, 31.48331254720688)
#
# Sat:  2 ,  1 ,  end
# (2020, 2, 10, 1, 45, 41.15747809410095)
#
# Sat:  2 ,  1 ,  start
# (2020, 2, 13, 12, 22, 15.227318108081818)
#
# Sat:  2 ,  1 ,  end
# (2020, 2, 13, 15, 3, 42.47946113348007)
#
# Sat:  2 ,  1 ,  start
# (2020, 2, 17, 1, 39, 47.37042099237442)
#
# Sat:  2 ,  1 ,  end
# (2020, 2, 17, 4, 21, 27.806077301502228)
#
# Sat:  2 ,  1 ,  start
# (2020, 2, 20, 14, 57, 37.26667642593384)
#
# Sat:  2 ,  1 ,  end
# (2020, 2, 20, 17, 39, 34.40149784088135)
#
# Sat:  2 ,  1 ,  start
# (2020, 2, 24, 4, 15, 13.100565969944)
#
# Sat:  2 ,  1 ,  end
# (2020, 2, 24, 6, 57, 23.41886043548584)
#
# Sat:  2 ,  1 ,  start
# (2020, 2, 27, 17, 33, 10.731802582740784)
#
# Sat:  2 ,  1 ,  end
# (2020, 2, 27, 20, 15, 38.628195226192474)
#
# Sat:  3 ,  0 ,  start
# (2020, 1, 2, 9, 42, 48.38466078042984)
#
# Sat:  3 ,  0 ,  end
# (2020, 1, 2, 12, 38, 29.929092228412628)
#
# Sat:  3 ,  0 ,  start
# (2020, 1, 9, 14, 12, 11.79318755865097)
#
# Sat:  3 ,  0 ,  end
# (2020, 1, 9, 17, 9, 44.95805561542511)
#
# Sat:  3 ,  0 ,  start
# (2020, 1, 16, 18, 40, 10.827197134494781)
#
# Sat:  3 ,  0 ,  end
# (2020, 1, 16, 21, 39, 36.49143487215042)
#
# Sat:  3 ,  0 ,  start
# (2020, 1, 23, 23, 7, 15.369287431240082)
#
# Sat:  3 ,  0 ,  end
# (2020, 1, 24, 2, 8, 32.65408247709274)
#
# Sat:  3 ,  0 ,  start
# (2020, 1, 31, 3, 33, 22.957914769649506)
#
# Sat:  3 ,  0 ,  end
# (2020, 1, 31, 6, 36, 31.863146424293518)
#
# Sat:  3 ,  0 ,  start
# (2020, 2, 7, 7, 58, 27.090479135513306)
#
# Sat:  3 ,  0 ,  end
# (2020, 2, 7, 11, 3, 24.97954934835434)
#
# Sat:  3 ,  0 ,  start
# (2020, 2, 14, 12, 22, 51.67254388332367)
#
# Sat:  3 ,  0 ,  end
# (2020, 2, 14, 15, 29, 35.90865343809128)
#
# Sat:  3 ,  0 ,  start
# (2020, 2, 21, 16, 45, 4.419355094432831)
#
# Sat:  3 ,  0 ,  end
# (2020, 2, 21, 19, 53, 30.608039796352386)
#
# Sat:  3 ,  0 ,  start
# (2020, 2, 28, 21, 5, 44.00260001420975)
#
# Sat:  3 ,  0 ,  end
# (2020, 2, 29, 0, 15, 47.7493554353714)
#
# Sat:  3 ,  1 ,  start
# (2020, 1, 2, 9, 11, 25.77769249677658)
#
# Sat:  3 ,  1 ,  end
# (2020, 1, 2, 12, 5, 12.185955047607422)
#
# Sat:  3 ,  1 ,  start
# (2020, 1, 9, 13, 11, 0.6217101216316223)
#
# Sat:  3 ,  1 ,  end
# (2020, 1, 9, 16, 5, 52.94757932424545)
#
# Sat:  3 ,  1 ,  start
# (2020, 1, 16, 17, 9, 44.48942005634308)
#
# Sat:  3 ,  1 ,  end
# (2020, 1, 16, 20, 5, 40.97515046596527)
#
# Sat:  3 ,  1 ,  start
# (2020, 1, 23, 21, 8, 16.931442618370056)
#
# Sat:  3 ,  1 ,  end
# (2020, 1, 24, 0, 5, 18.455886840820312)
#
# Sat:  3 ,  1 ,  start
# (2020, 1, 31, 1, 6, 49.54855978488922)
#
# Sat:  3 ,  1 ,  end
# (2020, 1, 31, 4, 4, 56.11167758703232)
#
# Sat:  3 ,  1 ,  start
# (2020, 2, 7, 5, 5, 31.658484041690826)
#
# Sat:  3 ,  1 ,  end
# (2020, 2, 7, 8, 4, 44.13920849561691)
#
# Sat:  3 ,  1 ,  start
# (2020, 2, 14, 9, 5, 1.229064166545868)
#
# Sat:  3 ,  1 ,  end
# (2020, 2, 14, 12, 5, 17.869649827480316)
#
# Sat:  3 ,  1 ,  start
# (2020, 2, 21, 13, 4, 4.432617723941803)
#
# Sat:  3 ,  1 ,  end
# (2020, 2, 21, 16, 5, 25.232984125614166)
#
# Sat:  3 ,  1 ,  start
# (2020, 2, 28, 17, 3, 39.27667558193207)
#
# Sat:  3 ,  1 ,  end
# (2020, 2, 28, 20, 6, 2.479037046432495)
#
# Sat:  4 ,  0 ,  start
# (2020, 1, 15, 14, 32, 21.161642968654633)
#
# Sat:  4 ,  0 ,  end
# (2020, 1, 15, 17, 9, 38.805725276470184)
#
# Sat:  4 ,  0 ,  start
# (2020, 2, 1, 11, 3, 55.7410803437233)
#
# Sat:  4 ,  0 ,  end
# (2020, 2, 1, 14, 1, 56.15190804004669)
#
# Sat:  4 ,  0 ,  start
# (2020, 2, 18, 7, 20, 14.505167305469513)
#
# Sat:  4 ,  0 ,  end
# (2020, 2, 18, 10, 36, 2.7812951803207397)
#
# Sat:  4 ,  1 ,  start
# (2020, 1, 15, 11, 26, 20.870577692985535)
#
# Sat:  4 ,  1 ,  end
# (2020, 1, 15, 13, 47, 35.238693952560425)
#
# Sat:  4 ,  1 ,  start
# (2020, 2, 1, 5, 24, 18.41020792722702)
#
# Sat:  4 ,  1 ,  end
# (2020, 2, 1, 7, 59, 11.035603880882263)
#
# Sat:  4 ,  1 ,  start
# (2020, 2, 17, 23, 22, 17.532489001750946)
#
# Sat:  4 ,  1 ,  end
# (2020, 2, 18, 2, 9, 36.520322263240814)

# %%
for timing in calc.timing_lists[3][1]:
    print("Sat: ", 4, ", ", "EC", ", ", timing[1])
    print(timing[2].get_full_date())
    print()
# Out:
# Sat:  4 ,  EC ,  start
# (2020, 1, 15, 11, 26, 20.870577692985535)
#
# Sat:  4 ,  EC ,  end
# (2020, 1, 15, 13, 47, 35.238693952560425)
#
# Sat:  4 ,  EC ,  start
# (2020, 2, 1, 5, 24, 18.41020792722702)
#
# Sat:  4 ,  EC ,  end
# (2020, 2, 1, 7, 59, 11.035603880882263)
#
# Sat:  4 ,  EC ,  start
# (2020, 2, 17, 23, 22, 17.532489001750946)
#
# Sat:  4 ,  EC ,  end
# (2020, 2, 18, 2, 9, 36.520322263240814)

# %%
for timing in calc.timing_lists[3][0]:
    print("Sat: ", 4, ", ", "OC", ", ", timing[1])
    print(timing[2].get_full_date())
    print()
# Out:
# Sat:  4 ,  OC ,  start
# (2020, 1, 15, 14, 32, 21.161642968654633)
#
# Sat:  4 ,  OC ,  end
# (2020, 1, 15, 17, 9, 38.805725276470184)
#
# Sat:  4 ,  OC ,  start
# (2020, 2, 1, 11, 3, 55.7410803437233)
#
# Sat:  4 ,  OC ,  end
# (2020, 2, 1, 14, 1, 56.15190804004669)
#
# Sat:  4 ,  OC ,  start
# (2020, 2, 18, 7, 20, 14.505167305469513)
#
# Sat:  4 ,  OC ,  end
# (2020, 2, 18, 10, 36, 2.7812951803207397)
