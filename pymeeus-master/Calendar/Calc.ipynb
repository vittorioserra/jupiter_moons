# %%
from typing import List, Tuple
from Calendar.Calculation import Calculation
from pymeeus.Epoch import Epoch
from pymeeus.JupiterMoons import JupiterMoons

import matplotlib.pyplot as plt

# %%
epoch_start = Epoch()
epoch_start.set(1992, 12, 1, 5 + 59 / 3600)
epoch_end = Epoch()
epoch_end.set(1992, 12, 31, 5 + 59 / 3600)
# 1 s in jd = 1.157401129603386e-05
time_step = 60 * 120 * 1.157401129603386e-05

calc = Calculation(epoch_start, epoch_end, time_step)
# Out:
# Coordinate Calculation finished
# Got rough timings
# Got exact timings

# %%
plt.plot(calc.distances[0][1])
plt.grid(True)
plt.ylim([0, 1])

print(len(calc.timing_list[0][1]))
print(calc.timing_list[0][1])
# Out:
# 33
# ...

# %%
epoch_start = Epoch()
epoch_start.set(1992, 12, 1, 5 + 59 / 3600)
epoch_end = Epoch()
epoch_end.set(1992, 12, 31, 5 + 59 / 3600)
# 1 s in jd = 1.157401129603386e-05
time_step = 60 * 150 * 1.157401129603386e-05

calc_4 = Calculation(epoch_start, epoch_end, time_step)
# Out:
# Coordinate Calculation finished
# Got rough timings
# Got exact timings

# %%
plt.plot(calc_4.distances[0][1])
plt.grid(True)
plt.ylim([0, 1])

print(len(calc_4.timing_list[0][1]))
print(calc_4.timing_list[0][1])
# Out:
# 33
# ...
