# %%
import numpy as np
import pandas as pd

from astropy.time import Time as ap_time

from datetime import datetime

# %%
jupiter_vsop87_elements_l0 = pd.read_csv('jupiter_l0.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
jupiter_vsop87_elements_l1 = pd.read_csv('jupiter_l1.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
jupiter_vsop87_elements_l2 = pd.read_csv('jupiter_l2.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
jupiter_vsop87_elements_l3 = pd.read_csv('jupiter_l3.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
jupiter_vsop87_elements_l4 = pd.read_csv('jupiter_l4.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
jupiter_vsop87_elements_l5 = pd.read_csv('jupiter_l5.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')

jupiter_vsop87_elements_b0 = pd.read_csv('jupiter_b0.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
jupiter_vsop87_elements_b1 = pd.read_csv('jupiter_b1.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
jupiter_vsop87_elements_b2 = pd.read_csv('jupiter_b2.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
jupiter_vsop87_elements_b3 = pd.read_csv('jupiter_b3.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
jupiter_vsop87_elements_b4 = pd.read_csv('jupiter_b4.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
jupiter_vsop87_elements_b5 = pd.read_csv('jupiter_b5.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')

jupiter_vsop87_elements_r0 = pd.read_csv('jupiter_r0.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
jupiter_vsop87_elements_r1 = pd.read_csv('jupiter_r1.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
jupiter_vsop87_elements_r2 = pd.read_csv('jupiter_r2.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
jupiter_vsop87_elements_r3 = pd.read_csv('jupiter_r3.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
jupiter_vsop87_elements_r4 = pd.read_csv('jupiter_r4.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
jupiter_vsop87_elements_r5 = pd.read_csv('jupiter_r5.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')


earth_vsop87_elements_l0 = pd.read_csv('earth_l0.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
earth_vsop87_elements_l1 = pd.read_csv('earth_l1.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
earth_vsop87_elements_l2 = pd.read_csv('earth_l2.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
earth_vsop87_elements_l3 = pd.read_csv('earth_l3.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
earth_vsop87_elements_l4 = pd.read_csv('earth_l4.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
earth_vsop87_elements_l5 = pd.read_csv('earth_l5.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')

earth_vsop87_elements_b0 = pd.read_csv('earth_b0.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
earth_vsop87_elements_b1 = pd.read_csv('earth_b1.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
earth_vsop87_elements_b2 = pd.read_csv('earth_b2.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
earth_vsop87_elements_b3 = pd.read_csv('earth_b3.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
earth_vsop87_elements_b4 = pd.read_csv('earth_b4.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')

earth_vsop87_elements_r0 = pd.read_csv('earth_r0.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
earth_vsop87_elements_r1 = pd.read_csv('earth_r1.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
earth_vsop87_elements_r2 = pd.read_csv('earth_r2.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
earth_vsop87_elements_r3 = pd.read_csv('earth_r3.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
earth_vsop87_elements_r4 = pd.read_csv('earth_r4.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')
earth_vsop87_elements_r5 = pd.read_csv('earth_r5.csv', sep='\s+|[0-9]+-[0-9]+', header = None , skiprows = 1, engine = 'python')


pd.set_option('display.max_rows', earth_vsop87_elements_l0.shape[0]+1)
print(earth_vsop87_elements_l0.loc[:, [16,17,18]])
# Out:
#                16        17             18
# 0    1.753470e+00  0.000000       0.000000
# 1    3.341656e-02  4.669257    6283.075850
# 2    3.489428e-04  4.626102   12566.151700
# 3    3.417571e-05  2.828866       3.523118
# 4    3.497056e-05  2.744118    5753.384885
# 5    3.135896e-05  3.627670   77713.771468
# 6    2.676218e-05  4.418084    7860.419392
# 7    2.342687e-05  6.135162    3930.209696
# 8    1.273166e-05  2.037097     529.690965
# 9    1.324292e-05  0.742464   11506.769770
# 10   9.018550e-06  2.045054      26.298320
# 11   1.199167e-05  1.109629    1577.343542
# 12   8.572230e-06  3.508492     398.149003
# 13   7.797860e-06  1.178827    5223.693920
# 14   9.902500e-06  5.232681    5884.926847
# 15   7.531410e-06  2.533391    5507.553239
# 16   5.052640e-06  4.582926   18849.227550
# 17   4.923790e-06  4.205066     775.522611
# 18   3.566550e-06  2.919541       0.067310
# 19   2.841250e-06  1.898690     796.298007
# 20   2.428100e-06  0.344811    5486.777843
# 21   3.170870e-06  5.849020   11790.629089
# 22   2.710390e-06  0.314886   10977.078805
# 23   2.061600e-06  4.806466    2544.314420
# 24   2.053850e-06  1.869478    5573.142801
# 25   2.022610e-06  2.457678    6069.776755
# 26   1.261840e-06  1.083026      20.775395
# 27   1.555160e-06  0.833061     213.299095
# 28   1.151320e-06  0.645449       0.980321
# 29   1.028510e-06  0.635998    4694.002955
# 30   1.017240e-06  4.266798       7.113547
# 31   9.920600e-07  6.209929    2146.165416
# 32   1.322120e-06  3.411183    2942.463423
# 33   9.760700e-07  0.681013     155.420399
# 34   8.512800e-07  1.298707    6275.962303
# 35   7.465100e-07  1.755089    5088.628840
# 36   1.018950e-06  0.975692   15720.838785
# 37   8.471100e-07  3.670801   71430.695618
# 38   7.354700e-07  4.679266     801.820931
# 39   7.387400e-07  3.503194    3154.687085
# 40   7.875600e-07  3.036983   12036.460735
# 41   7.963700e-07  1.807913   17260.154655
# 42   8.580300e-07  5.983226  161000.685738
# 43   5.696300e-07  2.784304    6286.598968
# 44   6.114800e-07  1.818398    7084.896781
# 45   6.962700e-07  0.832976    9437.762935
# 46   5.611600e-07  4.386949   14143.495242
# 47   6.244900e-07  3.977639    8827.390270
# 48   5.114500e-07  0.283069    5856.477659
# 49   5.557700e-07  3.470060    6279.552732
# 50   4.103600e-07  5.368174    8429.241266
# 51   5.160500e-07  1.332827    1748.016413
# 52   5.199200e-07  0.189149   12139.553509
# 53   4.900000e-07  0.487351    1194.447010
# 54   3.920000e-07  6.168330   10447.387840
# 55   3.556600e-07  1.775973    6812.766815
# 56   3.677000e-07  6.041339   10213.285546
# 57   3.659600e-07  2.569552    1059.381930
# 58   3.329100e-07  0.593095   17789.845620
# 59   3.595400e-07  1.708761    2352.866154
# 60   4.093800e-07  2.398509   19651.048481
# 61   3.004700e-07  2.739751    1349.867410
# 62   3.041200e-07  0.442945   83996.847318
# 63   2.366300e-07  0.484736    8031.092263
# 64   2.357400e-07  2.065277    3340.612427
# 65   2.108900e-07  4.148255     951.718406
# 66   2.473800e-07  0.214848       3.590429
# 67   2.535200e-07  3.164710    4690.479836
# 68   2.282000e-07  5.221979    4705.732308
# 69   2.141900e-07  1.425637   16730.463690
# 70   2.189100e-07  5.555943     553.569403
# 71   1.748100e-07  4.560529     135.065080
# 72   1.992500e-07  5.222085   12168.002697
# 73   1.986000e-07  5.774702    6309.374170
# 74   2.030000e-07  0.371338     283.859319
# 75   1.442100e-07  4.193153     242.728604
# 76   1.622500e-07  5.988377   11769.853693
# 77   1.507700e-07  4.195672    6256.777530
# 78   1.912400e-07  3.822200   23581.258177
# 79   1.888800e-07  5.386269  149854.400135
# 80   1.434600e-07  3.723551      38.027673
# 81   1.789800e-07  2.214907   13367.972631
# 82   1.205400e-07  2.622296     955.599742
# 83   1.128700e-07  0.177393    4164.311990
# 84   1.397100e-07  4.401381    6681.224853
# 85   1.362100e-07  1.889345    7632.943260
# 86   1.250300e-07  1.130524       5.522924
# 87   1.049800e-07  5.359095    1592.596014
# 88   9.803000e-08  0.999475   11371.704690
# 89   9.220000e-08  4.571386    4292.330833
# 90   1.032700e-07  6.199826    6438.496249
# 91   1.200300e-07  1.003515     632.783739
# 92   1.082700e-07  0.327345     103.092774
# 93   8.356000e-08  4.539027   25132.303400
# 94   1.000500e-07  6.029150    5746.271338
# 95   8.409000e-08  3.299467    7234.794256
# 96   8.006000e-08  5.821453      28.449187
# 97   1.052300e-07  0.938718   11926.254414
# 98   7.686000e-08  3.121424    7238.675592
# 99   9.378000e-08  2.624142    5760.498432
# 100  8.127000e-08  6.112280    4732.030627
# 101  9.232000e-08  0.483440     522.577418
# 102  9.802000e-08  5.244140   27511.467874
# 103  7.871000e-08  0.995902    5643.178564
# 104  8.123000e-08  6.270530     426.598191
# 105  9.048000e-08  5.336863    6386.168624
# 106  8.620000e-08  4.165382    7058.598461
# 107  6.297000e-08  4.717248    6836.645253
# 108  7.575000e-08  3.973829   11499.656223
# 109  7.756000e-08  2.957291   23013.539540
# 110  7.314000e-08  0.606525   11513.883317
# 111  5.955000e-08  2.876410    6283.143160
# 112  6.534000e-08  5.790729   18073.704939
# 113  7.188000e-08  3.998315      74.781599
# 114  7.346000e-08  4.385824     316.391870
# 115  5.413000e-08  5.391990     419.484644
# 116  5.127000e-08  2.360628   10973.555686
# 117  7.056000e-08  0.322584     263.083923
# 118  6.625000e-08  3.664752   17298.182327
# 119  6.762000e-08  5.911325   90955.551694
# 120  4.938000e-08  5.736722    9917.696875
# 121  5.547000e-08  2.451526   12352.852605
# 122  5.958000e-08  3.320513    6283.008540
# 123  4.471000e-08  2.063860    7079.373857
# 124  6.153000e-08  1.458233  233141.314404
# 125  4.348000e-08  4.423422    5216.580373
# 126  6.123000e-08  1.074949   19804.827292
# 127  4.488000e-08  3.652850     206.185548
# 128  4.020000e-08  0.839958      20.355319
# 129  5.188000e-08  4.065039    6208.294251
# 130  5.307000e-08  0.382176   31441.677570
# 131  3.785000e-08  2.343692       3.881335
# 132  4.497000e-08  3.272308   11015.106477
# 133  4.132000e-08  0.921289    3738.761430
# 134  3.521000e-08  5.978448    3894.181830
# 135  4.215000e-08  1.906011     245.831646
# 136  3.701000e-08  5.030694     536.804512
# 137  3.865000e-08  1.826344   11856.218651
# 138  3.652000e-08  1.018386   16200.772725
# 139  3.390000e-08  0.977851    8635.942004
# 140  3.737000e-08  2.953801    3128.388765
# 141  3.507000e-08  3.712919    6290.189397
# 142  3.086000e-08  3.646469      10.636665
# 143  3.397000e-08  1.105907   14712.317116
# 144  3.334000e-08  0.836849    6496.374945
# 145  2.805000e-08  2.585045   14314.168113
# 146  3.650000e-08  1.083441   88860.057071
# 147  3.388000e-08  3.201851    5120.601146
# 148  3.252000e-08  3.478598    6133.512653
# 149  2.553000e-08  3.948690    1990.745017
# 150  3.520000e-08  2.055597  244287.600007
# 151  2.565000e-08  1.560718   23543.230505
# 152  2.621000e-08  3.856394     266.607042
# 153  2.955000e-08  3.396929    9225.539273
# 154  2.876000e-08  6.026356  154717.609888
# 155  2.395000e-08  1.161320   10984.192352
# 156  3.161000e-08  1.327987   10873.986030
# 157  3.163000e-08  5.089465   21228.392024
# 158  2.361000e-08  4.272129    6040.347246
# 159  3.030000e-08  1.802099   35371.887266
# 160  2.343000e-08  3.576899   10969.965258
# 161  2.618000e-08  2.578702   22483.848574
# 162  2.113000e-08  3.713938   65147.619768
# 163  2.019000e-08  0.813939     170.672871
# 164  2.003000e-08  0.380910    6172.869529
# 165  2.506000e-08  3.743791   10575.406683
# 166  2.381000e-08  0.105814       7.046237
# 167  1.949000e-08  4.868925      36.027867
# 168  2.074000e-08  4.227948    5650.292111
# 169  1.924000e-08  5.594605    6282.095529
# 170  1.949000e-08  1.070025    5230.807467
# 171  1.988000e-08  5.197360    6262.300454
# 172  1.887000e-08  3.743657      23.878438
# 173  1.787000e-08  1.259297   12559.038153
# 174  1.883000e-08  1.903641      15.252471
# 175  1.816000e-08  3.680839   15110.466120
# 176  1.701000e-08  4.411059     110.206321
# 177  1.990000e-08  3.932958    6206.809779
# 178  2.103000e-08  0.753549   13521.751442
# 179  1.774000e-08  0.487475    1551.045223
# 180  1.882000e-08  0.866845   22003.914635
# 181  1.924000e-08  1.228983     709.933049
# 182  2.009000e-08  4.628509    6037.244204
# 183  1.924000e-08  0.602318    6284.056171
# 184  1.596000e-08  3.983330   13916.019110
# 185  1.664000e-08  4.419397    8662.240324
# 186  1.971000e-08  1.045605   18209.330264
# 187  1.942000e-08  4.313360    6244.942814
# 188  1.476000e-08  0.932714    2379.164474
# 189  1.810000e-08  0.491121       1.484473
# 190  1.346000e-08  1.515747    4136.910434
# 191  1.528000e-08  5.618357    6127.655451
# 192  1.791000e-08  3.221873   39302.096962
# 193  1.747000e-08  3.056387   18319.536585
# 194  1.431000e-08  4.511538   20426.571092
# 195  1.695000e-08  0.220477   25158.601720
# 196  1.242000e-08  4.466658   17256.631536
# 197  1.463000e-08  4.692427   14945.316174
# 198  1.205000e-08  1.869121    4590.910180
# 199  1.192000e-08  2.742272   12569.674818
# 200  1.222000e-08  5.181201    5333.900241
# 201  1.390000e-08  5.428946  143571.324285
# 202  1.473000e-08  1.704792   11712.955318
# 203  1.362000e-08  2.610695    6062.663208
# 204  1.148000e-08  6.030018    3634.621025
# 205  1.198000e-08  5.152941   10177.257680
# 206  1.266000e-08  0.114215   18422.629359
# 207  1.411000e-08  1.099089    3496.032826
# 208  1.349000e-08  2.998051   17654.780540
# 209  1.253000e-08  2.798502  167283.761588
# 210  1.311000e-08  1.609430    5481.254919
# 211  1.079000e-08  6.203045       3.286357
# 212  1.181000e-08  1.206538     131.541962
# 213  1.254000e-08  5.451033    6076.890302
# 214  1.035000e-08  2.321427    7342.457780
# 215  1.117000e-08  0.388384     949.175609
# 216  9.660000e-09  3.183419   11087.285126
# 217  1.171000e-08  3.396350   12562.628582
# 218  1.121000e-08  0.726275     220.412642
# 219  1.024000e-08  2.193783   11403.676996
# 220  8.880000e-09  3.911732    4686.889408
# 221  9.100000e-09  1.988027     735.876514
# 222  8.300000e-09  0.489849   24072.921470
# 223  1.096000e-08  6.173778    5436.993015
# 224  9.080000e-09  0.449596    7477.522860
# 225  9.740000e-09  1.529962    9623.688277
# 226  8.400000e-09  1.795433    5429.879468
# 227  7.780000e-09  6.176992      38.133036
# 228  7.760000e-09  4.098554      14.227094
# 229  1.068000e-08  4.642002   43232.306658
# 230  9.540000e-09  1.499884    1162.474704
# 231  9.070000e-09  0.869869   10344.295065
# 232  9.310000e-09  4.060447   28766.924424
# 233  7.390000e-09  5.043682     639.897286
# 234  9.370000e-09  3.468847    1589.072895
# 235  7.630000e-09  5.863049   16858.482533
# 236  9.530000e-09  4.208015   11190.377900
# 237  7.080000e-09  1.729000   13095.842665
# 238  9.690000e-09  1.644395   29088.811416
# 239  7.170000e-09  0.166887      11.729353
# 240  9.620000e-09  3.530923   12416.588503
# 241  7.470000e-09  5.778669   12592.450020
# 242  6.720000e-09  1.910958       3.932153
# 243  6.710000e-09  5.462408   18052.929543
# 244  6.750000e-09  6.283116    4535.059437
# 245  6.840000e-09  0.399750    5849.364112
# 246  7.990000e-09  0.298512   12132.439962
# 247  7.580000e-09  0.963708    1052.268383
# 248  7.820000e-09  5.338783   13517.870106
# 249  7.300000e-09  1.701062   17267.268202
# 250  7.490000e-09  2.595999   11609.862544
# 251  7.340000e-09  2.784178     640.877607
# 252  6.880000e-09  5.150483   16496.361396
# 253  7.700000e-09  1.624696    4701.116502
# 254  6.330000e-09  2.205879   25934.124331
# 255  7.600000e-09  4.213172     377.373608
# 256  5.840000e-09  2.134201   10557.594161
# 257  5.740000e-09  0.242501    9779.108676
# 258  5.730000e-09  3.164353     533.214083
# 259  6.850000e-09  3.193443   12146.667056
# 260  6.750000e-09  0.961792   10454.501387
# 261  6.480000e-09  1.463273    6268.848756
# 262  5.890000e-09  2.505435    3097.883823
# 263  5.510000e-09  5.280990    9388.005909
# 264  6.960000e-09  3.653422    4804.209276
# 265  6.690000e-09  2.510301    2388.894020
# 266  5.500000e-09  0.068839   20199.094960
# 267  6.290000e-09  4.133510   45892.730433
# 268  6.780000e-09  6.091902     135.625325
# 269  5.930000e-09  1.501363  226858.238554
# 270  5.420000e-09  3.585736    6148.010770
# 271  6.820000e-09  5.022031   17253.041108
# 272  5.650000e-09  4.293092   11933.367961
# 273  4.860000e-09  0.777462      27.401556
# 274  5.030000e-09  0.589636   15671.081759
# 275  6.160000e-09  4.065399     227.476133
# 276  5.830000e-09  6.126955   18875.525870
# 277  5.370000e-09  2.150564   21954.157609
# 278  6.690000e-09  6.069863   47162.516355
# 279  4.750000e-09  0.403438    6915.859589
# 280  5.400000e-09  2.834442    5326.786694
# 281  5.300000e-09  5.263599   10988.808158
# 282  5.820000e-09  3.245331     153.778810
# 283  6.410000e-09  3.247118    2107.034508
# 284  6.210000e-09  3.096985   33019.021112
# 285  4.660000e-09  3.149824   10440.274293
# 286  4.660000e-09  0.907088    5966.683980
# 287  5.280000e-09  0.819265     813.550284
# 288  6.030000e-09  3.813789  316428.228674
# 289  5.590000e-09  1.818948   17996.031168
# 290  4.370000e-09  2.286256    6303.851245
# 291  5.180000e-09  4.860692   20597.243963
# 292  4.240000e-09  6.235200    6489.261398
# 293  5.180000e-09  6.176178       0.243817
# 294  4.040000e-09  5.728043    5642.198243
# 295  4.580000e-09  1.341178    6287.008003
# 296  5.480000e-09  5.684545  155427.542936
# 297  5.470000e-09  1.033915    3646.350377
# 298  4.280000e-09  4.698010     846.082835
# 299  4.130000e-09  6.025207    6279.485421
# 300  5.340000e-09  3.030306   66567.485865
# 301  3.830000e-09  1.490569   19800.945956
# 302  4.100000e-09  5.283196   18451.078547
# 303  3.520000e-09  4.688916    4907.302050
# 304  4.800000e-09  5.365727     348.924420
# 305  3.440000e-09  5.891575    6546.159773
# 306  3.400000e-09  0.375574   13119.721103
# 307  4.340000e-09  4.984178    6702.560494
# 308  3.320000e-09  2.689025   29296.615390
# 309  4.480000e-09  2.164785    5905.702242
# 310  3.440000e-09  2.065466      49.757025
# 311  3.150000e-09  1.240238    4061.219215
# 312  3.240000e-09  2.308975    5017.508371
# 313  4.130000e-09  0.171717    6286.666279
# 314  4.310000e-09  3.866011   12489.885629
# 315  3.490000e-09  4.553723    4933.208440
# 316  3.230000e-09  0.419711   10770.893256
# 317  3.410000e-09  2.686129      11.045700
# 318  3.160000e-09  3.529369   17782.732073
# 319  3.150000e-09  5.633573     568.821874
# 320  3.400000e-09  3.835712   10660.686935
# 321  2.970000e-09  0.626914   20995.392966
# 322  4.050000e-09  1.000858   16460.333530
# 323  4.140000e-09  1.219988   51092.726051
# 324  3.360000e-09  4.714659    6179.983076
# 325  3.610000e-09  3.712275   28237.233459
# 326  3.850000e-09  6.219252   24356.780789
# 327  3.270000e-09  1.056065   11919.140867
# 328  3.270000e-09  6.142224    6254.626663
# 329  2.680000e-09  2.472243     664.756045
# 330  2.690000e-09  1.862079   23141.558383
# 331  3.450000e-09  0.934613    6058.731054
# 332  2.960000e-09  4.516876    6418.140930
# 333  3.530000e-09  4.500337   36949.230808
# 334  2.600000e-09  4.049635    6525.804454
# 335  2.980000e-09  2.200467  156137.475985
# 336  2.530000e-09  3.499008   29864.334027
# 337  2.540000e-09  2.449017    5331.357444
# 338  2.960000e-09  0.843476    5729.506447
# 339  2.980000e-09  1.291947   22805.735566
# 340  2.410000e-09  2.007213   16737.577237
# 341  3.110000e-09  1.236680    6281.591377
# 342  2.400000e-09  2.516504    6245.048177
# 343  3.320000e-09  3.555769    7668.637425
# 344  2.640000e-09  4.440521   12964.300703
# 345  2.570000e-09  1.796545   11080.171579
# 346  2.600000e-09  3.330776    5888.449965
# 347  2.850000e-09  0.308864   11823.161639
# 348  2.900000e-09  5.701419      77.673770
# 349  2.550000e-09  4.009397    5881.403728
# 350  2.530000e-09  4.733185   16723.350143
# 351  2.280000e-09  0.953337    5540.085789
# 352  3.190000e-09  1.386332  163096.180361
# 353  2.240000e-09  1.651563   10027.903196
# 354  2.260000e-09  0.341065   17796.959167
# 355  2.360000e-09  4.198174      19.669761
# 356  2.800000e-09  4.140803   12539.853380
# 357  2.750000e-09  5.503069      32.532551
# 358  2.230000e-09  5.233342      56.898375
# 359  2.170000e-09  6.085879    6805.653268
# 360  2.800000e-09  4.524720    6016.468808
# 361  2.270000e-09  5.065098    6277.552926
# 362  2.260000e-09  5.177552   11720.068865
# 363  2.450000e-09  3.964863      22.775201
# 364  2.200000e-09  4.720781       6.628559
# 365  2.070000e-09  5.717014      41.550791
# 366  2.040000e-09  3.912274    2699.734819
# 367  2.090000e-09  0.868820    6321.103523
# 368  2.000000e-09  2.119844    4274.518311
# 369  2.000000e-09  5.398399    6019.991927
# 370  2.090000e-09  5.676063   11293.470674
# 371  2.520000e-09  1.649657    9380.959673
# 372  2.750000e-09  5.048269      73.297126
# 373  2.080000e-09  1.882073   11300.584221
# 374  2.720000e-09  0.746409    1975.492546
# 375  1.990000e-09  3.308367   22743.409380
# 376  2.690000e-09  4.485608   64471.991242
# 377  1.920000e-09  2.174642    5863.591206
# 378  2.280000e-09  5.853731     128.018843
# 379  2.610000e-09  2.643212   55022.935747
# 380  2.200000e-09  5.750121      29.429509
# 381  1.870000e-09  4.032306     467.964990
# 382  2.000000e-09  5.605561    1066.495477
# 383  2.310000e-09  1.098027   12341.806904
# 384  1.990000e-09  0.295006     149.563197
# 385  2.490000e-09  5.104732    7875.671864
# 386  2.080000e-09  0.930138   14919.017854
# 387  1.790000e-09  0.871044   12721.572099
# 388  2.030000e-09  1.569208   28286.990485
# 389  1.790000e-09  2.470364   16062.184526
# 390  1.980000e-09  3.540616      30.914126
# 391  1.710000e-09  3.453565    5327.476108
# 392  1.830000e-09  0.723254    6272.030150
# 393  2.160000e-09  2.971746   19402.796953
# 394  1.680000e-09  2.515506   23937.856390
# 395  1.950000e-09  0.090454     156.400721
# 396  1.790000e-09  4.494718   31415.379250
# 397  2.160000e-09  0.421776   23539.707386
# 398  1.890000e-09  0.375425    9814.604100
# 399  2.180000e-09  2.368359   16627.370915
# 400  1.660000e-09  4.231830   16840.670011
# 401  2.000000e-09  2.021533   16097.679950
# 402  1.690000e-09  0.913187      95.979227
# 403  2.110000e-09  5.733706     151.897281
# 404  2.040000e-09  0.426431     515.463871
# 405  2.120000e-09  3.002335   12043.574282
# 406  1.920000e-09  5.461536    6379.055077
# 407  1.650000e-09  1.386982    4171.425537
# 408  1.600000e-09  6.237984     202.253395
# 409  2.150000e-09  0.208891    5621.842923
# 410  1.810000e-09  4.124392   13341.674311
# 411  1.530000e-09  1.244608   29826.306355
# 412  1.500000e-09  3.129998     799.821125
# 413  1.750000e-09  4.556716  239424.390254
# 414  1.920000e-09  1.339288     394.625885
# 415  1.490000e-09  2.656976      21.335640
# 416  1.460000e-09  5.580212     412.371097
# 417  1.560000e-09  3.756502   12323.423096
# 418  1.430000e-09  3.757086   58864.543918
# 419  1.430000e-09  3.282485      29.821438
# 420  1.440000e-09  1.078625    1265.567479
# 421  1.480000e-09  0.233892   10021.837280
# 422  1.930000e-09  5.927511   40879.440505
# 423  1.400000e-09  4.976124     158.943518
# 424  1.480000e-09  2.616405   17157.061880
# 425  1.410000e-09  3.668713   26084.021806
# 426  1.470000e-09  5.099682     661.232927
# 427  1.460000e-09  4.968856   57375.801901
# 428  1.420000e-09  0.786783   12779.450795
# 429  1.340000e-09  4.794326     111.186642
# 430  1.400000e-09  1.277480     107.663524
# 431  1.690000e-09  2.748935   26735.945262
# 432  1.650000e-09  3.952880    6357.857449
# 433  1.830000e-09  5.434184     369.699816
# 434  1.340000e-09  3.091329      17.812522
# 435  1.320000e-09  3.056339   22490.962121
# 436  1.340000e-09  4.094728    6599.467720
# 437  1.810000e-09  4.229507     966.970877
# 438  1.520000e-09  5.288859   12669.244474
# 439  1.500000e-09  5.868194   97238.627544
# 440  1.420000e-09  5.872665   22476.735027
# 441  1.450000e-09  5.073308      87.308205
# 442  1.330000e-09  5.654711      31.972306
# 443  1.240000e-09  2.833262   12566.219010
# 444  1.350000e-09  3.128617   32217.200181
# 445  1.370000e-09  0.864875    9924.810422
# 446  1.720000e-09  1.983696  174242.465964
# 447  1.700000e-09  4.411153  327574.514277
# 448  1.510000e-09  0.465421   39609.654583
# 449  1.480000e-09  2.134396     491.663292
# 450  1.530000e-09  3.788018   17363.247429
# 451  1.650000e-09  5.316541   16943.762785
# 452  1.650000e-09  4.067476   58953.145443
# 453  1.180000e-09  0.638463       6.065916
# 454  1.590000e-09  0.860870  221995.028801
# 455  1.190000e-09  5.964329    1385.895276
# 456  1.140000e-09  5.165161   25685.872803
# 457  1.120000e-09  3.394037   21393.541970
# 458  1.120000e-09  4.928892      56.803262
# 459  1.190000e-09  2.406376   18635.928455
# 460  1.150000e-09  0.233745     418.924399
# 461  1.220000e-09  0.935752   24492.406114
# 462  1.150000e-09  4.588800   26709.646942
# 463  1.300000e-09  4.855393   22345.260376
# 464  1.400000e-09  1.094131   44809.650201
# 465  1.120000e-09  6.054018     433.711738
# 466  1.040000e-09  1.549315     127.951533
# 467  1.050000e-09  4.826209   33794.543724
# 468  1.020000e-09  4.124485   15664.035523
# 469  1.070000e-09  4.679194   77690.759506
# 470  1.180000e-09  4.523202   19004.647949
# 471  1.070000e-09  5.717745   77736.783431
# 472  1.430000e-09  1.812018    4214.069015
# 473  1.250000e-09  1.144192     625.670192
# 474  1.240000e-09  3.277365   12566.084390
# 475  1.100000e-09  1.086826    2787.043024
# 476  1.050000e-09  1.783181   18139.294501
# 477  1.020000e-09  4.751196   12242.646283
# 478  1.370000e-09  1.435106   86464.613317
# 479  1.010000e-09  4.912894     401.672122
# 480  1.290000e-09  1.235679   12029.347188
# 481  1.380000e-09  2.456547    7576.560074
# 482  1.030000e-09  0.400041   90279.923168
# 483  1.080000e-09  0.989898    5636.065017
# 484  1.170000e-09  5.173629   34520.309309
# 485  1.000000e-09  3.955346    5547.199336
# 486  9.800000e-10  1.281183   21548.962369
# 487  9.700000e-10  3.347171   16310.979046
# 488  9.800000e-10  4.370419   34513.263073
# 489  1.250000e-09  2.721644   24065.807923
# 490  1.020000e-09  0.669380   10239.583866
# 491  1.190000e-09  1.216895    1478.866574
# 492  9.400000e-10  1.995952   13362.449707
# 493  9.400000e-10  4.309660   26880.319813
# 494  9.500000e-10  2.898077   34911.412076
# 495  1.060000e-09  1.001567   16522.659716
# 496  9.700000e-10  0.896423   71980.633575
# 497  1.160000e-09  4.199672     206.700737
# 498  9.900000e-10  1.374378    1039.026611
# 499  1.260000e-09  3.216425  305281.943071
# 500  9.400000e-10  0.689979    7834.121073
# 501  9.400000e-10  5.581322    3104.930059
# 502  9.500000e-10  3.038237    8982.810669
# 503  1.080000e-09  0.526966     276.745772
# 504  1.240000e-09  3.438999  172146.971341
# 505  1.020000e-09  1.040317   95143.132921
# 506  1.040000e-09  3.392186     290.972866
# 507  1.100000e-09  3.682059   22380.755800
# 508  1.170000e-09  0.784760   83286.914270
# 509  8.300000e-10  0.182418   15141.390794
# 510  8.900000e-10  4.453718     792.774888
# 511  8.200000e-10  4.807037    6819.880362
# 512  8.700000e-10  3.431229   27707.542494
# 513  1.010000e-09  5.320816    2301.585816
# 514  8.200000e-10  0.870601   10241.202291
# 515  8.600000e-10  4.619195   36147.409877
# 516  9.500000e-10  2.870329   23020.653087
# 517  8.800000e-10  3.211332   33326.578733
# 518  8.000000e-10  1.849004   21424.466644
# 519  1.010000e-09  4.187964   30666.154958
# 520  1.070000e-09  5.778649   34115.114069
# 521  1.040000e-09  1.087395    6288.598774
# 522  1.100000e-09  3.328989   72140.628667
# 523  8.700000e-10  4.406577     142.178627
# 524  1.090000e-09  1.945460   24279.107018
# 525  8.700000e-10  4.324720     742.990061
# 526  1.070000e-09  4.915809     277.034994
# 527  8.800000e-10  2.101802   26482.170810
# 528  8.600000e-10  4.018874   12491.370101
# 529  1.060000e-09  5.490924   62883.355140
# 530  8.000000e-10  6.197813    6709.674041
# 531  8.800000e-10  2.098728  238004.524157
# 532  8.300000e-10  4.906622      51.280338
# 533  9.500000e-10  4.133874   18216.443811
# 534  7.800000e-10  6.069494  148434.534038
# 535  7.900000e-10  3.030482     838.969288
# 536  7.400000e-10  5.498131   29026.485230
# 537  7.300000e-10  3.050087     567.718638
# 538  8.400000e-10  0.466044      45.141220
# 539  9.300000e-10  2.522675   48739.859897
# 540  7.600000e-10  1.764181   41654.963116
# 541  6.700000e-10  5.778512    6311.525037
# 542  6.200000e-10  3.329679   15508.615123
# 543  7.900000e-10  5.597738   71960.386583
# 544  5.700000e-10  3.906295    5999.216531
# 545  6.100000e-10  0.056950    7856.896274
# 546  6.100000e-10  5.632980    7863.942511
# 547  6.500000e-10  3.721784   12573.265247
# 548  5.700000e-10  4.182172   26087.903142
# 549  6.600000e-10  3.922623   69853.352076
# 550  5.300000e-10  5.511194   77710.248350
# 551  5.300000e-10  4.885740   77717.294586
# 552  6.200000e-10  2.888763    9411.464615
# 553  5.100000e-10  1.126572   82576.981221
# 554  4.500000e-10  2.956711   24602.612435
# 555  4.000000e-10  5.551457   12565.171379
# 556  3.900000e-10  1.208382   18842.114003
# 557  4.500000e-10  3.185906   45585.172812
# 558  4.900000e-10  2.447909   13613.804277

# %%
curr_time = datetime.now()

datestr = (str(curr_time.year) +"-"+ str(curr_time.month) +"-"+ str(curr_time.day) +"T"+ 
          str(curr_time.hour) +":"+ str(curr_time.minute) +":"+ str(curr_time.second))


datestr = "1992-12-16T00:00:00"


t = ap_time(datestr)

# %%
curr_julian_day = t.jd
curr_mean_sidereal_time = t.sidereal_time('mean', 'greenwich')

print("current julian day : " + str(curr_julian_day))
print("current mean sidereal time : " + str(curr_mean_sidereal_time))
# Out:
# current julian day : 2448972.5
# current mean sidereal time : 5h39m31.9685s

# %%
#clculate tau in julian millenia since J2000.0

tau = (curr_julian_day-2451545.0)/365250.0
T = (curr_julian_day-2451545.0)/36525.0

# %%
#step 1 : d = JDE - 2433282.5 ; T_1 = d / 36525

d = curr_julian_day - 2433282.5 

print("d : " + str(d))

T_1 = d / 36525

print("T_1 : "+ str(T_1))

#RA and DEC of Jupiter's north pole for 1985

alpha_0_deg = 268 + 0.1061*T_1
delta_0_deg = 64.5 - 0.0164*T_1

print("alpha_zero_deg : "+ str(alpha_0_deg))
print("delta_zero_deg : "+ str(delta_0_deg))
# Out:
# d : 15690.0
# T_1 : 0.4295687885010267
# alpha_zero_deg : 268.04557724845995
# delta_zero_deg : 64.49295507186858

# %%
#step 2 : 

W_1_deg = 17.71 + 877.90003539*d
W_2_deg = 16.838 + 870.27003539*d

#nor values to 0--360

while(W_1_deg > 360 or W_1_deg < 0):
    if(W_1_deg > 360):
        W_1_deg = W_1_deg - 360;
        
    if(W_1_deg <0 ):
        W_1_deg = W_1_deg + 360;


while(W_2_deg > 360 or W_2_deg < 0 ):
    
    if(W_2_deg > 360):
        W_2_deg = W_2_deg - 360;
    else:
        W_2_deg = W_2_deg + 360

    
print("W_1_deg : "+str(W_1_deg))
print("W_2_deg : "+str(W_2_deg))
# Out:
# W_1_deg : 309.26526910066605
# W_2_deg : 113.6932691000402

# %%
#heliocentric longitude, latitue and radius vector of the earth (l_0, b_0, R)

# A = col 16, B = col 17, C = col 18

#print(earth_vsop87_elements_l0.loc[:, 18]);
#print("----- tau : "+ str(tau))
#print(earth_vsop87_elements_l0.loc[:, 18]*tau);

l_0_earth = earth_vsop87_elements_l0.loc[:, 16] * np.cos(earth_vsop87_elements_l0.loc[:, 17] + earth_vsop87_elements_l0.loc[:, 18]*tau)
l_1_earth = earth_vsop87_elements_l1.loc[:, 16] * np.cos(earth_vsop87_elements_l1.loc[:, 17] + earth_vsop87_elements_l1.loc[:, 18]*tau)
l_2_earth = earth_vsop87_elements_l2.loc[:, 16] * np.cos(earth_vsop87_elements_l2.loc[:, 17] + earth_vsop87_elements_l2.loc[:, 18]*tau)
l_3_earth = earth_vsop87_elements_l3.loc[:, 16] * np.cos(earth_vsop87_elements_l3.loc[:, 17] + earth_vsop87_elements_l3.loc[:, 18]*tau)
l_4_earth = earth_vsop87_elements_l4.loc[:, 16] * np.cos(earth_vsop87_elements_l4.loc[:, 17] + earth_vsop87_elements_l4.loc[:, 18]*tau)
l_5_earth = earth_vsop87_elements_l5.loc[:, 16] * np.cos(earth_vsop87_elements_l5.loc[:, 17] + earth_vsop87_elements_l5.loc[:, 18]*tau)

L_earth = (np.sum(l_0_earth) + np.sum(l_1_earth)*tau + np.sum(l_2_earth)*(tau**2) + np.sum(l_3_earth)*(tau**3)
          + np.sum(l_4_earth)*(tau**4) + np.sum(l_5_earth)*(tau**5))

b_0_earth = earth_vsop87_elements_b0.loc[:, 16] * np.cos(earth_vsop87_elements_b0.loc[:, 17] + earth_vsop87_elements_b0.loc[:, 18]*tau)
b_1_earth = earth_vsop87_elements_b1.loc[:, 16] * np.cos(earth_vsop87_elements_b1.loc[:, 17] + earth_vsop87_elements_b1.loc[:, 18]*tau)
b_2_earth = earth_vsop87_elements_b2.loc[:, 16] * np.cos(earth_vsop87_elements_b2.loc[:, 17] + earth_vsop87_elements_b2.loc[:, 18]*tau)
b_3_earth = earth_vsop87_elements_b3.loc[:, 16] * np.cos(earth_vsop87_elements_b3.loc[:, 17] + earth_vsop87_elements_b3.loc[:, 18]*tau)
b_4_earth = earth_vsop87_elements_b4.loc[:, 16] * np.cos(earth_vsop87_elements_b4.loc[:, 17] + earth_vsop87_elements_b4.loc[:, 18]*tau)


B_earth = (np.sum(b_0_earth) + np.sum(b_1_earth)*tau + np.sum(b_2_earth)*(tau**2) + np.sum(b_3_earth)*(tau**3)
          + np.sum(b_4_earth)*(tau**4))

r_0_earth = earth_vsop87_elements_r0.loc[:, 16] * np.cos((earth_vsop87_elements_r0.loc[:, 17] + earth_vsop87_elements_r0.loc[:, 18]*tau))
r_1_earth = earth_vsop87_elements_r1.loc[:, 16] * np.cos((earth_vsop87_elements_r1.loc[:, 17] + earth_vsop87_elements_r1.loc[:, 18]*tau))
r_2_earth = earth_vsop87_elements_r2.loc[:, 16] * np.cos((earth_vsop87_elements_r2.loc[:, 17] + earth_vsop87_elements_r2.loc[:, 18]*tau))
r_3_earth = earth_vsop87_elements_r3.loc[:, 16] * np.cos((earth_vsop87_elements_r3.loc[:, 17] + earth_vsop87_elements_r3.loc[:, 18]*tau))
r_4_earth = earth_vsop87_elements_r4.loc[:, 16] * np.cos((earth_vsop87_elements_r4.loc[:, 17] + earth_vsop87_elements_r4.loc[:, 18]*tau))
r_5_earth = earth_vsop87_elements_r5.loc[:, 16] * np.cos((earth_vsop87_elements_r0.loc[:, 17] + earth_vsop87_elements_r5.loc[:, 18]*tau))

R_earth = (np.sum(r_0_earth) + np.sum(r_1_earth)*tau + np.sum(r_2_earth)*(tau**2) + np.sum(r_3_earth)*(tau**3)
          + np.sum(r_4_earth)*(tau**4) + np.sum(r_5_earth)*(tau**5))

L_earth_deg = L_earth*180/np.pi;

B_earth_deg = B_earth*180/np.pi;


while(L_earth_deg < 0 or L_earth_deg > 360):
    
    if(L_earth_deg > 360):
        L_earth_deg = L_earth_deg - 360;
    else:
        L_earth_deg = L_earth_deg + 360


print("L_earth : " + str(L_earth_deg))
print("B_earth : " + str(B_earth_deg))
print("R_earth : " + str(R_earth))
# Out:
# L_earth : 84.28503093505697
# B_earth : 0.0002064937605841353
# R_earth : 0.9841232200710164

# %%
#heliocentric coordinates of jupiter, [eliocentric - ] latitude, longitiude and radius vector

# A = col 16, B = col 17, C = col 18

l_0_jupiter = jupiter_vsop87_elements_l0.loc[:, 16] * np.cos((jupiter_vsop87_elements_l0.loc[:, 17] + jupiter_vsop87_elements_l0.loc[:, 18]*tau))
l_1_jupiter = jupiter_vsop87_elements_l1.loc[:, 16] * np.cos((jupiter_vsop87_elements_l1.loc[:, 17] + jupiter_vsop87_elements_l1.loc[:, 18]*tau))
l_2_jupiter = jupiter_vsop87_elements_l2.loc[:, 16] * np.cos((jupiter_vsop87_elements_l2.loc[:, 17] + jupiter_vsop87_elements_l2.loc[:, 18]*tau))
l_3_jupiter = jupiter_vsop87_elements_l3.loc[:, 16] * np.cos((jupiter_vsop87_elements_l3.loc[:, 17] + jupiter_vsop87_elements_l3.loc[:, 18]*tau))
l_4_jupiter = jupiter_vsop87_elements_l4.loc[:, 16] * np.cos((jupiter_vsop87_elements_l4.loc[:, 17] + jupiter_vsop87_elements_l4.loc[:, 18]*tau))
l_5_jupiter = jupiter_vsop87_elements_l5.loc[:, 16] * np.cos((jupiter_vsop87_elements_l0.loc[:, 17] + jupiter_vsop87_elements_l5.loc[:, 18]*tau))

L_jupiter = (np.sum(l_0_jupiter) + np.sum(l_1_jupiter)*tau + np.sum(l_2_jupiter)*(tau**2) + np.sum(l_3_jupiter)*(tau**3)
          + np.sum(l_4_jupiter)*(tau**4) + np.sum(l_5_jupiter)*(tau**5))

b_0_jupiter = jupiter_vsop87_elements_b0.loc[:, 16] * np.cos((jupiter_vsop87_elements_b0.loc[:, 17] + jupiter_vsop87_elements_b0.loc[:, 18]*tau))
b_1_jupiter = jupiter_vsop87_elements_b1.loc[:, 16] * np.cos((jupiter_vsop87_elements_b1.loc[:, 17] + jupiter_vsop87_elements_b1.loc[:, 18]*tau))
b_2_jupiter = jupiter_vsop87_elements_b2.loc[:, 16] * np.cos((jupiter_vsop87_elements_b2.loc[:, 17] + jupiter_vsop87_elements_b2.loc[:, 18]*tau))
b_3_jupiter = jupiter_vsop87_elements_b3.loc[:, 16] * np.cos((jupiter_vsop87_elements_b3.loc[:, 17] + jupiter_vsop87_elements_b3.loc[:, 18]*tau))
b_4_jupiter = jupiter_vsop87_elements_b4.loc[:, 16] * np.cos((jupiter_vsop87_elements_b4.loc[:, 17] + jupiter_vsop87_elements_b4.loc[:, 18]*tau))
b_5_jupiter = jupiter_vsop87_elements_b5.loc[:, 16] * np.cos((jupiter_vsop87_elements_b5.loc[:, 17] + jupiter_vsop87_elements_b5.loc[:, 18]*tau))


b_0_jupiter.head(10)

B_jupiter = (np.sum(b_0_jupiter) + np.sum(b_1_jupiter)*tau + np.sum(b_2_jupiter)*(tau**2) + np.sum(b_3_jupiter)*(tau**3)
          + np.sum(b_4_jupiter)*(tau**4) + np.sum(b_5_jupiter)*(tau**5))

r_0_jupiter = jupiter_vsop87_elements_r0.loc[:, 16] * np.cos((jupiter_vsop87_elements_r0.loc[:, 17] + jupiter_vsop87_elements_r0.loc[:, 18]*tau))
r_1_jupiter = jupiter_vsop87_elements_r1.loc[:, 16] * np.cos((jupiter_vsop87_elements_r1.loc[:, 17] + jupiter_vsop87_elements_r1.loc[:, 18]*tau))
r_2_jupiter = jupiter_vsop87_elements_r2.loc[:, 16] * np.cos((jupiter_vsop87_elements_r2.loc[:, 17] + jupiter_vsop87_elements_r2.loc[:, 18]*tau))
r_3_jupiter = jupiter_vsop87_elements_r3.loc[:, 16] * np.cos((jupiter_vsop87_elements_r3.loc[:, 17] + jupiter_vsop87_elements_r3.loc[:, 18]*tau))
r_4_jupiter = jupiter_vsop87_elements_r4.loc[:, 16] * np.cos((jupiter_vsop87_elements_r4.loc[:, 17] + jupiter_vsop87_elements_r4.loc[:, 18]*tau))
r_5_jupiter = jupiter_vsop87_elements_r5.loc[:, 16] * np.cos((jupiter_vsop87_elements_r0.loc[:, 17] + jupiter_vsop87_elements_r5.loc[:, 18]*tau))

R_jupiter = (np.sum(r_0_jupiter) + np.sum(r_1_jupiter)*tau + np.sum(r_2_jupiter)*(tau**2) + np.sum(r_3_jupiter)*(tau**3)
          + np.sum(r_4_jupiter)*(tau**4) + np.sum(r_5_jupiter)*(tau**5))


L_jupiter_deg = L_jupiter*180/np.pi;

B_jupiter_deg = B_jupiter*180/np.pi;


while(L_jupiter_deg < 0 or L_jupiter_deg > 360):
    
    if(L_jupiter_deg > 360):
        L_jupiter_deg = L_jupiter_deg - 360;
    else:
        L_jupiter_deg = L_jupiter_deg + 360


print("L_jupiter : " + str(L_jupiter_deg))
print("B_jupiter : " + str(B_jupiter_deg))
print("R_jupiter : " + str(R_jupiter))
# Out:
# L_jupiter : 181.88214220603035
# B_jupiter : 1.2904740415782932
# R_jupiter : 5.446423139894462

# %%
#convert to heliocentric cartesian

#earth
x_earth = R_earth*np.cos(B_earth)*np.cos(L_earth)
y_earth = R_earth*np.cos(B_earth)*np.sin(L_earth)
z_earth = R_earth*np.sin(B_earth)

#jupiter
x_jupiter = R_jupiter*np.cos(B_jupiter)*np.cos(L_jupiter)
y_jupiter = R_jupiter*np.cos(B_jupiter)*np.sin(L_jupiter)
z_jupiter = R_jupiter*np.sin(B_jupiter)


print("Earth's position in heliocentric coordinates : x|y|z : " + str(x_earth)+"|"+str(y_earth)+"|"+str(z_earth))
print("Jupiter's position in heliocentric coordinates : x|y|z : " + str(x_jupiter)+"|"+str(y_jupiter)+"|"+str(z_jupiter))
# Out:
# Earth's position in heliocentric coordinates : x|y|z : 0.09799870883525073|0.979231721982591|3.546776155542011e-06
# Jupiter's position in heliocentric coordinates : x|y|z : -5.442104155941271|-0.1788351589246649|0.12265953121131797

# %%
#calculate distance between earth and jupiter (Delta)
x_dist = x_jupiter - R_earth*np.cos(L_earth)
y_dist = y_jupiter - R_earth*np.sin(L_earth)
z_dist = z_jupiter - R_earth*np.sin(B_earth)

Delta = np.sqrt(x_dist**2  + y_dist**2 + z_dist**2)

print("Earth-Jupiter distance : x|y|z-->Delta : " + str(x_dist)+"|"+str(y_dist)+"|"+str(z_dist)+"|"+str(Delta))
# Out:
# Earth-Jupiter distance : x|y|z-->Delta : -5.540102864777158|-1.1580668809136154|0.12265598443516243|5.661175067377693

# %%
#correct jupiter's heliocentric latitude for the light-delay time

l_correction_deg = -0.01299*Delta/(R_jupiter**2)

print("l-correction term in deg : "+str(l_correction_deg))
# Out:
# l-correction term in deg : -0.002479093906698013

# %%
#repeat cnversion to cartesian with the updated latutude of jupiter and recmpute the diatnce Delta

L_jupiter = L_jupiter + l_correction_deg*(np.pi/180)

x_jupiter = R_jupiter*np.cos(B_jupiter)*np.cos(L_jupiter)
y_jupiter = R_jupiter*np.cos(B_jupiter)*np.sin(L_jupiter)
z_jupiter = R_jupiter*np.sin(B_jupiter)


print("Jupiter's position in heliocentric coordinates --corrected for light delay : x|y|z : " + str(x_jupiter)+"|"+str(y_jupiter)+"|"+str(z_jupiter))

#calculate distance between earth and jupiter (Delta) accounting for light delay
x_dist = -x_earth + x_jupiter
y_dist = -y_earth + y_jupiter
z_dist = -z_earth + z_jupiter

Delta = np.sqrt(x_dist**2  + y_dist**2 + z_dist**2)

print("Earth-Jupiter distance : x|y|z-->Delta : " + str(x_dist)+"|"+str(y_dist)+"|"+str(z_dist)+"|"+str(Delta))
# Out:
# Jupiter's position in heliocentric coordinates --corrected for light delay : x|y|z : -5.442111888749502|-0.17859968788378638|0.12265953121131797
# Earth-Jupiter distance : x|y|z-->Delta : -5.540110597584753|-1.1578314098663773|0.12265598443516243|5.661134470904379

# %%
#obliuquity of the ecliptic 

epsilon_0_deg = 23.43929111 - 0.01300416667*T - 0.0000001638888889*(T**2) + 0.0000005036111111*(T**3)

print("Epsilon_0 in degrees : " + str(epsilon_0_deg))
# Out:
# Epsilon_0 in degrees : 23.440207008224167

# %%
alpha_s = np.arctan2(np.cos(np.deg2rad(epsilon_0_deg))*np.sin(L_jupiter)-np.sin(np.deg2rad(epsilon_0_deg))*np.tan(B_jupiter), np.cos(L_jupiter))
delta_s = np.cos(np.deg2rad(epsilon_0_deg))*np.sin(B_jupiter) + np.sin(np.deg2rad(epsilon_0_deg))*np.cos(B_jupiter)*np.sin(L_jupiter)

print("alpha_s | delta_s : "+str(np.rad2deg(alpha_s))+"|"+str(np.rad2deg(delta_s)))
# Out:
# alpha_s | delta_s : -177.76227102887717|0.4364875895121452

# %%
D_s = np.arcsin(-np.sin(np.deg2rad(delta_0_deg))*np.sin(delta_s)-np.cos(np.deg2rad(delta_0_deg))*np.cos(delta_s)*np.cos(np.deg2rad(alpha_0_deg)-alpha_s))

print("D_s : " + str(np.rad2deg(D_s)))
# Out:
# D_s : -2.198049947779022

# %%
u_jupiter = y_dist*np.cos(np.deg2rad(epsilon_0_deg))-z_dist*np.sin(np.deg2rad(epsilon_0_deg))
v_jupiter = y_dist*np.sin(np.deg2rad(epsilon_0_deg))+z_dist*np.cos(np.deg2rad(epsilon_0_deg))

alpha_jupiter = np.arctan2(u_jupiter, x_dist)

delta_jupiter = np.arctan2(v_jupiter, np.sqrt(x_dist**2 + u_jupiter**2))

zeta_jupiter = np.arctan2(np.sin(np.deg2rad(delta_0_deg))*np.cos(delta_jupiter)*np.cos(np.deg2rad(alpha_0_deg)-alpha_jupiter)-np.sin(delta_jupiter)*np.cos(np.deg2rad(delta_0_deg)), np.cos(delta_jupiter)*np.sin(np.deg2rad(alpha_0_deg)-alpha_jupiter))

print("u|v|alpha|delta|zeta of jupiter")
print(str(u_jupiter)+"|"+str(v_jupiter)+"|"+str(np.rad2deg(alpha_jupiter))+"|"+str(np.rad2deg(delta_jupiter))+"|"+str(np.rad2deg(zeta_jupiter)))
# Out:
# u|v|alpha|delta|zeta of jupiter
# -1.1110737346439574|-0.348041980765612|-168.6597248013544|-3.5247210826780293|13.523701821605837

# %%
D_E = np.arcsin(-np.sin(np.deg2rad(delta_0_deg))*np.sin(delta_jupiter)-np.cos(np.deg2rad(delta_0_deg))*np.cos(delta_jupiter)*np.cos(np.deg2rad(alpha_0_deg)-alpha_jupiter))

print("D_E : " + str(np.rad2deg(D_E)))
# Out:
# D_E : -2.4846328180499615

# %%
omega_1_deg = W_1_deg - np.rad2deg(zeta_jupiter) - 5.07033*Delta

omega_2_deg = W_2_deg - np.rad2deg(zeta_jupiter) - 5.02626*Delta

print("omega_1 in deg : " + str(omega_1_deg) + " omega 2 in deg : " + str(omega_2_deg))
# Out:
# omega_1 in deg : 267.0377473371996 omega 2 in deg : 71.71523353270652

# %%
np.cos(np.pi/6)
# Out:
# 0.8660254037844387
